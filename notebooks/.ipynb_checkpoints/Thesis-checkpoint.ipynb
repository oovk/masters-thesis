# %% [markdown]
# # Data Extraction and Cleaning

# %%
import pandas as pd

df1 = pd.read_excel('./../AmplifiersData/AudioAmplifiers.xlsx')
df2 = pd.read_excel('./../AmplifiersData/GPSAmplifiers.xlsx')
df4 = pd.read_excel('./../AmplifiersData/OperationalAmplifiers.xlsx')
df5 = pd.read_excel('./../AmplifiersData/VideoAmplifiers.xlsx')
df6 = pd.read_excel('./../AmplifiersData/InstrumentationAmplifiers.xlsx')

# %%
AudioAmpData = df1.drop(columns=['Description','Product line'])
AudioAmpData = AudioAmpData.to_csv(index=False)
AudioAmpData
# Out:
# 'Part,Type,Manufacturer,PowerSupplyType,InputSignalType,OutputSignalType,OutputType,PinCount,TypicalSingleSupplyVoltage,TypicalSingleSupplyVoltageUnit,MinimumSingleSupplyVoltage,MinimumSingleSupplyVoltageUnit,MaximumSingleSupplyVoltage,MaximumSingleSupplyVoltageUnit,MinimumOperatingTemperature,MinimumOperatingTemperatureUnit,MaximumOperatingTemperature,MaximumOperatingTemperatureUnit,MaximumPowerDissipation,MaximumPowerDissipationUnit\nLM4861M-NOPB ,Class-AB ,Texas Instruments ,Single ,Single ,Differential ,1-Channel Mono ,8,3|5,V,2,V,5.5,V,-40,°C,85,°C,-,mW\nLM4889MA-NOPB ,Class-AB ,Texas Instruments ,Single ,Differential|Single ,Differential ,1-Channel Mono ,8,3|5,V,2.2,V,5.5,V,-40,°C,85,°C,-,mW\nTPA3125D2N ,Class-D ,Texas Instruments ,Single ,Single ,Differential|Single ,1-Channel Mono|2-Channel Stereo ,20,12|15|18|24,V,10,V,26,V,-40,°C,85,°C,1870,mW\nBD28623MUV-E2 ,Class-D ,ROHM Semiconductor ,Single ,Single ,Differential ,2-Channel Stereo ,24,9|12|15|18,V,8.5,V,24,V,-25,°C,85,°C,3560,mW\nOPA1611AID ,Class-AB ,Texas Instruments ,Single|Dual ,Differential ,Single ,1-Channel Mono ,8,5|9|12|15|18|24|28,V,4.5,V,36,V,-40,°C,85,°C,-,mW\nPAM8945PJR ,Class-G ,Diodes Incorporated ,Single ,Differential ,Differential ,1-Channel Mono ,12,3|5,V,2.8,V,5.2,V,-40,°C,85,°C,-,mW\nLM4862M-NOPB ,Class-AB ,Texas Instruments ,Single ,Single ,Differential ,1-Channel Mono ,8,3|5,V,2.7,V,5.5,V,-40,°C,85,°C,-,mW\nLM386MMX-1-NOPB ,Class-AB ,Texas Instruments ,Single ,Differential ,Single ,1-Channel Mono ,8,5|9,V,4,V,12,V,-,°C,70,°C,595,mW\nBM28723AMUV-E2 ,Class-D ,ROHM Semiconductor ,Triple ,Single ,Differential ,2-Channel Stereo ,32,-,V,-,V,-,V,-25,°C,85,°C,-,mW\nPAM8610TR ,Class-D ,Diodes Incorporated ,Single ,Differential ,Differential ,2-Channel Stereo ,40,12,V,7,V,15,V,-20,°C,85,°C,-,mW\n'

# %%
GPSAmpData = df2.drop(columns=['Description','ProductLine'])
GPSAmpData = GPSAmpData.to_csv(index=False)
GPSAmpData
# Out:
# 'Part,Type,Manufacturer,ProcessTechnology,PowerSupplyType,PinCount,MaximumGain,MaximumGainUnit,TypicalSingleSupplyVoltage,TypicalSingleSupplyVoltageUnit,MinimumSingleSupplyVoltage,MinimumSingleSupplyVoltageUnit,MaximumSingleSupplyVoltage,MaximumSingleSupplyVoltageUnit,MinimumOperatingFrequency,MinimumOperatingFrequencyUnit,MaximumOperatingFrequency,MaximumOperatingFrequencyUnit,TypicalNoiseFigure,TypicalNoiseFigureUnit,MinimumOperatingTemperature,MinimumOperatingTemperatureUnit,MaximumOperatingTemperature,MaximumOperatingTemperatureUnit,MaximumSupplyCurrent,MaximumSupplyCurrentUnit,MaximumPowerDissipation,MaximumPowerDissipationUnit\nBGA725L6E6327FTSA1,Low Noise Amplifier,Infineon Technologies AG,SiGe,Single,6,-,dB,3,V,1.5,V,3.6,V,1550,MHz,1615,MHz,0.65,dB,-40,°C,85,°C,3.6,mA,72,mW\nBGU7005-115,Low Noise Amplifier,NXP Semiconductors,SiGe,Single,6,20,dB,1.8,V,1.5,V,3.1,V,-,MHz,1850,MHz,1.3,dB,-40,°C,85,°C,14.4,mA,55,mW\nBGA123L4E6327XTSA1,Low Noise Amplifier,Infineon Technologies AG,-,Single,4,19.9,dB,1.8,V,1.1,V,3.6,V,1550,MHz,1615,MHz,0.75,dB,-40,°C,85,°C,1.7,mA,40,mW\nBGA715N7E6327XTSA2,Low Noise Amplifier,Infineon Technologies AG,SiGe,Single,6,20,dB,1.8,V,1.5,V,3.6,V,1550,MHz,1615,MHz,0.7,dB,-40,°C,85,°C,3.3,mA,36,mW\nBGU8103X,Low Noise Amplifier,NXP Semiconductors,SiGe,Single,6,18.5,dB,3,V,1.5,V,3.1,V,1559,MHz,1610,MHz,1.4,dB,-40,°C,85,°C,2.5,mA,55,mW\nBGU8019X,Low Noise Amplifier,NXP Semiconductors,SiGe,Single,6,20.5,dB,3,V,1.5,V,3.1,V,1559,MHz,1610,MHz,1.3,dB,-40,°C,85,°C,10.0,mA,55,mW\nBGU7007-115,Low Noise Amplifier,NXP Semiconductors,SiGe,Single,6,21.5,dB,-,-,1.5,V,3.1,V,1559,MHz,1610,MHz,1.3,dB,-40,°C,85,°C,15.9,mA,55,mW\nBGU7008-115,Low Noise Amplifier,NXP Semiconductors,SiGe,Single,6,21.5,dB,-,-,1.5,V,2.85,V,1559,MHz,1610,MHz,1.3,dB,-40,°C,125,°C,15.9,mA,55,mW\nBGU7004-115,Low Noise Amplifier,NXP Semiconductors,SiGe,Single,6,21,dB,-,-,1.5,V,2.85,V,1559,MHz,1610,MHz,1.3,dB,-40,°C,125,°C,14.4,mA,55,mW\nBGA524N6E6327XTSA1,Low Noise Amplifier,Infineon Technologies AG,SiGe,Single,6,-,dB,3,V,1.5,V,3.3,V,1550,MHz,1615,MHz,0.55,dB,-40,°C,85,°C,3.6,mA,60,mW\n'

# %%
InstruAmpData = df6.drop(columns=['Description','ProductLine'])
InstruAmpData = InstruAmpData.to_csv(index=False)
InstruAmpData
# Out:
# 'Part,Type,Manufacturer,PowerSupplyType,PinCount,MinimumPSRR,MinimumPSRRUnit,MaximumOperatingSupplyVoltage,MaximumOperatingSupplyVoltageUnit,MinimumSupplyVoltage,MinimumSupplyVoltageUnit,MaximumSupplyVoltage,MaximumSupplyVoltageUnit,TypicalDualSupplyVoltage,TypicalDualSupplyVoltageUnit,TypicalSingleSupplyVoltage,TypicalSingleSupplyVoltageUnit,MinimumCMRR,MinimumCMRRUnit,MaximumInputBiasCurrent,MaximumInputBiasCurrentUnit,MinimumOperatingTemperature,MinimumOperatingTemperatureUnit,MaximumOperatingTemperature,MaximumOperatingTemperatureUnit\nINA101HP ,Single,Texas Instruments ,Dual ,14,-,dB,±20,V,30,V,50,V,±15,V,-,V,-,dB,0.02,uA,-,°C,70,°C\nMCP6N11T-100E-MNY ,Single,Microchip Technology ,Single ,8,86,dB,5.5,V,5,V,7,V,-,V,3.3|5,V,86,dB,-,uA,-40,°C,125,°C\nINA122PA ,Single,Texas Instruments ,Single|Dual ,8,100,dB,±18|36,V,30,V,50,V,±3|±5|±9|±12|±15,V,5,V,76,dB,0.05,uA,-40,°C,85,°C\nPGA204AP ,Single,Texas Instruments ,Dual ,16,-,dB,±18,V,30,V,50,V,±15,V,-,V,75,dB,0.005,uA,-40,°C,85,°C\nINA125UA ,Single,Texas Instruments ,Single|Dual ,16,-,dB,±18|36,V,30,V,50,V,±15,V,5,V,72,dB,0.05,uA,-55,°C,125,°C\nINA115BU ,Single,Texas Instruments ,Dual ,16,-,dB,±18,V,30,V,50,V,±15,V,-,V,80,dB,-,uA,-40,°C,85,°C\nINA217AIDWT ,Single,Texas Instruments ,Dual ,16,-,dB,±18,V,30,V,50,V,±15,V,-,V,70,dB,12,uA,-40,°C,125,°C\nLMP8358MA-NOPB ,Single,Texas Instruments ,Single ,14,112,dB,5.5,V,5,V,7,V,-,V,3|5,V,116,dB,-,uA,-40,°C,125,°C\nMCP6N16-010E-MS ,Single,Microchip Technology ,Single ,8,104,dB,5.5,V,5,V,7,V,-,V,3.3|5,V,94,dB,-,uA,-40,°C,125,°C\nINA2128U ,Dual,Texas Instruments ,Dual ,16,-,dB,±18,V,30,V,50,V,±15,V,-,V,80,dB,0.005,uA,-40,°C,85,°C\n'

# %%
OpAmpData = df4.drop(columns=['Description','ProductLine'])
OpAmpData = OpAmpData.to_csv(index=False)
OpAmpData
# Out:
# 'Part,Type,Manufacturer,ProcessTechnology,PowerSupplyType,PinCount,MinimumPSRR,MinimumPSRRUnit,MaximumOperatingSupplyVoltage,MaximumOperatingSupplyVoltageUnit,MinimumSupplyVoltage,MinimumSupplyVoltageUnit,MaximumSupplyVoltage,MaximumSupplyVoltageUnit,TypicalSingleSupplyVoltage,TypicalSingleSupplyVoltageunit,MinimumSingleSupplyVoltage,MinimumSingleSupplyVoltageUnit,MaximumSingleSupplyVoltage,MaximumSingleSupplyVoltageUnit,MinimumCMRR,MinimumCMRRUnit,MaximumInputBiasCurrent,MaximumInputBiasCurrentUnit,MinimumOperatingTemperature,MinimumOperatingTemperatureUnit,MaximumOperatingTemperature,MaximumOperatingTemperatureUnit,TypicalOutputCurrent,TypicalOutputCurrentUnit,TypicalGainBandwidthProduct,TypicalGainBandwidthProductUnit\nMCP607-I-P ,Micropower Amplifier ,Microchip Technology ,CMOS ,Single ,8,80,dB,6,V,6.0,V,9,V,3|5,V,2.5,V,6.0,V,75,dB,-,uA,-40,°C,85,°C,30,mA,0.155,MHz\nMCP6034-E-SL ,Precision Amplifier ,Microchip Technology ,CMOS ,Single ,14,70,dB,5.5,V,5.5,V,6,V,3|5,V,1.8,V,5.5,V,70,dB,0.0001,uA,-40,°C,125,°C,30,mA,0.01,MHz\nMCP6V27-E-SN ,Auto Zero Amplifier ,Microchip Technology ,CMOS ,Single ,8,125,dB,5.5,V,5.5,V,6,V,3|5,V,2.3,V,5.5,V,120,dB,0.005,uA,-40,°C,125,°C,30,mA,2.0,MHz\nLM6132BIN-NOPB ,Low Power Amplifier ,Texas Instruments ,-,Single ,8,78,dB,24,V,17.0,V,30,V,3|5|9|12|15|18,V,1.8,V,24.0,V,60,dB,0.18,uA,-40,°C,85,°C,30,mA,10.0,MHz\nMCP6292-E-P ,General Purpose Amplifier ,Microchip Technology ,CMOS ,Single ,8,70,dB,5.5,V,5.5,V,6,V,3|5,V,2.4,V,6.0,V,70,dB,1e-06,uA,-40,°C,125,°C,30,mA,10.0,MHz\nMCP6V32-E-MS ,Chopper Amplifier ,Microchip Technology ,CMOS ,Single ,8,120,dB,5.5,V,5.5,V,6,V,3|5,V,1.8,V,5.5,V,120,dB,-,uA,-40,°C,125,°C,30,mA,0.3,MHz\nOPA625IDBVT ,High Speed Amplifier ,Texas Instruments ,Bipolar ,Single|Dual ,8,100,dB,±2.75|5.5,V,5.5,V,6,V,5|9,V,3.0,V,12.0,V,72,dB,2.6,uA,-40,°C,85,°C,110,mA,86.0,MHz\nLMH6639MA-NOPB ,Low Offset Voltage Amplifier ,Texas Instruments ,VIP10 ,Single|Dual ,8,72,dB,±6|12,V,12.0,V,12.5,V,5|9|12|15|18|24|28,V,4.0,V,40.0,V,85,dB,0.07,uA,-40,°C,85,°C,20,mA,1.2,MHz\nTLC27M2CP ,Wideband Amplifier ,Texas Instruments ,LinCMOS ,Single ,8,-,dB,16,V,16.0,V,17,V,3,V,2.7,V,5.0,V,54,dB,1e-05,uA,-40,°C,85,°C,-,mA,5.5,MHz\nOPA343UA ,Low Noise Amplifier ,Texas Instruments ,CMOS ,Single|Dual ,8,87.96,dB,5,V,5.5,V,-,V,5|9|12|15,V,4.4,V,16.0,V,70,dB,0.0001,uA,-,°C,70,°C,50,mA,0.71,MHz\n'

# %%
VideoAmpData = df5.drop(columns=['Description','ProductLine'])
VideoAmpData = VideoAmpData.to_csv(index=False)
VideoAmpData
# Out:
# 'Part,Type,Manufacturer,PowerSupplyType,PinCount,TypicalDualSupplyVoltage,TypicalDualSupplyVoltageUnit,MinimumDualSupplyVoltage,MinimumDualSupplyVoltageUnit,MaximumDualSupplyVoltage,MaximumDualSupplyVoltageUnit,TypicalSingleSupplyVoltage,TypicalSingleSupplyVoltageUnit,MinimumSingleSupplyVoltage,MinimumSingleSupplyVoltageUnit,MaximumSingleSupplyVoltage,MaximumSingleSupplyVoltageUnit,MinimumOperatingTemperature,MinimumOperatingTemperatureUnit,MaximumOperatingTemperature,MaximumOperatingTemperatureUnit\nLMH6714MF-NOPB ,Single,Texas Instruments ,Single|Dual ,5,±5,V,±4,V,±6.25,V,9|12,V,8,V,12.6,V,-40,°C,85,°C\nLM6172IN-NOPB ,Dual,Texas Instruments ,Dual ,8,±5|±15,V,±2.75,V,±18,V,-,V,-,V,-,V,-40,°C,85,°C\nLMH6720MF-NOPB ,Single,Texas Instruments ,Single|Dual ,6,±5,V,±4,V,±6.25,V,9|12,V,8,V,12.5,V,-40,°C,85,°C\nLMH6739MQ-NOPB ,Triple,Texas Instruments ,Single ,16,-,V,-,V,-,V,9,V,8,V,12,V,-40,°C,85,°C\nLMH6738MQ-NOPB ,Triple,Texas Instruments ,Single ,16,-,V,-,V,-,V,9,V,8,V,12,V,-40,°C,85,°C\nAD812ARZ ,Dual,Analog Devices ,Single|Dual ,8,±3|±5|±12|±15,V,±1.2,V,±18,V,3|5|9|12|15|18|24|28,V,2.4,V,36,V,-40,°C,85,°C\nLMH6722MA-NOPB ,Quad,Texas Instruments ,Single|Dual ,14,±5,V,±4,V,±6.25,V,9|12,V,8,V,12.5,V,-40,°C,85,°C\nTHS7360IPW ,Hex,Texas Instruments ,Single ,20,-,V,-,V,-,V,3,V,2.7,V,5,V,-40,°C,85,°C\nTHS7374IPW ,Quad,Texas Instruments ,Single ,14,-,V,-,V,-,V,-,V,3,V,5,V,-40,°C,85,°C\nTHS7360IPWR ,Hex,Texas Instruments ,Single ,20,-,V,-,V,-,V,3,V,2.7,V,5,V,-40,°C,85,°C\n'

# %% [markdown]
# # Prompt Engineering

# %%
# Reading prompts from files
def read_file(file_path):
    try:
        with open(file_path, 'r') as file:
            file_content = file.read()
            return file_content
    except FileNotFoundError:
        print(f"The file at path '{file_path}' was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# Setting Prompts:
file1_path = "./../prompts/AudioInput.txt"
file2_path = "./../prompts/AudioOutput.txt"
file3_path = "./../prompts/GPSInput.txt"
file4_path = "./../prompts/GPSOutput.txt"
file5_path = "./../prompts/InstrumentationInput.txt"
file6_path = "./../prompts/InstrumentationOutput.txt"
file7_path = "./../prompts/OpInput.txt"
file8_path = "./../prompts/OpOutput.txt"
file9_path = "./../prompts/RFInput.txt"
file10_path = "./../prompts/RFOutput.txt"
file11_path = "./../prompts/VideoInput.txt"
file12_path = "./../prompts/VideoOutput.txt"
file13_path = "./../prompts/system2.txt"

audio_input_prompt = read_file(file1_path)
audio_ouput_prompt = read_file(file2_path)
gps_input_prompt = read_file(file3_path)
gps_ouput_prompt = read_file(file4_path)
instru_input_prompt = read_file(file5_path)
instru_ouput_prompt = read_file(file6_path)
op_input_prompt = read_file(file7_path)
op_ouput_prompt = read_file(file8_path)
rf_input_prompt = read_file(file9_path)
rf_ouput_prompt = read_file(file10_path)
video_input_prompt = read_file(file11_path)
video_ouput_prompt = read_file(file12_path)
system_prompt = read_file(file13_path)

# %% [markdown]
# # LLM for Triplets Extraction

# %%
import vertexai
from vertexai import language_models

project_id = "modular-glider-408308"
location = "us-central1"

def extract_triplets(project_id: str, location: str, data: str, input_prompt:str, output_prompt:str) -> str:
    """Extract Triplets with a Large Language Model."""

    vertexai.init(project=project_id, location=location)

    chat_model = language_models.ChatModel.from_pretrained("chat-bison")

    parameters = {
        "temperature": 0.8,
        "max_output_tokens": 2048,
        "top_p": 0.95,
        "top_k": 40,
    }

    chat = chat_model.start_chat(
        context=system_prompt,   #add our system_prompt
        examples=[
            language_models.InputOutputTextPair(
                input_text=input_prompt,   #add input data example
                output_text=output_prompt, #add output we expect
            ),
        ],
    )

    responses = chat.send_message_streaming(
        message=data,   #provide our own data
        **parameters,
    )

    results = []
    for response in responses:
        results.append(str(response.candidates[0].text))
    results = "".join(results)
    return results

# %%
import csv
import json
from io import StringIO

def process_csv_to_triplets(csv_data, project_id, location, input_prompt, output_prompt):
    
    # Use StringIO to simulate reading from a file
    csv_file = StringIO(csv_data.strip())

    # Use csv.reader to read the CSV data
    reader = csv.reader(csv_file)

    # Read the header row
    header = next(reader)

    for row in reader:
    
        # Combine the header and row into a single list
        combined_row = header + row
        row_data = ','.join(combined_row)
        json_data = extract_triplets(project_id, location, row_data, input_prompt, output_prompt)
        
        print(json_data)

# %% [markdown]
# ## Extracted triplets using Google's Gemini

# %%
process_csv_to_triplets(AudioAmpData, project_id, location, audio_input_prompt, audio_ouput_prompt)
# Out:
#  [
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasType",
#     "tail": "Class-AB"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasInputSignalType",
#     "tail": "Single"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasOutputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasOutputType",
#     "tail": "1-Channel Mono"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "\u00b0C"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  ```json
# [
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasType",
#     "tail": "Class-AB"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasInputSignalType",
#     "tail": "Differential|Single"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasOutputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasOutputType",
#     "tail": "1-Channel Mono"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.2"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "\u00b0C"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
# ```
#  [
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasType",
#     "tail": "Class-D"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasInputSignalType",
#     "tail": "Single"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasOutputSignalType",
#     "tail": "Differential|Single"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasOutputType",
#     "tail": "1-Channel Mono|2-Channel Stereo"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasPinCount",
#     "tail": "20"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "12|15|18|24"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "10"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "26"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1870"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  """
# [
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasType",
#     "tail": "Class-D"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasManufacturer",
#     "tail": "ROHM Semiconductor"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasInputSignalType",
#     "tail": "Single"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasOutputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasOutputType",
#     "tail": "2-Channel Stereo"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasPinCount",
#     "tail": "24"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "9|12|15|18"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "8.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "24"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-25"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3560"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
# """
#  {
#     "head": "OPA1611AID",
#     "relation": "hasType",
#     "tail": "Class-AB"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasInputSignalType",
#     "tail": "Differential"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasOutputSignalType",
#     "tail": "Single"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasOutputType",
#     "tail": "1-Channel Mono"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasPinCount",
#     "tail": "8"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
# },
# {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "5|9|12|15|18|24|28"
# },
# {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "4.5"
# },
# {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "36"
# },
# {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
# },
# {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
# },
# {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
# },
# {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
# },
# {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
# },
# {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
# }
#  ```json
# [
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasType",
#     "tail": "Class-G"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasManufacturer",
#     "tail": "Diodes Incorporated"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasInputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasOutputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasOutputType",
#     "tail": "1-Channel Mono"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasPinCount",
#     "tail": "12"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.2"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
# ```
#  [
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasType",
#         "tail":"Class-AB"
#     },
#     {
#         "head": "LM4862M-NOPB",
#         "relation":"hasManufacturer",
#         "tail":"Texas Instruments"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasPowerSupplyType",
#         "tail":"Single"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasInputSignalType",
#         "tail":"Single"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasOutputSignalType",
#         "tail":"Differential"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasOutputType",
#         "tail":"1-Channel Mono"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasPinCount",
#         "tail":"8"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasProperty",
#         "tail":"SingleSupplyVoltage"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasNumericalValue",
#         "tail":"3|5"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"2.7"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"5.50"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasProperty",
#         "tail":"OperatingTemperature"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"-40"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"85"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUnit",
#         "tail":"°C"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasProperty",
#         "tail":"PowerDissipation"
#     },
#     {
#         "head":"PowerDissipation",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"-"
#     },
#     {
#         "head":"PowerDissipation",
#         "relation":"hasUnit",
#         "tail":"mW"
#     }
# ]
#  [
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasType",
#     "tail": "Class-AB"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasInputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasOutputSignalType",
#     "tail": "Single"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasOutputType",
#     "tail": "1-Channel Mono"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasProperty",
#     "tail": "TypicalSingleSupplyVoltage"
#   },
#   {
#     "head": "TypicalSingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "5|9"
#   },
#   {
#     "head": "TypicalSingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasProperty",
#     "tail": "MinimumSingleSupplyVoltage"
#   },
#   {
#     "head": "MinimumSingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "4"
#   },
#   {
#     "head": "MinimumSingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasProperty",
#     "tail": "MaximumSingleSupplyVoltage"
#   },
#   {
#     "head": "MaximumSingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "12"
#   },
#   {
#     "head": "MaximumSingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasProperty",
#     "tail": "MinimumOperatingTemperature"
#   },
#   {
#     "head": "MinimumOperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasProperty",
#     "tail": "MaximumOperatingTemperature"
#   },
#   {
#     "head": "MaximumOperatingTemperature",
#     "relation": "hasNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "MaximumOperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasProperty",
#     "tail": "MaximumPowerDissipation"
#   },
#   {
#     "head": "MaximumPowerDissipation",
#     "relation": "hasNumericalValue",
#     "tail": "595"
#   },
#   {
#     "head": "MaximumPowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasType",
#     "tail": "Class-D"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasManufacturer",
#     "tail": "ROHM Semiconductor"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasPowerSupplyType",
#     "tail": "Triple"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasInputSignalType",
#     "tail": "Single"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasOutputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasOutputType",
#     "tail": "2-Channel Stereo"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasPinCount",
#     "tail": "32"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-25"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "PAM8610TR",
#     "relation": "hasType",
#     "tail": "Class-D"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasManufacturer",
#     "tail": "Diodes Incorporated"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasInputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasOutputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasOutputType",
#     "tail": "2-Channel Stereo"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasPinCount",
#     "tail": "40"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "12"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "7"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "15"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-20"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]

# %%
process_csv_to_triplets(GPSAmpData, project_id, location, gps_input_prompt, gps_ouput_prompt)
# Out:
#  ```json
# [
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasManufacturer",
#     "tail": "Infineon Technologies AG"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.6"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1550"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1615"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "0.65"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.6"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "72"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
# ```
#  [
#   {
#     "head": "BGU7005-115",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasManufacturer",
#     "tail": "NXP Semiconductors"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "20"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "1.8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.1"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1850"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "1.3"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "14.4"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "55"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasManufacturer",
#     "tail": "Infineon Technologies AG"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasPinCount",
#     "tail": "4"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "19.9"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "1.8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.1"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.6"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1550"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1615"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "0.75"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1.7"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "40"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasManufacturer",
#     "tail": "Infineon Technologies AG"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "20"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "1.8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.6"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1550"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1615"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "0.7"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.3"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "36"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#   {
#     "head": "BGU8103X",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasManufacturer",
#     "tail": "NXP Semiconductors"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "18.5"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.1"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1559"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1610"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "1.4"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "2.5"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "55"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#   {
#     "head": "BGU8019X",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasManufacturer",
#     "tail": "NXP Semiconductors"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "20.5"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.1"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1559"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1610"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "1.3"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "\u00b0C"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "10.0"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "55"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#   {
#     "head": "BGU7007-115",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasManufacturer",
#     "tail": "NXP Semiconductors"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "21.5"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.1"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1559"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1610"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "1.3"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "15.9"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "55"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#     {
#         "head":"BGU7008-115",
#         "relation":"hasType",
#         "tail":"Low Noise Amplifier"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasManufacturer",
#         "tail":"NXP Semiconductors"
#     },
#     {
#         "head": "BGU7008-115",
#         "relation":"hasProcessTechnology",
#         "tail":"SiGe"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasPowerSupplyType",
#         "tail":"Single"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasPinCount",
#         "tail":"6"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasProperty",
#         "tail":"Gain"
#     },
#     {
#         "head":"Gain",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"21.5"
#     },
#     {
#         "head":"Gain",
#         "relation":"hasUnit",
#         "tail":"dB"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasProperty",
#         "tail":"SingleSupplyVoltage"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"1.5"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"2.85"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasProperty",
#         "tail":"OperatingFrequency"
#     },
#     {
#         "head":"OperatingFrequency",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"1559"
#     },
#     {
#         "head":"OperatingFrequency",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"1610"
#     },
#     {
#         "head":"OperatingFrequency",
#         "relation":"hasUnit",
#         "tail":"MHz"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasProperty",
#         "tail":"NoiseFigure"
#     },
#     {
#         "head":"NoiseFigure",
#         "relation":"hasNumericalValue",
#         "tail":"1.3"
#     },
#     {
#         "head":"NoiseFigure",
#         "relation":"hasUnit",
#         "tail":"dB"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasProperty",
#         "tail":"OperatingTemperature"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"-40"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"125"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUnit",
#         "tail":"°C"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasProperty",
#         "tail":"SupplyCurrent"
#     },
#     {
#         "head":"SupplyCurrent",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"15.9"
#     },
#     {
#         "head":"SupplyCurrent",
#         "relation":"hasUnit",
#         "tail":"mA"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasProperty",
#         "tail":"PowerDissipation"
#     },
#     {
#         "head":"PowerDissipation",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"55"
#     },
#     {
#         "head":"PowerDissipation",
#         "relation":"hasUnit",
#         "tail":"mW"
#     }
# ]
#  [
#   {
#     "head": "BGU7004-115",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasManufacturer",
#     "tail": "NXP Semiconductors"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "21"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "2.85"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1559"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1610"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "1.3"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "14.4"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "55"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasManufacturer",
#     "tail": "Infineon Technologies AG"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1550"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1615"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "0.55"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.6"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "60"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]

# %%
process_csv_to_triplets(InstruAmpData, project_id, location, instru_input_prompt, instru_ouput_prompt)
# Out:
#  [
#   {
#     "head": "INA101HP",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasPowerSupplyType",
#     "tail": "Dual"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasPinCount",
#     "tail": "14"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±20"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.02"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasManufacturer",
#     "tail": "Microchip Technology"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "86"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "7"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3.3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "86"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "INA122PA",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "100"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18|36"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±3|±5|±9|±12|±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "76"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.05"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  ```json
# [
#   {
#     "head": "PGA204AP",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasPowerSupplyType",
#     "tail": "Dual"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasPinCount",
#     "tail": "16"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "75"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.005"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
# ```
#  [
#   {
#     "head": "INA125UA",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasPinCount",
#     "tail": "16"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "72"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.05"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-55"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  ```JSON
# [
#   {
#     "head": "INA115BU",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasPowerSupplyType",
#     "tail": "Dual"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasPinCount",
#     "tail": "16"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "80"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
# ```
#  [
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasPowerSupplyType",
#     "tail": "Dual"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasPinCount",
#     "tail": "16"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasType",
#         "tail":"Single"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasManufacturer",
#         "tail":"Texas Instruments"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasPowerSupplyType",
#         "tail":"Single"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasPinCount",
#         "tail":"14"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"PSRR"
#     },
#     {
#         "head":"PSRR",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"112"
#     },
#     {
#         "head":"PSRR",
#         "relation":"hasUnit",
#         "tail":"dB"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"OperatingSupplyVoltage"
#     },
#     {
#         "head":"OperatingSupplyVoltage",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"5.5"
#     },
#     {
#         "head":"OperatingSupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"SupplyVoltage"
#     },
#     {
#         "head":"SupplyVoltage",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"5"
#     },
#     {
#         "head":"SupplyVoltage",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"7"
#     },
#     {
#         "head":"SupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"DualSupplyVoltage"
#     },
#     {
#         "head":"DualSupplyVoltage",
#         "relation":"hasNumericalValue",
#         "tail":"-"
#     },
#     {
#         "head":"DualSupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"SingleSupplyVoltage"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasNumericalValue",
#         "tail":"3|5"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"CMRR"
#     },
#     {
#         "head":"CMRR",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"116"
#     },
#     {
#         "head":"CMRR",
#         "relation":"hasUnit",
#         "tail":"dB"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"InputBiasCurrent"
#     },
#     {
#         "head":"InputBiasCurrent",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"-"
#     },
#     {
#         "head":"InputBiasCurrent",
#         "relation":"hasUnit",
#         "tail":"uA"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"OperatingTemperature"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"-40"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"125"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUnit",
#         "tail":"°C"
#     }
# ]
#  ```json
# [
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasManufacturer",
#     "tail": "Microchip Technology"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "104"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "7"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3.3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "94"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
# ```
#  ```json
# [
#   {
#     "head": "INA2128U",
#     "relation": "hasType",
#     "tail": "Dual"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasPowerSupplyType",
#     "tail": "Dual"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasPinCount",
#     "tail": "16"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "80"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.005"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
# ```

# %%
process_csv_to_triplets(OpAmpData, project_id, location, op_input_prompt, op_ouput_prompt)
# Out:
#  ```json
# [
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasType",
#     "tail": "Micropower Amplifier"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasManufacturer",
#     "tail": "Microchip Technology"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProcessTechnology",
#     "tail": "CMOS"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "80"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "9"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "75"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "OutputCurrent"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "0.155"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]
# ```
#  ```json
# [
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasType",
#     "tail": "Precision Amplifier"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasManufacturer",
#     "tail": "Microchip Technology"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProcessTechnology",
#     "tail": "CMOS"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasPinCount",
#     "tail": "14"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.0001"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "\u00b0C"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "OutputCurrent"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "0.01"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]
# ```
#  ```json
# [
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasType",
#     "tail": "Auto Zero Amplifier"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasManufacturer",
#     "tail": "Microchip Technology"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProcessTechnology",
#     "tail": "CMOS"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "120"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.005"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "OutputCurrent"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "2.0"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]
# ```
#  [
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasType",
#     "tail": "General Purpose Amplifier"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasManufacturer",
#     "tail": "Microchip Technology"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProcessTechnology",
#     "tail": "CMOS"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.4"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1e-06"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "OutputCurrent"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "10.0"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]
#  [
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasType",
#         "tail":"Chopper Amplifier"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasManufacturer",
#         "tail":"Microchip Technology"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProcessTechnology",
#         "tail":"CMOS"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasPowerSupplyType",
#         "tail":"Single"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasPinCount",
#         "tail":"8"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"PSRR"
#     },
#     {
#         "head":"PSRR",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"120"
#     },
#     {
#         "head":"PSRR",
#         "relation":"hasUnit",
#         "tail":"dB"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"OperatingSupplyVoltage"
#     },
#     {
#         "head":"OperatingSupplyVoltage",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"5.5"
#     },
#     {
#         "head":"OperatingSupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"SupplyVoltage"
#     },
#     {
#         "head":"SupplyVoltage",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"5.5"
#     },
#     {
#         "head":"SupplyVoltage",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"6"
#     },
#     {
#         "head":"SupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"SingleSupplyVoltage"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasNumericalValue",
#         "tail":"3|5"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"1.8"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"5.5"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"CMRR"
#     },
#     {
#         "head":"CMRR",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"120"
#     },
#     {
#         "head":"CMRR",
#         "relation":"hasUnit",
#         "tail":"dB"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"InputBiasCurrent"
#     },
#     {
#         "head":"InputBiasCurrent",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"-"
#     },
#     {
#         "head":"InputBiasCurrent",
#         "relation":"hasUnit",
#         "tail":"uA"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"OperatingTemperature"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"-40"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"125"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUnit",
#         "tail":"°C"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"OutputCurrent"
#     },
#     {
#         "head":"OutputCurrent",
#         "relation":"hasNumericalValue",
#         "tail":"30"
#     },
#     {
#         "head":"OutputCurrent",
#         "relation":"hasUnit",
#         "tail":"mA"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"GainBandwidthProduct"
#     },
#     {
#         "head":"GainBandwidthProduct",
#         "relation":"hasNumericalValue",
#         "tail":"0.3"
#     },
#     {
#         "head":"GainBandwidthProduct",
#         "relation":"hasUnit",
#         "tail":"MHz"
#     }
# ]
#  ```json
# [
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasType",
#     "tail": "High Speed Amplifier"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProcessTechnology",
#     "tail": "Bipolar"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "100"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "5|9"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "3.0"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12.0"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "72"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "2.6"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "OutputCurrent"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasNumericalValue",
#     "tail": "110"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "86.0"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]
# ```
#  ```json
# [
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasType",
#     "tail": "Low Offset Voltage Amplifier"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProcessTechnology",
#     "tail": "VIP10"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "72"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "12"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12.5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "5|9|12|15|18|24|28"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.07"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "OutputCurrent"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasNumericalValue",
#     "tail": "20"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "1.2"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]
# ```
#  ```json
# [
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasType",
#     "tail": "Wideband Amplifier"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProcessTechnology",
#     "tail": "LinCMOS"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "54"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "16"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "16"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "17"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.7"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "54"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1e-05"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]
# ```
#  [
#   {
#     "head": "OPA343UA",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProcessTechnology",
#     "tail": "CMOS"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasNumericalValue",
#     "tail": "87.96"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "5|9|12|15"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.0001"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "OutputCurrent"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "0.71"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]

# %%
process_csv_to_triplets(VideoAmpData, project_id, location, video_input_prompt, video_ouput_prompt)
# Out:
#  [
#   {
#     "head": "LMH6714MF-NOPB",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "LMH6714MF-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LMH6714MF-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "LMH6714MF-NOPB",
#     "relation": "hasPinCount",
#     "tail": "5"
#   },
#   {
#     "head": "LMH6714MF-NOPB",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±5"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "±4"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±6.25"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6714MF-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "9|12"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12.6"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6714MF-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "LM6172IN-NOPB",
#     "relation": "hasType",
#     "tail": "Dual"
#   },
#   {
#     "head": "LM6172IN-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LM6172IN-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Dual"
#   },
#   {
#     "head": "LM6172IN-NOPB",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "LM6172IN-NOPB",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±5|±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "±2.75"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LM6172IN-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LM6172IN-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "LMH6720MF-NOPB",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "LMH6720MF-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LMH6720MF-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "LMH6720MF-NOPB",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "LMH6720MF-NOPB",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±5"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "±4"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±6.25"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6720MF-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "9|12"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6720MF-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "LMH6739MQ-NOPB",
#     "relation": "hasType",
#     "tail": "Triple"
#   },
#   {
#     "head": "LMH6739MQ-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LMH6739MQ-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "LMH6739MQ-NOPB",
#     "relation": "hasPinCount",
#     "tail": "16"
#   },
#   {
#     "head": "LMH6739MQ-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "9"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6739MQ-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "LMH6738MQ-NOPB",
#     "relation": "hasType",
#     "tail": "Triple"
#   },
#   {
#     "head": "LMH6738MQ-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LMH6738MQ-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "LMH6738MQ-NOPB",
#     "relation": "hasPinCount",
#     "tail": "16"
#   },
#   {
#     "head": "LMH6738MQ-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "9"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6738MQ-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "AD812ARZ",
#     "relation": "hasType",
#     "tail": "Dual"
#   },
#   {
#     "head": "AD812ARZ",
#     "relation": "hasManufacturer",
#     "tail": "Analog Devices"
#   },
#   {
#     "head": "AD812ARZ",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "AD812ARZ",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "AD812ARZ",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±3|±5|±12|±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "±1.2"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "AD812ARZ",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5|9|12|15|18|24|28"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.4"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "36"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "AD812ARZ",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "LMH6722MA-NOPB",
#     "relation": "hasType",
#     "tail": "Quad"
#   },
#   {
#     "head": "LMH6722MA-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LMH6722MA-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "LMH6722MA-NOPB",
#     "relation": "hasPinCount",
#     "tail": "14"
#   },
#   {
#     "head": "LMH6722MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±5"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "±4"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±6.25"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6722MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "9|12"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6722MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "THS7360IPW",
#     "relation": "hasType",
#     "tail": "Hex"
#   },
#   {
#     "head": "THS7360IPW",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "THS7360IPW",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "THS7360IPW",
#     "relation": "hasPinCount",
#     "tail": "20"
#   },
#   {
#     "head": "THS7360IPW",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.7"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "THS7360IPW",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "THS7374IPW",
#     "relation": "hasType",
#     "tail": "Quad"
#   },
#   {
#     "head": "THS7374IPW",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "THS7374IPW",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "THS7374IPW",
#     "relation": "hasPinCount",
#     "tail": "14"
#   },
#   {
#     "head": "THS7374IPW",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "THS7374IPW",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "THS7360IPWR",
#     "relation": "hasType",
#     "tail": "Hex"
#   },
#   {
#     "head": "THS7360IPWR",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "THS7360IPWR",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "THS7360IPWR",
#     "relation": "hasPinCount",
#     "tail": "20"
#   },
#   {
#     "head": "THS7360IPWR",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.7"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "THS7360IPWR",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]

# %% [markdown]
# # Populating OWL File With Extracted Triplets

# %% [markdown]
# ### Importing OWL File Using owlready2

# %%
from owlready2 import *
filepath = "./../OntoFiles/AmpKB.rdf"
onto = get_ontology(filepath)
onto.load()
# Out:
# get_ontology("http://w3id.org/amplifiers#")

# %% [markdown]
# ### 1. Creating Amplifier's Individuals In OWL File Using JSON Triplets

# %% [markdown]
# #### Instrumental Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/InstruAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Access the data as a Python dictionary
for array in data:
    if array[0]["tail"] == "Single":
            SingleInstrumentalAmplifier = onto.SingleInstrumentalAmplifier
            array[0]["head"] = SingleInstrumentalAmplifier(array[0]["head"])        
    else:
        DualInstrumentalAmplifier = onto.DualInstrumentalAmplifier
        array[0]["head"] = DualInstrumentalAmplifier(array[0]["head"])

# %% [markdown]
# #### Audio Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/AudioAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Access the data as a Python dictionary
for array in data:
    if array[0]["tail"] == "Class-AB":
        ClassAB = onto.ClassAB
        array[0]["head"] = ClassAB(array[0]["head"])        
    elif array[0]["tail"] == "Class-D":
        ClassD = onto.ClassD
        array[0]["head"] = ClassD(array[0]["head"])
    else:
        ClassG = onto.ClassG
        array[0]["head"] = ClassG(array[0]["head"])

# %% [markdown]
# #### GPS Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/GPSAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Access the data as a Python dictionary
for array in data:
    if array[0]["tail"] == "Low Noise Amplifier":
            LowNoiseGPSAmplifier = onto.LowNoiseGPSAmplifier
            array[0]["head"] = LowNoiseGPSAmplifier(array[0]["head"])

# %% [markdown]
# #### Operational Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/OpAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

for array in data:
    if array[0]["tail"] == "Micropower Amplifier":
        MicropowerOperationalAmplifier = onto.MicropowerOperationalAmplifier
        array[0]["head"] = MicropowerOperationalAmplifier(array[0]["head"])        
    elif array[0]["tail"] == "Precision Amplifier":
        PrecisionOperationalAmplifier = onto.PrecisionOperationalAmplifier
        array[0]["head"] = PrecisionOperationalAmplifier(array[0]["head"])
    elif array[0]["tail"] == "Auto Zero Amplifier":
        AutoZeroOperationalAmplifier = onto.AutoZeroOperationalAmplifier
        array[0]["head"] = AutoZeroOperationalAmplifier(array[0]["head"])
    elif array[0]["tail"] == "Low Power Amplifier":
        LowPowerOperationalAmplifier = onto.LowPowerOperationalAmplifier
        array[0]["head"] = LowPowerOperationalAmplifier(array[0]["head"])
    elif array[0]["tail"] == "General Purpose Amplifier":
        GeneralPurposeOperationalAmplifier = onto.GeneralPurposeOperationalAmplifier
        array[0]["head"] = GeneralPurposeOperationalAmplifier(array[0]["head"])
    elif array[0]["tail"] == "Chopper Amplifier":
        ChopperOperationalAmplifier = onto.ChopperOperationalAmplifier
        array[0]["head"] = ChopperOperationalAmplifier(array[0]["head"])
    elif array[0]["tail"] == "High Speed Amplifier":
        HighSpeedOperationalAmplifier = onto.HighSpeedOperationalAmplifier
        array[0]["head"] = HighSpeedOperationalAmplifier(array[0]["head"])
    elif array[0]["tail"] == "Low Offset Voltage Amplifier":
        LowOffsetVoltageOperationalAmplifier = onto.LowOffsetVoltageOperationalAmplifier
        array[0]["head"] = LowOffsetVoltageOperationalAmplifier(array[0]["head"])
    elif array[0]["tail"] == "Wideband Amplifier":
        WidebandOperationalAmplifier = onto.WidebandOperationalAmplifier
        array[0]["head"] = WidebandOperationalAmplifier(array[0]["head"])
    else:
        LowNoiseOperationalAmplifier = onto.LowNoiseOperationalAmplifier 
        array[0]["head"] = LowNoiseOperationalAmplifier(array[0]["head"])

# %% [markdown]
# #### Video Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/VideoAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

for array in data:
    if array[0]["tail"] == "Single":
        SingleVideoAmplifier = onto.SingleVideoAmplifier
        array[0]["head"] = SingleVideoAmplifier(array[0]["head"])        
    elif array[0]["tail"] == "Dual":
        DualVideoAmplifier = onto.DualVideoAmplifier
        array[0]["head"] = DualVideoAmplifier(array[0]["head"])
    elif array[0]["tail"] == "Hex":
        HexVideoAmplifier = onto.HexVideoAmplifier
        array[0]["head"] = HexVideoAmplifier(array[0]["head"])
    elif array[0]["tail"] == "Triple":
        TripleVideoAmplifier = onto.TripleVideoAmplifier
        array[0]["head"] = TripleVideoAmplifier(array[0]["head"])
    else:
        QuadVideoAmplifier = onto.QuadVideoAmplifier
        array[0]["head"] = QuadVideoAmplifier(array[0]["head"])

# %% [markdown]
# ### 2. Creating Individuals For Electrical Charaterstics In OWL File Using JSON Triplets

# %% [markdown]
# #### GPS Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/GPSAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for i in range(1,11):
            if obj["relation"] == "hasProperty" and obj["tail"] == "Gain":
                Gain = onto.Gain
                gain_instance = "GPSGain"+str(i)
                gain_instance = Gain(gain_instance)
                gain_instance.
            if obj["relation"] == "hasProperty" and obj["tail"] == "SingleSupplyVoltage":
                SingleSupplyVoltage = onto.SingleSupplyVoltage
                SingleSupplyVoltage_instance = "GPSSV"+str(i)
                SingleSupplyVoltage_instance = SingleSupplyVoltage(SingleSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingFrequency":
                OperatingFrequency = onto.OperatingFrequency
                OperatingFrequency_instance = "GPSOF"+str(i)
                OperatingFrequency_instance = OperatingFrequency(OperatingFrequency_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "NoiseFigure":
                NoiseFigure = onto.NoiseFigure
                NoiseFigure_instance = "GPSNF"+str(i)
                NoiseFigure_instance = NoiseFigure(NoiseFigure_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingTemperature":
                OperatingTemperature = onto.OperatingTemperature
                OperatingTemperature_instance = "GPSOT"+str(i)
                OperatingTemperature_instance = OperatingTemperature(OperatingTemperature_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "SupplyCurrent":
                SupplyCurrent = onto.SupplyCurrent
                SupplyCurrent_instance = "GPSSC"+str(i)
                SupplyCurrent_instance = SupplyCurrent(SupplyCurrent_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "PowerDissipation":
                PowerDissipation = onto.PowerDissipation
                PowerDissipation_instance = "GPSPD"+str(i)
                PowerDissipation_instance = PowerDissipation(PowerDissipation_instance)

# %% [markdown]
# #### Audio Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/AudioAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

count = 0
# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for i in range(1,11):
            if obj["relation"] == "hasProperty" and obj["tail"] == "SingleSupplyVoltage":
                SingleSupplyVoltage = onto.SingleSupplyVoltage
                SingleSupplyVoltage_instance = "AUDIOSV"+str(i)
                SingleSupplyVoltage_instance = SingleSupplyVoltage(SingleSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingTemperature":
                OperatingTemperature = onto.OperatingTemperature
                OperatingTemperature_instance = "AUDIOOT"+str(i)
                OperatingTemperature_instance = OperatingTemperature(OperatingTemperature_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "PowerDissipation":
                PowerDissipation = onto.PowerDissipation
                PowerDissipation_instance = "AUDIOPD"+str(i)
                PowerDissipation_instance = PowerDissipation(PowerDissipation_instance)

# %% [markdown]
# #### Instrumental Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/InstruAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for i in range(1,11):
            if obj["relation"] == "hasProperty" and obj["tail"] == "PSRR":
                PSRR = onto.PSRR
                PSRR_instance = "INSTRUPSRR"+str(i)
                PSRR_instance = PSRR(PSRR_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingSupplyVoltage":
                OperatingSupplyVoltage = onto.OperatingSupplyVoltage
                OperatingSupplyVoltage_instance = "INSTRUOSV"+str(i)
                OperatingSupplyVoltage_instance = OperatingSupplyVoltage(OperatingSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "SupplyVoltage":
                SupplyVoltage = onto.SupplyVoltage
                SupplyVoltage_instance = "INSTRUSV"+str(i)
                SupplyVoltage_instance = SupplyVoltage(SupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "DualSupplyVoltage":
                DualSupplyVoltage = onto.DualSupplyVoltage
                DualSupplyVoltage_instance = "INSTRUDSV"+str(i)
                DualSupplyVoltage_instance = DualSupplyVoltage(DualSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "SingleSupplyVoltage":
                SingleSupplyVoltage = onto.SingleSupplyVoltage
                SingleSupplyVoltage_instance = "INSTRUSSV"+str(i)
                SingleSupplyVoltage_instance = SingleSupplyVoltage(SingleSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "CMRR":
                CMRR = onto.CMRR
                CMRR_instance = "INSTRUCMRR"+str(i)
                CMRR_instance = CMRR(CMRR_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "InputBiasCurrent":
                InputBiasCurrent = onto.InputBiasCurrent
                InputBiasCurrent_instance = "INSTRUIBC"+str(i)
                InputBiasCurrent_instance = InputBiasCurrent(InputBiasCurrent_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingTemperature":
                OperatingTemperature = onto.OperatingTemperature
                OperatingTemperature_instance = "INSTRUOT"+str(i)
                OperatingTemperature_instance = OperatingTemperature(OperatingTemperature_instance)

# %% [markdown]
# #### Operational Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/OpAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for i in range(1,11):
            if obj["relation"] == "hasProperty" and obj["tail"] == "PSRR":
                PSRR = onto.PSRR
                PSRR_instance = "OPPSRR"+str(i)
                PSRR_instance = PSRR(PSRR_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingSupplyVoltage":
                OperatingSupplyVoltage = onto.OperatingSupplyVoltage
                OperatingSupplyVoltage_instance = "OPOSV"+str(i)
                OperatingSupplyVoltage_instance = OperatingSupplyVoltage(OperatingSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "SupplyVoltage":
                SupplyVoltage = onto.SupplyVoltage
                SupplyVoltage_instance = "OPSV"+str(i)
                SupplyVoltage_instance = SupplyVoltage(SupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "SingleSupplyVoltage":
                SingleSupplyVoltage = onto.SingleSupplyVoltage
                SingleSupplyVoltage_instance = "OPSSV"+str(i)
                SingleSupplyVoltage_instance = SingleSupplyVoltage(SingleSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "CMRR":
                CMRR = onto.CMRR
                CMRR_instance = "OPCMRR"+str(i)
                CMRR_instance = CMRR(CMRR_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "InputBiasCurrent":
                InputBiasCurrent = onto.InputBiasCurrent
                InputBiasCurrent_instance = "OPIBC"+str(i)
                InputBiasCurrent_instance = InputBiasCurrent(InputBiasCurrent_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingTemperature":
                OperatingTemperature = onto.OperatingTemperature
                OperatingTemperature_instance = "OPOT"+str(i)
                OperatingTemperature_instance = OperatingTemperature(OperatingTemperature_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OutputCurrent":
                OutputCurrent = onto.OutputCurrent
                OutputCurrent_instance = "OPOC"+str(i)
                OutputCurrent_instance = OutputCurrent(OutputCurrent_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "GainBandwidthProduct":
                GainBandwidthProduct = onto.GainBandwidthProduct
                GainBandwidthProduct_instance = "OPGBP"+str(i)
                GainBandwidthProduct_instance = GainBandwidthProduct(GainBandwidthProduct_instance)

# %% [markdown]
# #### Video Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/VideoAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

count = 0
# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for i in range(1,11):
            if obj["relation"] == "hasProperty" and obj["tail"] == "DualSupplyVoltage":
                DualSupplyVoltage = onto.DualSupplyVoltage
                DualSupplyVoltage_instance = "VIDEODSV"+str(i)
                DualSupplyVoltage_instance = DualSupplyVoltage(DualSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "SingleSupplyVoltage":
                SingleSupplyVoltage = onto.SingleSupplyVoltage
                SingleSupplyVoltage_instance = "VIDEOSSV"+str(i)
                SingleSupplyVoltage_instance = SingleSupplyVoltage(SingleSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingTemperature":
                OperatingTemperature = onto.OperatingTemperature
                OperatingTemperature_instance = "VIDEOOT"+str(i)
                OperatingTemperature_instance = OperatingTemperature(OperatingTemperature_instance)

# %% [markdown]
# ### 3. Assigning Data Properties To Amplifier Individuals

# %% [markdown]
# #### Video Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/VideoAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)
    
instances = list(onto.VideoAmplifier.instances())

count = 0
# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for instance in instances:
            if instance.name == obj["head"]:
                if obj["relation"] == "hasManufacturer":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasManufacturer.append(obj["tail"])
                if obj["relation"] == "hasPowerSupplyType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPowerSupplyType.append(obj["tail"])
                if obj["relation"] == "hasPinCount":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPinCount.append(obj["tail"])
# Out:
# Assigning: LMH6714MF-NOPB hasManufacturer Texas Instruments
# Assigning: LMH6714MF-NOPB hasPowerSupplyType Single|Dual
# Assigning: LMH6714MF-NOPB hasPinCount 5
# Assigning: LM6172IN-NOPB hasManufacturer Texas Instruments
# Assigning: LM6172IN-NOPB hasPowerSupplyType Dual
# Assigning: LM6172IN-NOPB hasPinCount 8
# Assigning: LMH6720MF-NOPB hasManufacturer Texas Instruments
# Assigning: LMH6720MF-NOPB hasPowerSupplyType Single|Dual
# Assigning: LMH6720MF-NOPB hasPinCount 6
# Assigning: LMH6739MQ-NOPB hasManufacturer Texas Instruments
# Assigning: LMH6739MQ-NOPB hasPowerSupplyType Single
# Assigning: LMH6739MQ-NOPB hasPinCount 16
# Assigning: LMH6738MQ-NOPB hasManufacturer Texas Instruments
# Assigning: LMH6738MQ-NOPB hasPowerSupplyType Single
# Assigning: LMH6738MQ-NOPB hasPinCount 16
# Assigning: AD812ARZ hasManufacturer Analog Devices
# Assigning: AD812ARZ hasPowerSupplyType Single|Dual
# Assigning: AD812ARZ hasPinCount 8
# Assigning: LMH6722MA-NOPB hasManufacturer Texas Instruments
# Assigning: LMH6722MA-NOPB hasPowerSupplyType Single|Dual
# Assigning: LMH6722MA-NOPB hasPinCount 14
# Assigning: THS7360IPW hasManufacturer Texas Instruments
# Assigning: THS7360IPW hasPowerSupplyType Single
# Assigning: THS7360IPW hasPinCount 20
# Assigning: THS7374IPW hasManufacturer Texas Instruments
# Assigning: THS7374IPW hasPowerSupplyType Single
# Assigning: THS7374IPW hasPinCount 14
# Assigning: THS7360IPWR hasManufacturer Texas Instruments
# Assigning: THS7360IPWR hasPowerSupplyType Single
# Assigning: THS7360IPWR hasPinCount 20

# %% [markdown]
# #### Audio Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/AudioAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)
    
instances = list(onto.AudioAmplifier.instances())

count = 0
# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for instance in instances:
            if instance.name == obj["head"]:
                if obj["relation"] == "hasManufacturer":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasManufacturer.append(obj["tail"])
                if obj["relation"] == "hasPowerSupplyType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPowerSupplyType.append(obj["tail"])
                if obj["relation"] == "hasInputSignalType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasInputSignalType.append(obj["tail"])
                if obj["relation"] == "hasOutputSignalType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasOutputSignalType.append(obj["tail"])
                if obj["relation"] == "hasOutputType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasOutputType.append(obj["tail"])
                if obj["relation"] == "hasPinCount":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPinCount.append(obj["tail"])
# Out:
# Assigning: LM4861M-NOPB hasManufacturer Texas Instruments
# Assigning: LM4861M-NOPB hasPowerSupplyType Single
# Assigning: LM4861M-NOPB hasInputSignalType Single
# Assigning: LM4861M-NOPB hasOutputSignalType Differential
# Assigning: LM4861M-NOPB hasOutputType 1-Channel Mono
# Assigning: LM4861M-NOPB hasPinCount 8
# Assigning: LM4889MA-NOPB hasManufacturer Texas Instruments
# Assigning: LM4889MA-NOPB hasPowerSupplyType Single
# Assigning: LM4889MA-NOPB hasInputSignalType Differential|Single
# Assigning: LM4889MA-NOPB hasOutputSignalType Differential
# Assigning: LM4889MA-NOPB hasOutputType 1-Channel Mono
# Assigning: LM4889MA-NOPB hasPinCount 8
# Assigning: TPA3125D2N hasManufacturer Texas Instruments
# Assigning: TPA3125D2N hasPowerSupplyType Single
# Assigning: TPA3125D2N hasInputSignalType Single
# Assigning: TPA3125D2N hasOutputSignalType Differential|Single
# Assigning: TPA3125D2N hasOutputType 1-Channel Mono|2-Channel Stereo
# Assigning: TPA3125D2N hasPinCount 20
# Assigning: BD28623MUV-E2 hasManufacturer Rohm Semiconductor
# Assigning: BD28623MUV-E2 hasPowerSupplyType Single
# Assigning: BD28623MUV-E2 hasInputSignalType Single
# Assigning: BD28623MUV-E2 hasOutputSignalType Differential
# Assigning: BD28623MUV-E2 hasOutputType 2-Channel Stereo
# Assigning: BD28623MUV-E2 hasPinCount 24
# Assigning: OPA1611AID hasManufacturer Texas Instruments
# Assigning: OPA1611AID hasPowerSupplyType Single|Dual
# Assigning: OPA1611AID hasInputSignalType Differential
# Assigning: OPA1611AID hasOutputSignalType Single
# Assigning: OPA1611AID hasOutputType 1-Channel Mono
# Assigning: OPA1611AID hasPinCount 8
# Assigning: PAM8945PJR hasManufacturer Texas Instruments
# Assigning: PAM8945PJR hasPowerSupplyType Single
# Assigning: PAM8945PJR hasInputSignalType Differential
# Assigning: PAM8945PJR hasOutputSignalType Differential
# Assigning: PAM8945PJR hasOutputType 1-Channel Mono
# Assigning: PAM8945PJR hasPinCount 12
# Assigning: LM4862M-NOPB hasManufacturer Texas Instruments
# Assigning: LM4862M-NOPB hasPowerSupplyType Single
# Assigning: LM4862M-NOPB hasInputSignalType Single
# Assigning: LM4862M-NOPB hasOutputSignalType Differential
# Assigning: LM4862M-NOPB hasOutputType 1-Channel Mono
# Assigning: LM4862M-NOPB hasPinCount 8
# Assigning: LM386MMX-1-NOPB hasManufacturer Texas Instruments
# Assigning: LM386MMX-1-NOPB hasPowerSupplyType Single
# Assigning: LM386MMX-1-NOPB hasInputSignalType Differential
# Assigning: LM386MMX-1-NOPB hasOutputSignalType Single
# Assigning: LM386MMX-1-NOPB hasOutputType 1-Channel Mono
# Assigning: LM386MMX-1-NOPB hasPinCount 8
# Assigning: BM28723AMUV-E2 hasManufacturer Texas Instruments
# Assigning: BM28723AMUV-E2 hasPowerSupplyType Triple
# Assigning: BM28723AMUV-E2 hasInputSignalType Single
# Assigning: BM28723AMUV-E2 hasOutputSignalType Differential
# Assigning: BM28723AMUV-E2 hasOutputType 2-Channel Stereo
# Assigning: BM28723AMUV-E2 hasPinCount 32
# Assigning: PAM8610TR hasManufacturer Texas Instruments
# Assigning: PAM8610TR hasPowerSupplyType Single
# Assigning: PAM8610TR hasInputSignalType Differential
# Assigning: PAM8610TR hasOutputSignalType Differential
# Assigning: PAM8610TR hasOutputType 2-Channel Stereo
# Assigning: PAM8610TR hasPinCount 40

# %% [markdown]
# #### GPS Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/GPSAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)
    
instances = list(onto.GPSAmplifier.instances())

count = 0
# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for instance in instances:
            if instance.name == obj["head"]:
                if obj["relation"] == "hasManufacturer":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasManufacturer.append(obj["tail"])
                if obj["relation"] == "hasProcessTechnology":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasProcessTechnology.append(obj["tail"])
                if obj["relation"] == "hasPowerSupplyType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPowerSupplyType.append(obj["tail"])
                if obj["relation"] == "hasPinCount":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPinCount.append(obj["tail"])
# Out:
# Assigning: BGA725L6E6327FTSA1 hasManufacturer Infineon Technologies AG
# Assigning: BGA725L6E6327FTSA1 hasProcessTechnology SiGe
# Assigning: BGA725L6E6327FTSA1 hasPowerSupplyType Single
# Assigning: BGA725L6E6327FTSA1 hasPinCount 6
# Assigning: BGU7005-115 hasManufacturer NXP Semiconductors
# Assigning: BGU7005-115 hasProcessTechnology SiGe
# Assigning: BGU7005-115 hasPowerSupplyType Single
# Assigning: BGU7005-115 hasPinCount 6
# Assigning: BGA123L4E6327XTSA1 hasManufacturer Infineon Technologies AG
# Assigning: BGA123L4E6327XTSA1 hasProcessTechnology -
# Assigning: BGA123L4E6327XTSA1 hasPowerSupplyType Single
# Assigning: BGA123L4E6327XTSA1 hasPinCount 4
# Assigning: BGA715N7E6327XTSA2 hasManufacturer Infineon Technologies AG
# Assigning: BGA715N7E6327XTSA2 hasProcessTechnology SiGe
# Assigning: BGA715N7E6327XTSA2 hasPowerSupplyType Single
# Assigning: BGA715N7E6327XTSA2 hasPinCount 6
# Assigning: BGU8103X hasManufacturer NXP Semiconductors
# Assigning: BGU8103X hasProcessTechnology SiGe
# Assigning: BGU8103X hasPowerSupplyType Single
# Assigning: BGU8103X hasPinCount 6
# Assigning: BGU8019X hasManufacturer NXP Semiconductors
# Assigning: BGU8019X hasProcessTechnology SiGe
# Assigning: BGU8019X hasPowerSupplyType Single
# Assigning: BGU8019X hasPinCount 6
# Assigning: BGU7007-115 hasManufacturer NXP Semiconductors
# Assigning: BGU7007-115 hasProcessTechnology SiGe
# Assigning: BGU7007-115 hasPowerSupplyType Single
# Assigning: BGU7007-115 hasPinCount 6
# Assigning: BGU7008-115 hasManufacturer NXP Semiconductors
# Assigning: BGU7008-115 hasProcessTechnology SiGe
# Assigning: BGU7008-115 hasPowerSupplyType Single
# Assigning: BGU7008-115 hasPinCount 6
# Assigning: BGU7004-115 hasManufacturer NXP Semiconductors
# Assigning: BGU7004-115 hasProcessTechnology SiGe
# Assigning: BGU7004-115 hasPowerSupplyType Single
# Assigning: BGU7004-115 hasPinCount 6
# Assigning: BGA524N6E6327XTSA1 hasManufacturer Infineon Technologies AG
# Assigning: BGA524N6E6327XTSA1 hasProcessTechnology SiGe
# Assigning: BGA524N6E6327XTSA1 hasPowerSupplyType Single
# Assigning: BGA524N6E6327XTSA1 hasPinCount 6

# %% [markdown]
# #### Instrumental Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/InstruAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)
    
instances = list(onto.InstrumentalAmplifier.instances())

count = 0
# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for instance in instances:
            if instance.name == obj["head"]:
                if obj["relation"] == "hasManufacturer":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasManufacturer.append(obj["tail"])
                if obj["relation"] == "hasPowerSupplyType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPowerSupplyType.append(obj["tail"])
                if obj["relation"] == "hasPinCount":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPinCount.append(obj["tail"])
# Out:
# Assigning: INA101HP hasManufacturer Texas Instruments
# Assigning: INA101HP hasPowerSupplyType Dual
# Assigning: INA101HP hasPinCount 14
# Assigning: MCP6N11T-100E-MNY hasManufacturer Microchip Technology
# Assigning: MCP6N11T-100E-MNY hasPowerSupplyType Single
# Assigning: MCP6N11T-100E-MNY hasPinCount 8
# Assigning: INA122PA hasManufacturer Texas Instruments
# Assigning: INA122PA hasPowerSupplyType Single|Dual
# Assigning: INA122PA hasPinCount 8
# Assigning: PGA204AP hasManufacturer Texas Instruments
# Assigning: PGA204AP hasPowerSupplyType Dual
# Assigning: PGA204AP hasPinCount 16
# Assigning: INA125UA hasManufacturer Texas Instruments
# Assigning: INA125UA hasPowerSupplyType Single|Dual
# Assigning: INA125UA hasPinCount 16
# Assigning: INA115BU hasManufacturer Texas Instruments
# Assigning: INA115BU hasPowerSupplyType Dual
# Assigning: INA115BU hasPinCount 16
# Assigning: INA217AIDWT hasManufacturer Texas Instruments
# Assigning: INA217AIDWT hasPowerSupplyType Dual
# Assigning: INA217AIDWT hasPinCount 16
# Assigning: LMP8358MA-NOPB hasManufacturer Texas Instruments
# Assigning: LMP8358MA-NOPB hasPowerSupplyType Single
# Assigning: LMP8358MA-NOPB hasPinCount 14
# Assigning: MCP6N16-010E-MS hasManufacturer Microchip Technology
# Assigning: MCP6N16-010E-MS hasPowerSupplyType Single
# Assigning: MCP6N16-010E-MS hasPinCount 8
# Assigning: INA2128U hasManufacturer Texas Instruments
# Assigning: INA2128U hasPowerSupplyType Dual
# Assigning: INA2128U hasPinCount 16

# %% [markdown]
# #### Operational Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/OpAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)
    
instances = list(onto.OperationalAmplifier.instances())

count = 0
# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for instance in instances:
            if instance.name == obj["head"]:
                if obj["relation"] == "hasManufacturer":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasManufacturer.append(obj["tail"])
                if obj["relation"] == "hasProcessTechnology":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasProcessTechnology.append(obj["tail"])
                if obj["relation"] == "hasPowerSupplyType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPowerSupplyType.append(obj["tail"])
                if obj["relation"] == "hasPinCount":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPinCount.append(obj["tail"])
# Out:
# Assigning: MCP607-I-P hasManufacturer Microchip Technology
# Assigning: MCP607-I-P hasProcessTechnology CMOS
# Assigning: MCP607-I-P hasPowerSupplyType Single
# Assigning: MCP607-I-P hasPinCount 8
# Assigning: MCP6034-E-SL hasManufacturer Microchip Technology
# Assigning: MCP6034-E-SL hasProcessTechnology CMOS
# Assigning: MCP6034-E-SL hasPowerSupplyType Single
# Assigning: MCP6034-E-SL hasPinCount 14
# Assigning: MCP6V27-E-SN hasManufacturer Microchip Technology
# Assigning: MCP6V27-E-SN hasProcessTechnology CMOS
# Assigning: MCP6V27-E-SN hasPowerSupplyType Single
# Assigning: MCP6V27-E-SN hasPinCount 8
# Assigning: MCP6292-E-P hasManufacturer Microchip Technology
# Assigning: MCP6292-E-P hasProcessTechnology CMOS
# Assigning: MCP6292-E-P hasPowerSupplyType Single
# Assigning: MCP6292-E-P hasPinCount 8
# Assigning: MCP6V32-E-MS hasManufacturer Microchip Technology
# Assigning: MCP6V32-E-MS hasProcessTechnology CMOS
# Assigning: MCP6V32-E-MS hasPowerSupplyType Single
# Assigning: MCP6V32-E-MS hasPinCount 8
# Assigning: OPA625IDBVT hasManufacturer Texas Instruments
# Assigning: OPA625IDBVT hasProcessTechnology Bipolar
# Assigning: OPA625IDBVT hasPowerSupplyType Single|Dual
# Assigning: OPA625IDBVT hasPinCount 8
# Assigning: LMH6639MA-NOPB hasManufacturer Texas Instruments
# Assigning: LMH6639MA-NOPB hasProcessTechnology VIP10
# Assigning: LMH6639MA-NOPB hasPowerSupplyType Single|Dual
# Assigning: LMH6639MA-NOPB hasPinCount 8
# Assigning: TLC27M2CP hasManufacturer Texas Instruments
# Assigning: TLC27M2CP hasProcessTechnology LinCMOS
# Assigning: TLC27M2CP hasPowerSupplyType Single
# Assigning: TLC27M2CP hasPinCount 8
# Assigning: OPA343UA hasManufacturer Texas Instruments
# Assigning: OPA343UA hasProcessTechnology CMOS
# Assigning: OPA343UA hasPowerSupplyType Single|Dual
# Assigning: OPA343UA hasPinCount 8

# %% [markdown]
# ### 4. Assigning Data Properties To Amplifier Properties Classes

# %% [markdown]
# #### Video Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/VideoAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

dsv_video_list = []
for item in onto.DualSupplyVoltage.instances():
    if "VIDEO" in item.name:
        dsv_video_list.append(item)

ssv_video_list = []
for item in onto.SingleSupplyVoltage.instances():
    if "VIDEO" in item.name:
        ssv_video_list.append(item)
        
ot_video_list = []
for item in onto.OperatingTemperature.instances():
    if "VIDEO" in item.name:
        ot_video_list.append(item)
        

# Access the data as a Python dictionary
for item, json_data in zip(video_list, data):
    for obj in json_data:
        if obj["head"] == "DualSupplyVoltage":
            if obj["relation"] == "hasNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(ssv_video_list, data):
    for obj in json_data:
        if obj["head"] == "SingleSupplyVoltage":
            if obj["relation"] == "hasNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])

# Access the data as a Python dictionary
for item, json_data in zip(ot_video_list, data):
    for obj in json_data:
        if obj["head"] == "OperatingTemperature":
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
# Out:
# AmpKB.VIDEODSV1
# Assigned: DualSupplyVoltage hasNumericalValue 5
# Assigned: DualSupplyVoltage hasLowerBoundNumericalValue 4
# Assigned: DualSupplyVoltage hasUpperBoundNumericalValue 6.25
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.VIDEODSV10
# Assigned: DualSupplyVoltage hasNumericalValue 5|15
# Assigned: DualSupplyVoltage hasLowerBoundNumericalValue 2.75
# Assigned: DualSupplyVoltage hasUpperBoundNumericalValue 18
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.VIDEODSV2
# Assigned: DualSupplyVoltage hasNumericalValue 5
# Assigned: DualSupplyVoltage hasLowerBoundNumericalValue 4
# Assigned: DualSupplyVoltage hasUpperBoundNumericalValue 6.25
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.VIDEODSV3
# Assigned: DualSupplyVoltage hasNumericalValue -
# Assigned: DualSupplyVoltage hasLowerBoundNumericalValue -
# Assigned: DualSupplyVoltage hasUpperBoundNumericalValue -
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.VIDEODSV4
# Assigned: DualSupplyVoltage hasNumericalValue -
# Assigned: DualSupplyVoltage hasLowerBoundNumericalValue -
# Assigned: DualSupplyVoltage hasUpperBoundNumericalValue -
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.VIDEODSV5
# Assigned: DualSupplyVoltage hasNumericalValue 3|5|12|15
# Assigned: DualSupplyVoltage hasLowerBoundNumericalValue 1.2
# Assigned: DualSupplyVoltage hasUpperBoundNumericalValue 18
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.VIDEODSV6
# Assigned: DualSupplyVoltage hasNumericalValue 5
# Assigned: DualSupplyVoltage hasLowerBoundNumericalValue 4
# Assigned: DualSupplyVoltage hasUpperBoundNumericalValue 6.25
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.VIDEODSV7
# Assigned: DualSupplyVoltage hasNumericalValue -
# Assigned: DualSupplyVoltage hasLowerBoundNumericalValue -
# Assigned: DualSupplyVoltage hasUpperBoundNumericalValue -
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.VIDEODSV8
# Assigned: DualSupplyVoltage hasNumericalValue -
# Assigned: DualSupplyVoltage hasLowerBoundNumericalValue -
# Assigned: DualSupplyVoltage hasUpperBoundNumericalValue -
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.VIDEODSV9
# Assigned: DualSupplyVoltage hasNumericalValue -
# Assigned: DualSupplyVoltage hasLowerBoundNumericalValue -
# Assigned: DualSupplyVoltage hasUpperBoundNumericalValue -
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.VIDEOSSV1
# Assigned: SingleSupplyVoltage hasNumericalValue 9|12
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 8
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 12.6
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.VIDEOSSV10
# Assigned: SingleSupplyVoltage hasNumericalValue -
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue -
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue -
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.VIDEOSSV2
# Assigned: SingleSupplyVoltage hasNumericalValue 9|12
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 8
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 12.5
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.VIDEOSSV3
# Assigned: SingleSupplyVoltage hasNumericalValue 9
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 8
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 12
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.VIDEOSSV4
# Assigned: SingleSupplyVoltage hasNumericalValue 9
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 8
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 12
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.VIDEOSSV5
# Assigned: SingleSupplyVoltage hasNumericalValue 3|5|9|12|15|18|24|28
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 2.4
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 36
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.VIDEOSSV6
# Assigned: SingleSupplyVoltage hasNumericalValue 9|12
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 8
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 12.5
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.VIDEOSSV7
# Assigned: SingleSupplyVoltage hasNumericalValue 3
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 2.7
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 5
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.VIDEOSSV8
# Assigned: SingleSupplyVoltage hasNumericalValue 3
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.VIDEOSSV9
# Assigned: SingleSupplyVoltage hasNumericalValue 3
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 2.7
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 5
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.VIDEOOT1
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.VIDEOOT10
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.VIDEOOT2
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.VIDEOOT3
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.VIDEOOT4
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.VIDEOOT5
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.VIDEOOT6
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.VIDEOOT7
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.VIDEOOT8
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.VIDEOOT9
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C

# %% [markdown]
# #### Audio Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/AudioAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

pd_audio_list = []
for item in onto.PowerDissipation.instances():
    if "AUDIO" in item.name:
        pd_audio_list.append(item)

ssv_audio_list = []
for item in onto.SingleSupplyVoltage.instances():
    if "AUDIO" in item.name:
        ssv_audio_list.append(item)
        
ot_audio_list = []
for item in onto.OperatingTemperature.instances():
    if "AUDIO" in item.name:
        ot_audio_list.append(item)
        

# Access the data as a Python dictionary
for item, json_data in zip(pd_audio_list, data):
    for obj in json_data:
        if obj["head"] == "PowerDissipation":
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(ssv_audio_list, data):
    for obj in json_data:
        if obj["head"] == "SingleSupplyVoltage":
            if obj["relation"] == "hasNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])

# Access the data as a Python dictionary
for item, json_data in zip(ot_audio_list, data):
    for obj in json_data:
        if obj["head"] == "OperatingTemperature":
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
# Out:
# AmpKB.AUDIOPD1
# Assigned: PowerDissipation hasUpperBoundNumericalValue -
# Assigned: PowerDissipation hasUnit mW
# AmpKB.AUDIOPD10
# Assigned: PowerDissipation hasUpperBoundNumericalValue -
# Assigned: PowerDissipation hasUnit mW
# AmpKB.AUDIOPD2
# Assigned: PowerDissipation hasUpperBoundNumericalValue 1870
# Assigned: PowerDissipation hasUnit mW
# AmpKB.AUDIOPD3
# Assigned: PowerDissipation hasUpperBoundNumericalValue 3560
# Assigned: PowerDissipation hasUnit mW
# AmpKB.AUDIOPD4
# Assigned: PowerDissipation hasUpperBoundNumericalValue -
# Assigned: PowerDissipation hasUnit mW
# AmpKB.AUDIOPD5
# Assigned: PowerDissipation hasUpperBoundNumericalValue -
# Assigned: PowerDissipation hasUnit mW
# AmpKB.AUDIOPD6
# Assigned: PowerDissipation hasUpperBoundNumericalValue -
# Assigned: PowerDissipation hasUnit mW
# AmpKB.AUDIOPD7
# Assigned: PowerDissipation hasUpperBoundNumericalValue 595
# Assigned: PowerDissipation hasUnit mW
# AmpKB.AUDIOPD8
# Assigned: PowerDissipation hasUpperBoundNumericalValue -
# Assigned: PowerDissipation hasUnit mW
# AmpKB.AUDIOPD9
# Assigned: PowerDissipation hasUpperBoundNumericalValue -
# Assigned: PowerDissipation hasUnit mW
# AmpKB.AUDIOSV1
# Assigned: SingleSupplyVoltage hasNumericalValue 3|5
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 2
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 5.50
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.AUDIOSV10
# Assigned: SingleSupplyVoltage hasNumericalValue 3|5
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 2.2
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 5.5
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.AUDIOSV2
# Assigned: SingleSupplyVoltage hasNumericalValue 12|15|18|24
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 10
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 26
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.AUDIOSV3
# Assigned: SingleSupplyVoltage hasNumericalValue 9|12|15|18
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 8.5
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 24
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.AUDIOSV4
# Assigned: SingleSupplyVoltage hasNumericalValue 5|9|12|15|18|24|28
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 4.5
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 36
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.AUDIOSV5
# Assigned: SingleSupplyVoltage hasNumericalValue 3|5
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 2.8
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 5.2
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.AUDIOSV6
# Assigned: SingleSupplyVoltage hasNumericalValue 3|5
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 2.7
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 5.5
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.AUDIOSV7
# Assigned: SingleSupplyVoltage hasNumericalValue 5|9
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 4
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 12
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.AUDIOSV8
# Assigned: SingleSupplyVoltage hasNumericalValue -
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue -
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue -
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.AUDIOSV9
# Assigned: SingleSupplyVoltage hasNumericalValue 12
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 7
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 15
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.AUDIOOT1
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.AUDIOOT10
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.AUDIOOT2
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.AUDIOOT3
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -25
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.AUDIOOT4
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.AUDIOOT5
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.AUDIOOT6
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.AUDIOOT7
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 70
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.AUDIOOT8
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -25
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.AUDIOOT9
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -20
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C

# %% [markdown]
# #### GPS Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/GPSAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

pd_gps_list = []
for item in onto.PowerDissipation.instances():
    if "GPS" in item.name:
        pd_gps_list.append(item)

ssv_gps_list = []
for item in onto.SingleSupplyVoltage.instances():
    if "GPS" in item.name:
        ssv_gps_list.append(item)
        
ot_gps_list = []
for item in onto.OperatingTemperature.instances():
    if "GPS" in item.name:
        ot_gps_list.append(item)
        
gain_gps_list = []
for item in onto.Gain.instances():
    if "GPS" in item.name:
        gain_gps_list.append(item)

of_gps_list = []
for item in onto.OperatingFrequency.instances():
    if "GPS" in item.name:
        of_gps_list.append(item)

nf_gps_list = []
for item in onto.NoiseFigure.instances():
    if "GPS" in item.name:
        nf_gps_list.append(item)

sc_gps_list = []
for item in onto.SupplyCurrent.instances():
    if "GPS" in item.name:
        sc_gps_list.append(item)

# Access the data as a Python dictionary
for item, json_data in zip(pd_gps_list, data):
    for obj in json_data:
        if obj["head"] == "PowerDissipation":
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(ssv_gps_list, data):
    for obj in json_data:
        if obj["head"] == "SingleSupplyVoltage":
            if obj["relation"] == "hasNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])

# Access the data as a Python dictionary
for item, json_data in zip(ot_gps_list, data):
    for obj in json_data:
        if obj["head"] == "OperatingTemperature":
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(gain_gps_list, data):
    for obj in json_data:
        if obj["head"] == "Gain":
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(of_gps_list, data):
    for obj in json_data:
        if obj["head"] == "OperatingFrequency":
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])

# Access the data as a Python dictionary
for item, json_data in zip(nf_gps_list, data):
    for obj in json_data:
        if obj["head"] == "NoiseFigure":
            if obj["relation"] == "hasNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(sc_gps_list, data):
    for obj in json_data:
        if obj["head"] == "SupplyCurrent":
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
# Out:
# AmpKB.GPSPD1
# Assigned: PowerDissipation hasUpperBoundNumericalValue 72
# Assigned: PowerDissipation hasUnit mW
# AmpKB.GPSPD10
# Assigned: PowerDissipation hasUpperBoundNumericalValue 55
# Assigned: PowerDissipation hasUnit mW
# AmpKB.GPSPD2
# Assigned: PowerDissipation hasUpperBoundNumericalValue 40
# Assigned: PowerDissipation hasUnit mW
# AmpKB.GPSPD3
# Assigned: PowerDissipation hasUpperBoundNumericalValue 36
# Assigned: PowerDissipation hasUnit mW
# AmpKB.GPSPD4
# Assigned: PowerDissipation hasUpperBoundNumericalValue 55
# Assigned: PowerDissipation hasUnit mW
# AmpKB.GPSPD5
# Assigned: PowerDissipation hasUpperBoundNumericalValue 55
# Assigned: PowerDissipation hasUnit mW
# AmpKB.GPSPD6
# Assigned: PowerDissipation hasUpperBoundNumericalValue 55
# Assigned: PowerDissipation hasUnit mW
# AmpKB.GPSPD7
# Assigned: PowerDissipation hasUpperBoundNumericalValue 55
# Assigned: PowerDissipation hasUnit mW
# AmpKB.GPSPD8
# Assigned: PowerDissipation hasUpperBoundNumericalValue 55
# Assigned: PowerDissipation hasUnit mW
# AmpKB.GPSPD9
# Assigned: PowerDissipation hasUpperBoundNumericalValue 60
# Assigned: PowerDissipation hasUnit mW
# AmpKB.GPSSV1
# Assigned: SingleSupplyVoltage hasNumericalValue 3
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 1.5
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 3.6
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.GPSSV10
# Assigned: SingleSupplyVoltage hasNumericalValue 1.8
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 1.5
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 3.1
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.GPSSV2
# Assigned: SingleSupplyVoltage hasNumericalValue 1.8
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 1.1
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 3.6
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.GPSSV3
# Assigned: SingleSupplyVoltage hasNumericalValue 1.8
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 1.5
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 3.6
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.GPSSV4
# Assigned: SingleSupplyVoltage hasNumericalValue 3
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 1.5
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 3.1
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.GPSSV5
# Assigned: SingleSupplyVoltage hasNumericalValue 3
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 1.5
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 3.1
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.GPSSV6
# Assigned: SingleSupplyVoltage hasNumericalValue 3
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 1.5
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 3.1
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.GPSSV7
# Assigned: SingleSupplyVoltage hasNumericalValue 3
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 1.5
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 2.85
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.GPSSV8
# Assigned: SingleSupplyVoltage hasNumericalValue 3
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 1.5
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 2.85
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.GPSSV9
# Assigned: SingleSupplyVoltage hasNumericalValue 3
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 1.5
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 3.3
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.GPSOT1
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.GPSOT10
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.GPSOT2
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.GPSOT3
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.GPSOT4
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.GPSOT5
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.GPSOT6
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.GPSOT7
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 125
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.GPSOT8
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 125
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.GPSOT9
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.GPSGain1
# Assigned: Gain hasUpperBoundNumericalValue -
# Assigned: Gain hasUnit dB
# AmpKB.GPSGain10
# Assigned: Gain hasUpperBoundNumericalValue 20
# Assigned: Gain hasUnit dB
# AmpKB.GPSGain2
# Assigned: Gain hasUpperBoundNumericalValue 19.9
# Assigned: Gain hasUnit dB
# AmpKB.GPSGain3
# Assigned: Gain hasUpperBoundNumericalValue 20
# Assigned: Gain hasUnit dB
# AmpKB.GPSGain4
# Assigned: Gain hasUpperBoundNumericalValue 18.5
# Assigned: Gain hasUnit dB
# AmpKB.GPSGain5
# Assigned: Gain hasUpperBoundNumericalValue 20.5
# Assigned: Gain hasUnit dB
# AmpKB.GPSGain6
# Assigned: Gain hasUpperBoundNumericalValue 21.5
# Assigned: Gain hasUnit dB
# AmpKB.GPSGain7
# Assigned: Gain hasUpperBoundNumericalValue 21.5
# Assigned: Gain hasUnit dB
# AmpKB.GPSGain8
# Assigned: Gain hasUpperBoundNumericalValue 21
# Assigned: Gain hasUnit dB
# AmpKB.GPSGain9
# Assigned: Gain hasUpperBoundNumericalValue -
# Assigned: Gain hasUnit dB
# AmpKB.GPSOF1
# Assigned: OperatingFrequency hasLowerBoundNumericalValue 1550
# Assigned: OperatingFrequency hasUpperBoundNumericalValue 1615
# Assigned: OperatingFrequency hasUnit MHz
# AmpKB.GPSOF10
# Assigned: OperatingFrequency hasLowerBoundNumericalValue -
# Assigned: OperatingFrequency hasUpperBoundNumericalValue 1850
# Assigned: OperatingFrequency hasUnit MHz
# AmpKB.GPSOF2
# Assigned: OperatingFrequency hasLowerBoundNumericalValue 1550
# Assigned: OperatingFrequency hasUpperBoundNumericalValue 1615
# Assigned: OperatingFrequency hasUnit MHz
# AmpKB.GPSOF3
# Assigned: OperatingFrequency hasLowerBoundNumericalValue 1550
# Assigned: OperatingFrequency hasUpperBoundNumericalValue 1615
# Assigned: OperatingFrequency hasUnit MHz
# AmpKB.GPSOF4
# Assigned: OperatingFrequency hasLowerBoundNumericalValue 1559
# Assigned: OperatingFrequency hasUpperBoundNumericalValue 1610
# Assigned: OperatingFrequency hasUnit MHz
# AmpKB.GPSOF5
# Assigned: OperatingFrequency hasLowerBoundNumericalValue 1559
# Assigned: OperatingFrequency hasUpperBoundNumericalValue 1610
# Assigned: OperatingFrequency hasUnit MHz
# AmpKB.GPSOF6
# Assigned: OperatingFrequency hasLowerBoundNumericalValue 1559
# Assigned: OperatingFrequency hasUpperBoundNumericalValue 1610
# Assigned: OperatingFrequency hasUnit MHz
# AmpKB.GPSOF7
# Assigned: OperatingFrequency hasLowerBoundNumericalValue 1559
# Assigned: OperatingFrequency hasUpperBoundNumericalValue 1610
# Assigned: OperatingFrequency hasUnit MHz
# AmpKB.GPSOF8
# Assigned: OperatingFrequency hasLowerBoundNumericalValue 1559
# Assigned: OperatingFrequency hasUpperBoundNumericalValue 1610
# Assigned: OperatingFrequency hasUnit MHz
# AmpKB.GPSOF9
# Assigned: OperatingFrequency hasLowerBoundNumericalValue 1550
# Assigned: OperatingFrequency hasUpperBoundNumericalValue 1615
# Assigned: OperatingFrequency hasUnit MHz
# AmpKB.GPSNF1
# Assigned: NoiseFigure hasNumericalValue 0.65
# Assigned: NoiseFigure hasUnit dB
# AmpKB.GPSNF10
# Assigned: NoiseFigure hasNumericalValue 1.3
# Assigned: NoiseFigure hasUnit dB
# AmpKB.GPSNF2
# Assigned: NoiseFigure hasNumericalValue 0.75
# Assigned: NoiseFigure hasUnit dB
# AmpKB.GPSNF3
# Assigned: NoiseFigure hasNumericalValue 0.7
# Assigned: NoiseFigure hasUnit dB
# AmpKB.GPSNF4
# Assigned: NoiseFigure hasNumericalValue 1.4
# Assigned: NoiseFigure hasUnit dB
# AmpKB.GPSNF5
# Assigned: NoiseFigure hasNumericalValue 1.3
# Assigned: NoiseFigure hasUnit dB
# AmpKB.GPSNF6
# Assigned: NoiseFigure hasNumericalValue 1.3
# Assigned: NoiseFigure hasUnit dB
# AmpKB.GPSNF7
# Assigned: NoiseFigure hasNumericalValue 1.3
# Assigned: NoiseFigure hasUnit dB
# AmpKB.GPSNF8
# Assigned: NoiseFigure hasNumericalValue 1.3
# Assigned: NoiseFigure hasUnit dB
# AmpKB.GPSNF9
# Assigned: NoiseFigure hasNumericalValue 0.55
# Assigned: NoiseFigure hasUnit dB
# AmpKB.GPSSC1
# Assigned: SupplyCurrent hasUpperBoundNumericalValue 3.6
# Assigned: SupplyCurrent hasUnit mA
# AmpKB.GPSSC10
# Assigned: SupplyCurrent hasUpperBoundNumericalValue 14.4
# Assigned: SupplyCurrent hasUnit mA
# AmpKB.GPSSC2
# Assigned: SupplyCurrent hasUpperBoundNumericalValue 1.7
# Assigned: SupplyCurrent hasUnit mA
# AmpKB.GPSSC3
# Assigned: SupplyCurrent hasUpperBoundNumericalValue 3.3
# Assigned: SupplyCurrent hasUnit mA
# AmpKB.GPSSC4
# Assigned: SupplyCurrent hasUpperBoundNumericalValue 2.5
# Assigned: SupplyCurrent hasUnit mA
# AmpKB.GPSSC5
# Assigned: SupplyCurrent hasUpperBoundNumericalValue 10.0
# Assigned: SupplyCurrent hasUnit mA
# AmpKB.GPSSC6
# Assigned: SupplyCurrent hasUpperBoundNumericalValue 15.9
# Assigned: SupplyCurrent hasUnit mA
# AmpKB.GPSSC7
# Assigned: SupplyCurrent hasUpperBoundNumericalValue 15.9
# Assigned: SupplyCurrent hasUnit mA
# AmpKB.GPSSC8
# Assigned: SupplyCurrent hasUpperBoundNumericalValue 14.4
# Assigned: SupplyCurrent hasUnit mA
# AmpKB.GPSSC9
# Assigned: SupplyCurrent hasUpperBoundNumericalValue 3.6
# Assigned: SupplyCurrent hasUnit mA

# %% [markdown]
# #### Instrumental Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/InstruAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

psrr_instru_list = []
for item in onto.PSRR.instances():
    if "INSTR" in item.name:
        psrr_instru_list.append(item)

oss_instru_list = []
for item in onto.OperatingSupplyVoltage.instances():
    if "INSTR" in item.name:
        oss_instru_list.append(item)
        
sv_instru_list = []
for item in onto.SupplyVoltage.instances():
    if "INSTR" in item.name:
        sv_instru_list.append(item)
        
dsv_instru_list = []
for item in onto.DualSupplyVoltage.instances():
    if "INSTR" in item.name:
        dsv_instru_list.append(item)

ssv_instru_list = []
for item in onto.SingleSupplyVoltage.instances():
    if "INSTR" in item.name:
        ssv_instru_list.append(item)

cmrr_instru_list = []
for item in onto.CMRR.instances():
    if "INSTR" in item.name:
        cmrr_instru_list.append(item)

ibc_instru_list = []
for item in onto.InputBiasCurrent.instances():
    if "INSTR" in item.name:
        ibc_instru_list.append(item)
        
ot_instru_list = []
for item in onto.OperatingTemperature.instances():
    if "INSTR" in item.name:
        ot_instru_list.append(item)

# Access the data as a Python dictionary
for item, json_data in zip(psrr_instru_list, data):
    for obj in json_data:
        if obj["head"] == "PSRR":
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(oss_instru_list, data):
    for obj in json_data:
        if obj["head"] == "OperatingSupplyVoltage":
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])

# Access the data as a Python dictionary
for item, json_data in zip(sv_instru_list, data):
    for obj in json_data:
        if obj["head"] == "SupplyVoltage":
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(dsv_instru_list, data):
    for obj in json_data:
        if obj["head"] == "DualSupplyVoltage":
            if obj["relation"] == "hasNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(ssv_instru_list, data):
    for obj in json_data:
        if obj["head"] == "SingleSupplyVoltage":
            if obj["relation"] == "hasNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])

# Access the data as a Python dictionary
for item, json_data in zip(cmrr_instru_list, data):
    for obj in json_data:
        if obj["head"] == "CMRR":
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(ibc_instru_list, data):
    for obj in json_data:
        if obj["head"] == "InputBiasCurrent":
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])

# Access the data as a Python dictionary
for item, json_data in zip(ot_instru_list, data):
    for obj in json_data:
        if obj["head"] == "OperatingTemperature":
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
# Out:
# AmpKB.INSTRUPSRR1
# Assigned: PSRR hasLowerBoundNumericalValue -
# Assigned: PSRR hasUnit dB
# AmpKB.INSTRUPSRR10
# Assigned: PSRR hasLowerBoundNumericalValue 86
# Assigned: PSRR hasUnit dB
# AmpKB.INSTRUPSRR2
# Assigned: PSRR hasLowerBoundNumericalValue 100
# Assigned: PSRR hasUnit dB
# AmpKB.INSTRUPSRR3
# Assigned: PSRR hasLowerBoundNumericalValue -
# Assigned: PSRR hasUnit dB
# AmpKB.INSTRUPSRR4
# Assigned: PSRR hasLowerBoundNumericalValue -
# Assigned: PSRR hasUnit dB
# AmpKB.INSTRUPSRR5
# Assigned: PSRR hasLowerBoundNumericalValue -
# Assigned: PSRR hasUnit dB
# AmpKB.INSTRUPSRR6
# Assigned: PSRR hasLowerBoundNumericalValue -
# Assigned: PSRR hasUnit dB
# AmpKB.INSTRUPSRR7
# Assigned: PSRR hasLowerBoundNumericalValue 112
# Assigned: PSRR hasUnit dB
# AmpKB.INSTRUPSRR8
# Assigned: PSRR hasLowerBoundNumericalValue 104
# Assigned: PSRR hasUnit dB
# AmpKB.INSTRUPSRR9
# Assigned: PSRR hasLowerBoundNumericalValue -
# Assigned: PSRR hasUnit dB
# AmpKB.INSTRUOSV1
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 20
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.INSTRUOSV10
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 5.5
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.INSTRUOSV2
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 18|36
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.INSTRUOSV3
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 18
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.INSTRUOSV4
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 18
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.INSTRUOSV5
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 18
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.INSTRUOSV6
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 18
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.INSTRUOSV7
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 5.5
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.INSTRUOSV8
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 5.5
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.INSTRUOSV9
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 18
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.INSTRUSV1
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 30
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 50
# Assigned: SupplyVoltage hasUnit V
# AmpKB.INSTRUSV10
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 5
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 7
# Assigned: SupplyVoltage hasUnit V
# AmpKB.INSTRUSV2
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 30
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 50
# Assigned: SupplyVoltage hasUnit V
# AmpKB.INSTRUSV3
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 30
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 50
# Assigned: SupplyVoltage hasUnit V
# AmpKB.INSTRUSV4
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 30
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 50
# Assigned: SupplyVoltage hasUnit V
# AmpKB.INSTRUSV5
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 30
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 50
# Assigned: SupplyVoltage hasUnit V
# AmpKB.INSTRUSV6
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 30
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 50
# Assigned: SupplyVoltage hasUnit V
# AmpKB.INSTRUSV7
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 5
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 7
# Assigned: SupplyVoltage hasUnit V
# AmpKB.INSTRUSV8
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 5
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 7
# Assigned: SupplyVoltage hasUnit V
# AmpKB.INSTRUSV9
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 30
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 50
# Assigned: SupplyVoltage hasUnit V
# AmpKB.INSTRUDSV1
# Assigned: DualSupplyVoltage hasNumericalValue 15
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.INSTRUDSV10
# Assigned: DualSupplyVoltage hasNumericalValue -
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.INSTRUDSV2
# Assigned: DualSupplyVoltage hasNumericalValue 3|5|9|12|15
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.INSTRUDSV3
# Assigned: DualSupplyVoltage hasNumericalValue 15
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.INSTRUDSV4
# Assigned: DualSupplyVoltage hasNumericalValue 15
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.INSTRUDSV5
# Assigned: DualSupplyVoltage hasNumericalValue 15
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.INSTRUDSV6
# Assigned: DualSupplyVoltage hasNumericalValue 15
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.INSTRUDSV7
# Assigned: DualSupplyVoltage hasNumericalValue -
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.INSTRUDSV8
# Assigned: DualSupplyVoltage hasNumericalValue -
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.INSTRUDSV9
# Assigned: DualSupplyVoltage hasNumericalValue 15
# Assigned: DualSupplyVoltage hasUnit V
# AmpKB.INSTRUSSV1
# Assigned: SingleSupplyVoltage hasNumericalValue -
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.INSTRUSSV10
# Assigned: SingleSupplyVoltage hasNumericalValue 3.3|5
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.INSTRUSSV2
# Assigned: SingleSupplyVoltage hasNumericalValue 5
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.INSTRUSSV3
# Assigned: SingleSupplyVoltage hasNumericalValue -
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.INSTRUSSV4
# Assigned: SingleSupplyVoltage hasNumericalValue 5
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.INSTRUSSV5
# Assigned: SingleSupplyVoltage hasNumericalValue -
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.INSTRUSSV6
# Assigned: SingleSupplyVoltage hasNumericalValue -
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.INSTRUSSV7
# Assigned: SingleSupplyVoltage hasNumericalValue 3|5
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.INSTRUSSV8
# Assigned: SingleSupplyVoltage hasNumericalValue 3.3|5
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.INSTRUSSV9
# Assigned: SingleSupplyVoltage hasNumericalValue -
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.INSTRUCMRR1
# Assigned: CMRR hasLowerBoundNumericalValue -
# Assigned: CMRR hasUnit dB
# AmpKB.INSTRUCMRR10
# Assigned: CMRR hasLowerBoundNumericalValue 86
# Assigned: CMRR hasUnit dB
# AmpKB.INSTRUCMRR2
# Assigned: CMRR hasLowerBoundNumericalValue 76
# Assigned: CMRR hasUnit dB
# AmpKB.INSTRUCMRR3
# Assigned: CMRR hasLowerBoundNumericalValue 75
# Assigned: CMRR hasUnit dB
# AmpKB.INSTRUCMRR4
# Assigned: CMRR hasLowerBoundNumericalValue 72
# Assigned: CMRR hasUnit dB
# AmpKB.INSTRUCMRR5
# Assigned: CMRR hasLowerBoundNumericalValue 80
# Assigned: CMRR hasUnit dB
# AmpKB.INSTRUCMRR6
# Assigned: CMRR hasLowerBoundNumericalValue 70
# Assigned: CMRR hasUnit dB
# AmpKB.INSTRUCMRR7
# Assigned: CMRR hasLowerBoundNumericalValue 116
# Assigned: CMRR hasUnit dB
# AmpKB.INSTRUCMRR8
# Assigned: CMRR hasLowerBoundNumericalValue 94
# Assigned: CMRR hasUnit dB
# AmpKB.INSTRUCMRR9
# Assigned: CMRR hasLowerBoundNumericalValue 80
# Assigned: CMRR hasUnit dB
# AmpKB.INSTRUIBC1
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue 0.02
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.INSTRUIBC10
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue -
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.INSTRUIBC2
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue 0.05
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.INSTRUIBC3
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue 0.005
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.INSTRUIBC4
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue 0.05
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.INSTRUIBC5
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue -
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.INSTRUIBC6
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue 12
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.INSTRUIBC7
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue -
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.INSTRUIBC8
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue -
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.INSTRUIBC9
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue 0.005
# Assigned: InputBiasCurrent hasUnit uA
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -
# AmpKB.INSTRUOT1
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 70
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.INSTRUOT10
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 125
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.INSTRUOT2
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.INSTRUOT3
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -55
# AmpKB.INSTRUOT4
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 125
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.INSTRUOT5
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.INSTRUOT6
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 125
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.INSTRUOT7
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 125
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.INSTRUOT8
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 125
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.INSTRUOT9
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C

# %% [markdown]
# #### Operational Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/OpAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

psrr_op_list = []
for item in onto.PSRR.instances():
    if "OP" in item.name:
        psrr_op_list.append(item)

oss_op_list = []
for item in onto.OperatingSupplyVoltage.instances():
    if "OPO" in item.name:
        oss_op_list.append(item)
        
sv_op_list = []
for item in onto.SupplyVoltage.instances():
    if "OP" in item.name:
        sv_op_list.append(item)
        
oc_op_list = []
for item in onto.OutputCurrent.instances():
    if "OP" in item.name:
        oc_op_list.append(item)

ssv_op_list = []
for item in onto.SingleSupplyVoltage.instances():
    if "OP" in item.name:
        ssv_op_list.append(item)

cmrr_op_list = []
for item in onto.CMRR.instances():
    if "OP" in item.name:
        cmrr_op_list.append(item)

ibc_op_list = []
for item in onto.InputBiasCurrent.instances():
    if "OP" in item.name:
        ibc_op_list.append(item)
        
ot_op_list = []
for item in onto.OperatingTemperature.instances():
    if "OP" in item.name:
        ot_op_list.append(item)

gbp_op_list = []
for item in onto.GainBandwidthProduct.instances():
    if "OP" in item.name:
        gbp_op_list.append(item)
        
# Access the data as a Python dictionary
for item, json_data in zip(psrr_op_list, data):
    for obj in json_data:
        if obj["head"] == "PSRR":
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(oss_op_list, data):
    for obj in json_data:
        if obj["head"] == "OperatingSupplyVoltage":
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])

# Access the data as a Python dictionary
for item, json_data in zip(sv_op_list, data):
    for obj in json_data:
        if obj["head"] == "SupplyVoltage":
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(oc_op_list, data):
    for obj in json_data:
        if obj["head"] == "OutputCurrent":
            if obj["relation"] == "hasNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(ssv_op_list, data):
    for obj in json_data:
        if obj["head"] == "SingleSupplyVoltage":
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(cmrr_op_list, data):
    for obj in json_data:
        if obj["head"] == "CMRR":
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(ibc_op_list, data):
    for obj in json_data:
        if obj["head"] == "InputBiasCurrent":
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])

# Access the data as a Python dictionary
for item, json_data in zip(ot_op_list, data):
    for obj in json_data:
        if obj["head"] == "OperatingTemperature":
            if obj["relation"] == "hasUpperBoundNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUpperBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasLowerBoundNumericalValue":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasLowerBoundNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
                
# Access the data as a Python dictionary
for item, json_data in zip(gbp_op_list, data):
    for obj in json_data:
        if obj["head"] == "GainBandwidthProduct":
            if obj["relation"] == "hasNumericalValue":
                print(item)
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasNumericalValue.append(obj["tail"])
            if obj["relation"] == "hasUnit":
                print("Assigned: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                item.hasUnit.append(obj["tail"])
# Out:
# AmpKB.OPPSRR1
# Assigned: PSRR hasLowerBoundNumericalValue 80
# Assigned: PSRR hasUnit dB
# AmpKB.OPPSRR10
# Assigned: PSRR hasLowerBoundNumericalValue 70
# Assigned: PSRR hasUnit dB
# AmpKB.OPPSRR2
# Assigned: PSRR hasLowerBoundNumericalValue 125
# Assigned: PSRR hasUnit dB
# AmpKB.OPPSRR3
# Assigned: PSRR hasLowerBoundNumericalValue 70
# Assigned: PSRR hasUnit dB
# AmpKB.OPPSRR4
# Assigned: PSRR hasLowerBoundNumericalValue 120
# Assigned: PSRR hasUnit dB
# AmpKB.OPPSRR5
# Assigned: PSRR hasLowerBoundNumericalValue 100
# Assigned: PSRR hasUnit dB
# AmpKB.OPPSRR6
# Assigned: PSRR hasLowerBoundNumericalValue 72
# Assigned: PSRR hasUnit dB
# AmpKB.OPPSRR7
# Assigned: PSRR hasLowerBoundNumericalValue 54
# Assigned: PSRR hasUnit dB
# AmpKB.OPPSRR8
# Assigned: PSRR hasLowerBoundNumericalValue 87.96
# Assigned: PSRR hasUnit dB
# AmpKB.OPOSV1
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 6
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.OPOSV10
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 5.5
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.OPOSV2
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 5.5
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.OPOSV3
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 5.5
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.OPOSV4
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 5.5
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.OPOSV5
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 5.5
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.OPOSV6
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 6
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.OPOSV7
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 16
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.OPOSV8
# Assigned: OperatingSupplyVoltage hasUpperBoundNumericalValue 5
# Assigned: OperatingSupplyVoltage hasUnit V
# AmpKB.OPSV1
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 6
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 9
# Assigned: SupplyVoltage hasUnit V
# AmpKB.OPSV10
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 5.5
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 6
# Assigned: SupplyVoltage hasUnit V
# AmpKB.OPSV2
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 5.5
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 6
# Assigned: SupplyVoltage hasUnit V
# AmpKB.OPSV3
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 5.5
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 6
# Assigned: SupplyVoltage hasUnit V
# AmpKB.OPSV4
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 5.5
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 6
# Assigned: SupplyVoltage hasUnit V
# AmpKB.OPSV5
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 5.5
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 6
# Assigned: SupplyVoltage hasUnit V
# AmpKB.OPSV6
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 12
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 12.5
# Assigned: SupplyVoltage hasUnit V
# AmpKB.OPSV7
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 16
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 17
# Assigned: SupplyVoltage hasUnit V
# AmpKB.OPSV8
# Assigned: SupplyVoltage hasLowerBoundNumericalValue 5.5
# Assigned: SupplyVoltage hasUpperBoundNumericalValue 6
# Assigned: SupplyVoltage hasUnit V
# AmpKB.OPOC1
# Assigned: OutputCurrent hasNumericalValue 30
# Assigned: OutputCurrent hasUnit mA
# AmpKB.OPOC10
# Assigned: OutputCurrent hasNumericalValue 30
# Assigned: OutputCurrent hasUnit mA
# AmpKB.OPOC2
# Assigned: OutputCurrent hasNumericalValue 30
# Assigned: OutputCurrent hasUnit mA
# AmpKB.OPOC3
# Assigned: OutputCurrent hasNumericalValue 30
# Assigned: OutputCurrent hasUnit mA
# AmpKB.OPOC4
# Assigned: OutputCurrent hasNumericalValue 30
# Assigned: OutputCurrent hasUnit mA
# AmpKB.OPOC5
# Assigned: OutputCurrent hasNumericalValue 110
# Assigned: OutputCurrent hasUnit mA
# AmpKB.OPOC6
# Assigned: OutputCurrent hasNumericalValue 20
# Assigned: OutputCurrent hasUnit mA
# AmpKB.OPOC7
# Assigned: OutputCurrent hasNumericalValue -
# Assigned: OutputCurrent hasUnit mA
# AmpKB.OPOC8
# Assigned: OutputCurrent hasNumericalValue 50
# Assigned: OutputCurrent hasUnit mA
# Assigned: SingleSupplyVoltage hasNumericalValue 3|5
# AmpKB.OPSSV1
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 2.5
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 6
# Assigned: SingleSupplyVoltage hasUnit V
# Assigned: SingleSupplyVoltage hasNumericalValue 3|5
# AmpKB.OPSSV10
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 1.8
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 5.5
# Assigned: SingleSupplyVoltage hasUnit V
# Assigned: SingleSupplyVoltage hasNumericalValue 3|5
# AmpKB.OPSSV2
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 2.3
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 5.5
# Assigned: SingleSupplyVoltage hasUnit V
# Assigned: SingleSupplyVoltage hasNumericalValue 3|5
# AmpKB.OPSSV3
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 2.4
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 6
# Assigned: SingleSupplyVoltage hasUnit V
# Assigned: SingleSupplyVoltage hasNumericalValue 3|5
# AmpKB.OPSSV4
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 1.8
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 5.5
# Assigned: SingleSupplyVoltage hasUnit V
# Assigned: SingleSupplyVoltage hasNumericalValue 5|9
# AmpKB.OPSSV5
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 3.0
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 12.0
# Assigned: SingleSupplyVoltage hasUnit V
# Assigned: SingleSupplyVoltage hasNumericalValue 5|9|12|15|18|24|28
# AmpKB.OPSSV6
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 4.5
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 28
# Assigned: SingleSupplyVoltage hasUnit V
# Assigned: SingleSupplyVoltage hasNumericalValue 3
# AmpKB.OPSSV7
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 2.7
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 5
# Assigned: SingleSupplyVoltage hasUnit V
# Assigned: SingleSupplyVoltage hasNumericalValue 5|9|12|15
# AmpKB.OPSSV8
# Assigned: SingleSupplyVoltage hasLowerBoundNumericalValue 4.5
# Assigned: SingleSupplyVoltage hasUpperBoundNumericalValue 15
# Assigned: SingleSupplyVoltage hasUnit V
# AmpKB.OPCMRR1
# Assigned: CMRR hasLowerBoundNumericalValue 75
# Assigned: CMRR hasUnit dB
# AmpKB.OPCMRR10
# Assigned: CMRR hasLowerBoundNumericalValue 70
# Assigned: CMRR hasUnit dB
# AmpKB.OPCMRR2
# Assigned: CMRR hasLowerBoundNumericalValue 120
# Assigned: CMRR hasUnit dB
# AmpKB.OPCMRR3
# Assigned: CMRR hasLowerBoundNumericalValue 70
# Assigned: CMRR hasUnit dB
# AmpKB.OPCMRR4
# Assigned: CMRR hasLowerBoundNumericalValue 120
# Assigned: CMRR hasUnit dB
# AmpKB.OPCMRR5
# Assigned: CMRR hasLowerBoundNumericalValue 72
# Assigned: CMRR hasUnit dB
# AmpKB.OPCMRR6
# Assigned: CMRR hasLowerBoundNumericalValue 85
# Assigned: CMRR hasUnit dB
# AmpKB.OPCMRR7
# Assigned: CMRR hasLowerBoundNumericalValue 54
# Assigned: CMRR hasUnit dB
# AmpKB.OPCMRR8
# Assigned: CMRR hasLowerBoundNumericalValue 70
# Assigned: CMRR hasUnit dB
# AmpKB.OPIBC1
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue -
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.OPIBC10
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue 0.0001
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.OPIBC2
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue 0.005
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.OPIBC3
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue 1e-06
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.OPIBC4
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue -
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.OPIBC5
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue 2.6
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.OPIBC6
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue 0.07
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.OPIBC7
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue 1e-05
# Assigned: InputBiasCurrent hasUnit uA
# AmpKB.OPIBC8
# Assigned: InputBiasCurrent hasUpperBoundNumericalValue 0.0001
# Assigned: InputBiasCurrent hasUnit uA
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.OPOT1
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.OPOT10
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 125
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.OPOT2
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 125
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.OPOT3
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 125
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.OPOT4
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 125
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.OPOT5
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.OPOT6
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# AmpKB.OPOT7
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 85
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.OPOT8
# Assigned: OperatingTemperature hasUpperBoundNumericalValue 70
# Assigned: OperatingTemperature hasLowerBoundNumericalValue -40
# Assigned: OperatingTemperature hasUnit °C
# AmpKB.OPGBP1
# Assigned: GainBandwidthProduct hasNumericalValue 0.155
# Assigned: GainBandwidthProduct hasUnit MHz
# AmpKB.OPGBP10
# Assigned: GainBandwidthProduct hasNumericalValue 0.01
# Assigned: GainBandwidthProduct hasUnit MHz
# AmpKB.OPGBP2
# Assigned: GainBandwidthProduct hasNumericalValue 2.0
# Assigned: GainBandwidthProduct hasUnit MHz
# AmpKB.OPGBP3
# Assigned: GainBandwidthProduct hasNumericalValue 10.0
# Assigned: GainBandwidthProduct hasUnit MHz
# AmpKB.OPGBP4
# Assigned: GainBandwidthProduct hasNumericalValue 0.3
# Assigned: GainBandwidthProduct hasUnit MHz
# AmpKB.OPGBP5
# Assigned: GainBandwidthProduct hasNumericalValue 86.0
# Assigned: GainBandwidthProduct hasUnit MHz
# AmpKB.OPGBP6
# Assigned: GainBandwidthProduct hasNumericalValue 1.2
# Assigned: GainBandwidthProduct hasUnit MHz
# AmpKB.OPGBP7
# Assigned: GainBandwidthProduct hasNumericalValue 5.5
# Assigned: GainBandwidthProduct hasUnit MHz
# AmpKB.OPGBP8
# Assigned: GainBandwidthProduct hasNumericalValue 0.71
# Assigned: GainBandwidthProduct hasUnit MHz

# %% [markdown]
# ### 4. Assigning Object Property To Amplifiers

# %% [markdown]
# #### Video Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/VideoAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

dsv_video_list = []
for item in onto.DualSupplyVoltage.instances():
    if "VIDEO" in item.name:
        dsv_video_list.append(item)

ssv_video_list = []
for item in onto.SingleSupplyVoltage.instances():
    if "VIDEO" in item.name:
        ssv_video_list.append(item)
        
ot_video_list = []
for item in onto.OperatingTemperature.instances():
    if "VIDEO" in item.name:
        ot_video_list.append(item)
        
# Access the data as a Python dictionary
individuals_list = []
for array in data:
        individuals_list.append(array[0]["head"])
        
video_amp = list(onto.VideoAmplifier.instances())

# DualSupplyVoltage
for array,indi in zip(data,dsv_video_list):
    for instance in video_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# SingleSupplyVoltage
for array,indi in zip(data,ssv_video_list):
    for instance in video_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# OperatingTemperature
for array,indi in zip(data,ot_video_list):
    for instance in video_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
# Out:
# Assiging: AmpKB.LMH6714MF-NOPB value AmpKB.VIDEODSV1
# Assiging: AmpKB.LM6172IN-NOPB value AmpKB.VIDEODSV10
# Assiging: AmpKB.LMH6720MF-NOPB value AmpKB.VIDEODSV2
# Assiging: AmpKB.LMH6739MQ-NOPB value AmpKB.VIDEODSV3
# Assiging: AmpKB.LMH6738MQ-NOPB value AmpKB.VIDEODSV4
# Assiging: AmpKB.AD812ARZ value AmpKB.VIDEODSV5
# Assiging: AmpKB.LMH6722MA-NOPB value AmpKB.VIDEODSV6
# Assiging: AmpKB.THS7360IPW value AmpKB.VIDEODSV7
# Assiging: AmpKB.THS7374IPW value AmpKB.VIDEODSV8
# Assiging: AmpKB.THS7360IPWR value AmpKB.VIDEODSV9
# ----
# Assiging: AmpKB.LMH6714MF-NOPB value AmpKB.VIDEOSSV1
# Assiging: AmpKB.LM6172IN-NOPB value AmpKB.VIDEOSSV10
# Assiging: AmpKB.LMH6720MF-NOPB value AmpKB.VIDEOSSV2
# Assiging: AmpKB.LMH6739MQ-NOPB value AmpKB.VIDEOSSV3
# Assiging: AmpKB.LMH6738MQ-NOPB value AmpKB.VIDEOSSV4
# Assiging: AmpKB.AD812ARZ value AmpKB.VIDEOSSV5
# Assiging: AmpKB.LMH6722MA-NOPB value AmpKB.VIDEOSSV6
# Assiging: AmpKB.THS7360IPW value AmpKB.VIDEOSSV7
# Assiging: AmpKB.THS7374IPW value AmpKB.VIDEOSSV8
# Assiging: AmpKB.THS7360IPWR value AmpKB.VIDEOSSV9
# ----
# Assiging: AmpKB.LMH6714MF-NOPB value AmpKB.VIDEOOT1
# Assiging: AmpKB.LM6172IN-NOPB value AmpKB.VIDEOOT10
# Assiging: AmpKB.LMH6720MF-NOPB value AmpKB.VIDEOOT2
# Assiging: AmpKB.LMH6739MQ-NOPB value AmpKB.VIDEOOT3
# Assiging: AmpKB.LMH6738MQ-NOPB value AmpKB.VIDEOOT4
# Assiging: AmpKB.AD812ARZ value AmpKB.VIDEOOT5
# Assiging: AmpKB.LMH6722MA-NOPB value AmpKB.VIDEOOT6
# Assiging: AmpKB.THS7360IPW value AmpKB.VIDEOOT7
# Assiging: AmpKB.THS7374IPW value AmpKB.VIDEOOT8
# Assiging: AmpKB.THS7360IPWR value AmpKB.VIDEOOT9
# ----

# %% [markdown]
# #### Audio Triplets

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/AudioAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

pd_audio_list = []
for item in onto.PowerDissipation.instances():
    if "AUDIO" in item.name:
        pd_audio_list.append(item)

ssv_audio_list = []
for item in onto.SingleSupplyVoltage.instances():
    if "AUDIO" in item.name:
        ssv_audio_list.append(item)
        
ot_audio_list = []
for item in onto.OperatingTemperature.instances():
    if "AUDIO" in item.name:
        ot_audio_list.append(item)
        
# Access the data as a Python dictionary
individuals_list = []
for array in data:
        individuals_list.append(array[0]["head"])
        
audio_amp = list(onto.AudioAmplifier.instances())

# PowerDissipation
for array,indi in zip(data,pd_audio_list):
    for instance in audio_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# SingleSupplyVoltage
for array,indi in zip(data,ssv_audio_list):
    for instance in audio_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")

# OperatingTemperature
for array,indi in zip(data,ot_audio_list):
    for instance in audio_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
# Out:
# Assiging: AmpKB.LM4861M-NOPB value AmpKB.AUDIOPD1
# Assiging: AmpKB.LM4889MA-NOPB value AmpKB.AUDIOPD10
# Assiging: AmpKB.TPA3125D2N value AmpKB.AUDIOPD2
# Assiging: AmpKB.BD28623MUV-E2 value AmpKB.AUDIOPD3
# Assiging: AmpKB.OPA1611AID value AmpKB.AUDIOPD4
# Assiging: AmpKB.PAM8945PJR value AmpKB.AUDIOPD5
# Assiging: AmpKB.LM4862M-NOPB value AmpKB.AUDIOPD6
# Assiging: AmpKB.LM386MMX-1-NOPB value AmpKB.AUDIOPD7
# Assiging: AmpKB.BM28723AMUV-E2 value AmpKB.AUDIOPD8
# Assiging: AmpKB.PAM8610TR value AmpKB.AUDIOPD9
# ----
# Assiging: AmpKB.LM4861M-NOPB value AmpKB.AUDIOSV1
# Assiging: AmpKB.LM4889MA-NOPB value AmpKB.AUDIOSV10
# Assiging: AmpKB.TPA3125D2N value AmpKB.AUDIOSV2
# Assiging: AmpKB.BD28623MUV-E2 value AmpKB.AUDIOSV3
# Assiging: AmpKB.OPA1611AID value AmpKB.AUDIOSV4
# Assiging: AmpKB.PAM8945PJR value AmpKB.AUDIOSV5
# Assiging: AmpKB.LM4862M-NOPB value AmpKB.AUDIOSV6
# Assiging: AmpKB.LM386MMX-1-NOPB value AmpKB.AUDIOSV7
# Assiging: AmpKB.BM28723AMUV-E2 value AmpKB.AUDIOSV8
# Assiging: AmpKB.PAM8610TR value AmpKB.AUDIOSV9
# ----
# Assiging: AmpKB.LM4861M-NOPB value AmpKB.AUDIOOT1
# Assiging: AmpKB.LM4889MA-NOPB value AmpKB.AUDIOOT10
# Assiging: AmpKB.TPA3125D2N value AmpKB.AUDIOOT2
# Assiging: AmpKB.BD28623MUV-E2 value AmpKB.AUDIOOT3
# Assiging: AmpKB.OPA1611AID value AmpKB.AUDIOOT4
# Assiging: AmpKB.PAM8945PJR value AmpKB.AUDIOOT5
# Assiging: AmpKB.LM4862M-NOPB value AmpKB.AUDIOOT6
# Assiging: AmpKB.LM386MMX-1-NOPB value AmpKB.AUDIOOT7
# Assiging: AmpKB.BM28723AMUV-E2 value AmpKB.AUDIOOT8
# Assiging: AmpKB.PAM8610TR value AmpKB.AUDIOOT9

# %% [markdown]
# #### GPS Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/GPSAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

pd_gps_list = []
for item in onto.PowerDissipation.instances():
    if "GPS" in item.name:
        pd_gps_list.append(item)

ssv_gps_list = []
for item in onto.SingleSupplyVoltage.instances():
    if "GPS" in item.name:
        ssv_gps_list.append(item)
        
ot_gps_list = []
for item in onto.OperatingTemperature.instances():
    if "GPS" in item.name:
        ot_gps_list.append(item)
        
gain_gps_list = []
for item in onto.Gain.instances():
    if "GPS" in item.name:
        gain_gps_list.append(item)

of_gps_list = []
for item in onto.OperatingFrequency.instances():
    if "GPS" in item.name:
        of_gps_list.append(item)

nf_gps_list = []
for item in onto.NoiseFigure.instances():
    if "GPS" in item.name:
        nf_gps_list.append(item)

sc_gps_list = []
for item in onto.SupplyCurrent.instances():
    if "GPS" in item.name:
        sc_gps_list.append(item)

# Access the data as a Python dictionary
individuals_list = []
for array in data:
        individuals_list.append(array[0]["head"])
        
gps_amp = list(onto.GPSAmplifier.instances())

# PowerDissipation
for array,indi in zip(data,pd_gps_list):
    for instance in gps_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# SingleSupplyVoltage
for array,indi in zip(data,ssv_gps_list):
    for instance in gps_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")

# OperatingTemperature
for array,indi in zip(data,ot_gps_list):
    for instance in gps_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")

# Gain
for array,indi in zip(data,gain_gps_list):
    for instance in gps_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# OperatingFrequency
for array,indi in zip(data,of_gps_list):
    for instance in gps_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")

# NoiseFigure
for array,indi in zip(data,nf_gps_list):
    for instance in gps_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# SupplyCurrent
for array,indi in zip(data,sc_gps_list):
    for instance in gps_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
# Out:
# Assiging: AmpKB.BGA725L6E6327FTSA1 value AmpKB.GPSPD1
# Assiging: AmpKB.BGU7005-115 value AmpKB.GPSPD10
# Assiging: AmpKB.BGA123L4E6327XTSA1 value AmpKB.GPSPD2
# Assiging: AmpKB.BGA715N7E6327XTSA2 value AmpKB.GPSPD3
# Assiging: AmpKB.BGU8103X value AmpKB.GPSPD4
# Assiging: AmpKB.BGU8019X value AmpKB.GPSPD5
# Assiging: AmpKB.BGU7007-115 value AmpKB.GPSPD6
# Assiging: AmpKB.BGU7008-115 value AmpKB.GPSPD7
# Assiging: AmpKB.BGU7004-115 value AmpKB.GPSPD8
# Assiging: AmpKB.BGA524N6E6327XTSA1 value AmpKB.GPSPD9
# ----
# Assiging: AmpKB.BGA725L6E6327FTSA1 value AmpKB.GPSSV1
# Assiging: AmpKB.BGU7005-115 value AmpKB.GPSSV10
# Assiging: AmpKB.BGA123L4E6327XTSA1 value AmpKB.GPSSV2
# Assiging: AmpKB.BGA715N7E6327XTSA2 value AmpKB.GPSSV3
# Assiging: AmpKB.BGU8103X value AmpKB.GPSSV4
# Assiging: AmpKB.BGU8019X value AmpKB.GPSSV5
# Assiging: AmpKB.BGU7007-115 value AmpKB.GPSSV6
# Assiging: AmpKB.BGU7008-115 value AmpKB.GPSSV7
# Assiging: AmpKB.BGU7004-115 value AmpKB.GPSSV8
# Assiging: AmpKB.BGA524N6E6327XTSA1 value AmpKB.GPSSV9
# ----
# Assiging: AmpKB.BGA725L6E6327FTSA1 value AmpKB.GPSOT1
# Assiging: AmpKB.BGU7005-115 value AmpKB.GPSOT10
# Assiging: AmpKB.BGA123L4E6327XTSA1 value AmpKB.GPSOT2
# Assiging: AmpKB.BGA715N7E6327XTSA2 value AmpKB.GPSOT3
# Assiging: AmpKB.BGU8103X value AmpKB.GPSOT4
# Assiging: AmpKB.BGU8019X value AmpKB.GPSOT5
# Assiging: AmpKB.BGU7007-115 value AmpKB.GPSOT6
# Assiging: AmpKB.BGU7008-115 value AmpKB.GPSOT7
# Assiging: AmpKB.BGU7004-115 value AmpKB.GPSOT8
# Assiging: AmpKB.BGA524N6E6327XTSA1 value AmpKB.GPSOT9
# ----
# Assiging: AmpKB.BGA725L6E6327FTSA1 value AmpKB.GPSGain1
# Assiging: AmpKB.BGU7005-115 value AmpKB.GPSGain10
# Assiging: AmpKB.BGA123L4E6327XTSA1 value AmpKB.GPSGain2
# Assiging: AmpKB.BGA715N7E6327XTSA2 value AmpKB.GPSGain3
# Assiging: AmpKB.BGU8103X value AmpKB.GPSGain4
# Assiging: AmpKB.BGU8019X value AmpKB.GPSGain5
# Assiging: AmpKB.BGU7007-115 value AmpKB.GPSGain6
# Assiging: AmpKB.BGU7008-115 value AmpKB.GPSGain7
# Assiging: AmpKB.BGU7004-115 value AmpKB.GPSGain8
# Assiging: AmpKB.BGA524N6E6327XTSA1 value AmpKB.GPSGain9
# ----
# Assiging: AmpKB.BGA725L6E6327FTSA1 value AmpKB.GPSOF1
# Assiging: AmpKB.BGU7005-115 value AmpKB.GPSOF10
# Assiging: AmpKB.BGA123L4E6327XTSA1 value AmpKB.GPSOF2
# Assiging: AmpKB.BGA715N7E6327XTSA2 value AmpKB.GPSOF3
# Assiging: AmpKB.BGU8103X value AmpKB.GPSOF4
# Assiging: AmpKB.BGU8019X value AmpKB.GPSOF5
# Assiging: AmpKB.BGU7007-115 value AmpKB.GPSOF6
# Assiging: AmpKB.BGU7008-115 value AmpKB.GPSOF7
# Assiging: AmpKB.BGU7004-115 value AmpKB.GPSOF8
# Assiging: AmpKB.BGA524N6E6327XTSA1 value AmpKB.GPSOF9
# ----
# Assiging: AmpKB.BGA725L6E6327FTSA1 value AmpKB.GPSNF1
# Assiging: AmpKB.BGU7005-115 value AmpKB.GPSNF10
# Assiging: AmpKB.BGA123L4E6327XTSA1 value AmpKB.GPSNF2
# Assiging: AmpKB.BGA715N7E6327XTSA2 value AmpKB.GPSNF3
# Assiging: AmpKB.BGU8103X value AmpKB.GPSNF4
# Assiging: AmpKB.BGU8019X value AmpKB.GPSNF5
# Assiging: AmpKB.BGU7007-115 value AmpKB.GPSNF6
# Assiging: AmpKB.BGU7008-115 value AmpKB.GPSNF7
# Assiging: AmpKB.BGU7004-115 value AmpKB.GPSNF8
# Assiging: AmpKB.BGA524N6E6327XTSA1 value AmpKB.GPSNF9
# ----
# Assiging: AmpKB.BGA725L6E6327FTSA1 value AmpKB.GPSSC1
# Assiging: AmpKB.BGU7005-115 value AmpKB.GPSSC10
# Assiging: AmpKB.BGA123L4E6327XTSA1 value AmpKB.GPSSC2
# Assiging: AmpKB.BGA715N7E6327XTSA2 value AmpKB.GPSSC3
# Assiging: AmpKB.BGU8103X value AmpKB.GPSSC4
# Assiging: AmpKB.BGU8019X value AmpKB.GPSSC5
# Assiging: AmpKB.BGU7007-115 value AmpKB.GPSSC6
# Assiging: AmpKB.BGU7008-115 value AmpKB.GPSSC7
# Assiging: AmpKB.BGU7004-115 value AmpKB.GPSSC8
# Assiging: AmpKB.BGA524N6E6327XTSA1 value AmpKB.GPSSC9

# %% [markdown]
# #### Instrumental Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/InstruAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

psrr_instru_list = []
for item in onto.PSRR.instances():
    if "INSTR" in item.name:
        psrr_instru_list.append(item)

oss_instru_list = []
for item in onto.OperatingSupplyVoltage.instances():
    if "INSTR" in item.name:
        oss_instru_list.append(item)
        
sv_instru_list = []
for item in onto.SupplyVoltage.instances():
    if "INSTR" in item.name:
        sv_instru_list.append(item)
        
dsv_instru_list = []
for item in onto.DualSupplyVoltage.instances():
    if "INSTR" in item.name:
        dsv_instru_list.append(item)

ssv_instru_list = []
for item in onto.SingleSupplyVoltage.instances():
    if "INSTR" in item.name:
        ssv_instru_list.append(item)

cmrr_instru_list = []
for item in onto.CMRR.instances():
    if "INSTR" in item.name:
        cmrr_instru_list.append(item)

ibc_instru_list = []
for item in onto.InputBiasCurrent.instances():
    if "INSTR" in item.name:
        ibc_instru_list.append(item)
        
ot_instru_list = []
for item in onto.OperatingTemperature.instances():
    if "INSTR" in item.name:
        ot_instru_list.append(item)

# Access the data as a Python dictionary
individuals_list = []
for array in data:
        individuals_list.append(array[0]["head"])
        
instru_amp = list(onto.InstrumentalAmplifier.instances())

# PSRR
for array,indi in zip(data,psrr_instru_list):
    for instance in instru_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# OperatingSupplyVoltage
for array,indi in zip(data,oss_instru_list):
    for instance in instru_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")

# SupplyVoltage
for array,indi in zip(data,sv_instru_list):
    for instance in instru_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")

# DualSupplyVoltage
for array,indi in zip(data,dsv_instru_list):
    for instance in instru_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# SingleSupplyVoltage
for array,indi in zip(data,ssv_instru_list):
    for instance in instru_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")

# CMRR
for array,indi in zip(data,cmrr_instru_list):
    for instance in instru_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# InputBiasCurrent
for array,indi in zip(data,ibc_instru_list):
    for instance in instru_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# OperatingTemperature
for array,indi in zip(data,ot_instru_list):
    for instance in instru_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
# Out:
# Assiging: AmpKB.INA101HP value AmpKB.INSTRUPSRR1
# Assiging: AmpKB.MCP6N11T-100E-MNY value AmpKB.INSTRUPSRR10
# Assiging: AmpKB.INA122PA value AmpKB.INSTRUPSRR2
# Assiging: AmpKB.PGA204AP value AmpKB.INSTRUPSRR3
# Assiging: AmpKB.INA125UA value AmpKB.INSTRUPSRR4
# Assiging: AmpKB.INA115BU value AmpKB.INSTRUPSRR5
# Assiging: AmpKB.INA217AIDWT value AmpKB.INSTRUPSRR6
# Assiging: AmpKB.LMP8358MA-NOPB value AmpKB.INSTRUPSRR7
# Assiging: AmpKB.MCP6N16-010E-MS value AmpKB.INSTRUPSRR8
# Assiging: AmpKB.INA2128U value AmpKB.INSTRUPSRR9
# ----
# Assiging: AmpKB.INA101HP value AmpKB.INSTRUOSV1
# Assiging: AmpKB.MCP6N11T-100E-MNY value AmpKB.INSTRUOSV10
# Assiging: AmpKB.INA122PA value AmpKB.INSTRUOSV2
# Assiging: AmpKB.PGA204AP value AmpKB.INSTRUOSV3
# Assiging: AmpKB.INA125UA value AmpKB.INSTRUOSV4
# Assiging: AmpKB.INA115BU value AmpKB.INSTRUOSV5
# Assiging: AmpKB.INA217AIDWT value AmpKB.INSTRUOSV6
# Assiging: AmpKB.LMP8358MA-NOPB value AmpKB.INSTRUOSV7
# Assiging: AmpKB.MCP6N16-010E-MS value AmpKB.INSTRUOSV8
# Assiging: AmpKB.INA2128U value AmpKB.INSTRUOSV9
# ----
# Assiging: AmpKB.INA101HP value AmpKB.INSTRUSV1
# Assiging: AmpKB.MCP6N11T-100E-MNY value AmpKB.INSTRUSV10
# Assiging: AmpKB.INA122PA value AmpKB.INSTRUSV2
# Assiging: AmpKB.PGA204AP value AmpKB.INSTRUSV3
# Assiging: AmpKB.INA125UA value AmpKB.INSTRUSV4
# Assiging: AmpKB.INA115BU value AmpKB.INSTRUSV5
# Assiging: AmpKB.INA217AIDWT value AmpKB.INSTRUSV6
# Assiging: AmpKB.LMP8358MA-NOPB value AmpKB.INSTRUSV7
# Assiging: AmpKB.MCP6N16-010E-MS value AmpKB.INSTRUSV8
# Assiging: AmpKB.INA2128U value AmpKB.INSTRUSV9
# ----
# Assiging: AmpKB.INA101HP value AmpKB.INSTRUDSV1
# Assiging: AmpKB.MCP6N11T-100E-MNY value AmpKB.INSTRUDSV10
# Assiging: AmpKB.INA122PA value AmpKB.INSTRUDSV2
# Assiging: AmpKB.PGA204AP value AmpKB.INSTRUDSV3
# Assiging: AmpKB.INA125UA value AmpKB.INSTRUDSV4
# Assiging: AmpKB.INA115BU value AmpKB.INSTRUDSV5
# Assiging: AmpKB.INA217AIDWT value AmpKB.INSTRUDSV6
# Assiging: AmpKB.LMP8358MA-NOPB value AmpKB.INSTRUDSV7
# Assiging: AmpKB.MCP6N16-010E-MS value AmpKB.INSTRUDSV8
# Assiging: AmpKB.INA2128U value AmpKB.INSTRUDSV9
# ----
# Assiging: AmpKB.INA101HP value AmpKB.INSTRUSSV1
# Assiging: AmpKB.MCP6N11T-100E-MNY value AmpKB.INSTRUSSV10
# Assiging: AmpKB.INA122PA value AmpKB.INSTRUSSV2
# Assiging: AmpKB.PGA204AP value AmpKB.INSTRUSSV3
# Assiging: AmpKB.INA125UA value AmpKB.INSTRUSSV4
# Assiging: AmpKB.INA115BU value AmpKB.INSTRUSSV5
# Assiging: AmpKB.INA217AIDWT value AmpKB.INSTRUSSV6
# Assiging: AmpKB.LMP8358MA-NOPB value AmpKB.INSTRUSSV7
# Assiging: AmpKB.MCP6N16-010E-MS value AmpKB.INSTRUSSV8
# Assiging: AmpKB.INA2128U value AmpKB.INSTRUSSV9
# ----
# Assiging: AmpKB.INA101HP value AmpKB.INSTRUCMRR1
# Assiging: AmpKB.MCP6N11T-100E-MNY value AmpKB.INSTRUCMRR10
# Assiging: AmpKB.INA122PA value AmpKB.INSTRUCMRR2
# Assiging: AmpKB.PGA204AP value AmpKB.INSTRUCMRR3
# Assiging: AmpKB.INA125UA value AmpKB.INSTRUCMRR4
# Assiging: AmpKB.INA115BU value AmpKB.INSTRUCMRR5
# Assiging: AmpKB.INA217AIDWT value AmpKB.INSTRUCMRR6
# Assiging: AmpKB.LMP8358MA-NOPB value AmpKB.INSTRUCMRR7
# Assiging: AmpKB.MCP6N16-010E-MS value AmpKB.INSTRUCMRR8
# Assiging: AmpKB.INA2128U value AmpKB.INSTRUCMRR9
# ----
# Assiging: AmpKB.INA101HP value AmpKB.INSTRUIBC1
# Assiging: AmpKB.MCP6N11T-100E-MNY value AmpKB.INSTRUIBC10
# Assiging: AmpKB.INA122PA value AmpKB.INSTRUIBC2
# Assiging: AmpKB.PGA204AP value AmpKB.INSTRUIBC3
# Assiging: AmpKB.INA125UA value AmpKB.INSTRUIBC4
# Assiging: AmpKB.INA115BU value AmpKB.INSTRUIBC5
# Assiging: AmpKB.INA217AIDWT value AmpKB.INSTRUIBC6
# Assiging: AmpKB.LMP8358MA-NOPB value AmpKB.INSTRUIBC7
# Assiging: AmpKB.MCP6N16-010E-MS value AmpKB.INSTRUIBC8
# Assiging: AmpKB.INA2128U value AmpKB.INSTRUIBC9
# ----
# Assiging: AmpKB.INA101HP value AmpKB.INSTRUOT1
# Assiging: AmpKB.MCP6N11T-100E-MNY value AmpKB.INSTRUOT10
# Assiging: AmpKB.INA122PA value AmpKB.INSTRUOT2
# Assiging: AmpKB.PGA204AP value AmpKB.INSTRUOT3
# Assiging: AmpKB.INA125UA value AmpKB.INSTRUOT4
# Assiging: AmpKB.INA115BU value AmpKB.INSTRUOT5
# Assiging: AmpKB.INA217AIDWT value AmpKB.INSTRUOT6
# Assiging: AmpKB.LMP8358MA-NOPB value AmpKB.INSTRUOT7
# Assiging: AmpKB.MCP6N16-010E-MS value AmpKB.INSTRUOT8
# Assiging: AmpKB.INA2128U value AmpKB.INSTRUOT9

# %% [markdown]
# #### Operational Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/OpAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

psrr_op_list = []
for item in onto.PSRR.instances():
    if "OP" in item.name:
        psrr_op_list.append(item)

oss_op_list = []
for item in onto.OperatingSupplyVoltage.instances():
    if "OPO" in item.name:
        oss_op_list.append(item)
        
sv_op_list = []
for item in onto.SupplyVoltage.instances():
    if "OP" in item.name:
        sv_op_list.append(item)
        
oc_op_list = []
for item in onto.OutputCurrent.instances():
    if "OP" in item.name:
        oc_op_list.append(item)

ssv_op_list = []
for item in onto.SingleSupplyVoltage.instances():
    if "OP" in item.name:
        ssv_op_list.append(item)

cmrr_op_list = []
for item in onto.CMRR.instances():
    if "OP" in item.name:
        cmrr_op_list.append(item)

ibc_op_list = []
for item in onto.InputBiasCurrent.instances():
    if "OP" in item.name:
        ibc_op_list.append(item)
        
ot_op_list = []
for item in onto.OperatingTemperature.instances():
    if "OP" in item.name:
        ot_op_list.append(item)

gbp_op_list = []
for item in onto.GainBandwidthProduct.instances():
    if "OP" in item.name:
        gbp_op_list.append(item)
        
# Access the data as a Python dictionary
individuals_list = []
for array in data:
        individuals_list.append(array[0]["head"])
        
op_amp = list(onto.OperationalAmplifier.instances())
        
# PSRR
for array,indi in zip(data,psrr_op_list):
    for instance in op_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# OperatingSupplyVoltage
for array,indi in zip(data,oss_op_list):
    for instance in op_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")

# SupplyVoltage
for array,indi in zip(data,sv_op_list):
    for instance in op_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")

# OutputCurrent
for array,indi in zip(data,oc_op_list):
    for instance in op_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# SingleSupplyVoltage
for array,indi in zip(data,ssv_op_list):
    for instance in op_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")

# CMRR
for array,indi in zip(data,cmrr_op_list):
    for instance in op_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# InputBiasCurrent
for array,indi in zip(data,ibc_op_list):
    for instance in op_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# OperatingTemperature
for array,indi in zip(data,ot_op_list):
    for instance in op_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
print("----")
            
# OperatingTemperature
for array,indi in zip(data,gbp_op_list):
    for instance in op_amp:
        if array[0]["head"] == instance.name:
            instance.hasProperty.append(indi)
            print("Assiging:",instance,"value",indi)
# Out:
# Assiging: AmpKB.MCP607-I-P value AmpKB.OPPSRR1
# Assiging: AmpKB.MCP6034-E-SL value AmpKB.OPPSRR10
# Assiging: AmpKB.MCP6V27-E-SN value AmpKB.OPPSRR2
# Assiging: AmpKB.MCP6292-E-P value AmpKB.OPPSRR3
# Assiging: AmpKB.MCP6V32-E-MS value AmpKB.OPPSRR4
# Assiging: AmpKB.OPA625IDBVT value AmpKB.OPPSRR5
# Assiging: AmpKB.LMH6639MA-NOPB value AmpKB.OPPSRR6
# Assiging: AmpKB.TLC27M2CP value AmpKB.OPPSRR7
# Assiging: AmpKB.OPA343UA value AmpKB.OPPSRR8
# ----
# Assiging: AmpKB.MCP607-I-P value AmpKB.OPOSV1
# Assiging: AmpKB.MCP6034-E-SL value AmpKB.OPOSV10
# Assiging: AmpKB.MCP6V27-E-SN value AmpKB.OPOSV2
# Assiging: AmpKB.MCP6292-E-P value AmpKB.OPOSV3
# Assiging: AmpKB.MCP6V32-E-MS value AmpKB.OPOSV4
# Assiging: AmpKB.OPA625IDBVT value AmpKB.OPOSV5
# Assiging: AmpKB.LMH6639MA-NOPB value AmpKB.OPOSV6
# Assiging: AmpKB.TLC27M2CP value AmpKB.OPOSV7
# Assiging: AmpKB.OPA343UA value AmpKB.OPOSV8
# ----
# Assiging: AmpKB.MCP607-I-P value AmpKB.OPSV1
# Assiging: AmpKB.MCP6034-E-SL value AmpKB.OPSV10
# Assiging: AmpKB.MCP6V27-E-SN value AmpKB.OPSV2
# Assiging: AmpKB.MCP6292-E-P value AmpKB.OPSV3
# Assiging: AmpKB.MCP6V32-E-MS value AmpKB.OPSV4
# Assiging: AmpKB.OPA625IDBVT value AmpKB.OPSV5
# Assiging: AmpKB.LMH6639MA-NOPB value AmpKB.OPSV6
# Assiging: AmpKB.TLC27M2CP value AmpKB.OPSV7
# Assiging: AmpKB.OPA343UA value AmpKB.OPSV8
# ----
# Assiging: AmpKB.MCP607-I-P value AmpKB.OPOC1
# Assiging: AmpKB.MCP6034-E-SL value AmpKB.OPOC10
# Assiging: AmpKB.MCP6V27-E-SN value AmpKB.OPOC2
# Assiging: AmpKB.MCP6292-E-P value AmpKB.OPOC3
# Assiging: AmpKB.MCP6V32-E-MS value AmpKB.OPOC4
# Assiging: AmpKB.OPA625IDBVT value AmpKB.OPOC5
# Assiging: AmpKB.LMH6639MA-NOPB value AmpKB.OPOC6
# Assiging: AmpKB.TLC27M2CP value AmpKB.OPOC7
# Assiging: AmpKB.OPA343UA value AmpKB.OPOC8
# ----
# Assiging: AmpKB.MCP607-I-P value AmpKB.OPSSV1
# Assiging: AmpKB.MCP6034-E-SL value AmpKB.OPSSV10
# Assiging: AmpKB.MCP6V27-E-SN value AmpKB.OPSSV2
# Assiging: AmpKB.MCP6292-E-P value AmpKB.OPSSV3
# Assiging: AmpKB.MCP6V32-E-MS value AmpKB.OPSSV4
# Assiging: AmpKB.OPA625IDBVT value AmpKB.OPSSV5
# Assiging: AmpKB.LMH6639MA-NOPB value AmpKB.OPSSV6
# Assiging: AmpKB.TLC27M2CP value AmpKB.OPSSV7
# Assiging: AmpKB.OPA343UA value AmpKB.OPSSV8
# ----
# Assiging: AmpKB.MCP607-I-P value AmpKB.OPCMRR1
# Assiging: AmpKB.MCP6034-E-SL value AmpKB.OPCMRR10
# Assiging: AmpKB.MCP6V27-E-SN value AmpKB.OPCMRR2
# Assiging: AmpKB.MCP6292-E-P value AmpKB.OPCMRR3
# Assiging: AmpKB.MCP6V32-E-MS value AmpKB.OPCMRR4
# Assiging: AmpKB.OPA625IDBVT value AmpKB.OPCMRR5
# Assiging: AmpKB.LMH6639MA-NOPB value AmpKB.OPCMRR6
# Assiging: AmpKB.TLC27M2CP value AmpKB.OPCMRR7
# Assiging: AmpKB.OPA343UA value AmpKB.OPCMRR8
# ----
# Assiging: AmpKB.MCP607-I-P value AmpKB.OPIBC1
# Assiging: AmpKB.MCP6034-E-SL value AmpKB.OPIBC10
# Assiging: AmpKB.MCP6V27-E-SN value AmpKB.OPIBC2
# Assiging: AmpKB.MCP6292-E-P value AmpKB.OPIBC3
# Assiging: AmpKB.MCP6V32-E-MS value AmpKB.OPIBC4
# Assiging: AmpKB.OPA625IDBVT value AmpKB.OPIBC5
# Assiging: AmpKB.LMH6639MA-NOPB value AmpKB.OPIBC6
# Assiging: AmpKB.TLC27M2CP value AmpKB.OPIBC7
# Assiging: AmpKB.OPA343UA value AmpKB.OPIBC8
# ----
# Assiging: AmpKB.MCP607-I-P value AmpKB.OPOT1
# Assiging: AmpKB.MCP6034-E-SL value AmpKB.OPOT10
# Assiging: AmpKB.MCP6V27-E-SN value AmpKB.OPOT2
# Assiging: AmpKB.MCP6292-E-P value AmpKB.OPOT3
# Assiging: AmpKB.MCP6V32-E-MS value AmpKB.OPOT4
# Assiging: AmpKB.OPA625IDBVT value AmpKB.OPOT5
# Assiging: AmpKB.LMH6639MA-NOPB value AmpKB.OPOT6
# Assiging: AmpKB.TLC27M2CP value AmpKB.OPOT7
# Assiging: AmpKB.OPA343UA value AmpKB.OPOT8
# ----
# Assiging: AmpKB.MCP607-I-P value AmpKB.OPGBP1
# Assiging: AmpKB.MCP6034-E-SL value AmpKB.OPGBP10
# Assiging: AmpKB.MCP6V27-E-SN value AmpKB.OPGBP2
# Assiging: AmpKB.MCP6292-E-P value AmpKB.OPGBP3
# Assiging: AmpKB.MCP6V32-E-MS value AmpKB.OPGBP4
# Assiging: AmpKB.OPA625IDBVT value AmpKB.OPGBP5
# Assiging: AmpKB.LMH6639MA-NOPB value AmpKB.OPGBP6
# Assiging: AmpKB.TLC27M2CP value AmpKB.OPGBP7
# Assiging: AmpKB.OPA343UA value AmpKB.OPGBP8

# %%
onto.save(filepath)

# %%
from owlready2 import *
filepath = "./../OntoFiles/AmpKB.rdf"
go = get_ontology(filepath).load()

# %%
list(default_world.sparql("""
           SELECT (COUNT(?x) AS ?nb)
           { ?x a owl:Class . }
    """))
# Out:
# [[41]]

# %%
list(default_world.sparql("""
        SELECT * 
        WHERE {?subject ?predicate ?object}
    """))
# Out:
# [[.anonymous, 6, owl.Ontology],
#  [w3id.org.amplifiers, 6, owl.Ontology],
#  [1.1.title, 6, owl.AnnotationProperty],
#  [rdf-schema.description, 6, owl.AnnotationProperty],
#  [AmpKB.hasProperty, 6, owl.ObjectProperty],
#  [AmpKB.hasProperty, 7, AmpKB.Amplifier],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasLowerBoundNumericalValue],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.hasProperty, 8, AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 18, AmpKB.hasNumericalValue],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.hasProperty, 8, AmpKB.hasNumericalValue.some(<class 'str'>)],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasUpperBoundNumericalValue],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.hasProperty, 8, AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.hasInputSignalType, 6, owl.DatatypeProperty],
#  [AmpKB.hasInputSignalType, 10, owl.topDataProperty],
#  [AmpKB.hasInputSignalType, 7, AmpKB.Amplifier],
#  [AmpKB.hasInputSignalType, 8, str],
#  [AmpKB.hasLowerBoundNumericalValue, 6, owl.DatatypeProperty],
#  [AmpKB.hasLowerBoundNumericalValue, 10, owl.topDataProperty],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.CMRR],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.DualSupplyVoltage],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.Gain],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.GainBandwidthProduct],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.InputBiasCurrent],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.NoiseFigure],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.OperatingFrequency],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.OperatingSupplyVoltage],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.OperatingTemperature],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.OutputCurrent],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.PSRR],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.PowerDissipation],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.SingleSupplyVoltage],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.SupplyCurrent],
#  [AmpKB.hasLowerBoundNumericalValue, 7, AmpKB.SupplyVoltage],
#  [AmpKB.hasLowerBoundNumericalValue, 8, str],
#  [AmpKB.hasManufacturer, 6, owl.DatatypeProperty],
#  [AmpKB.hasManufacturer, 10, owl.topDataProperty],
#  [AmpKB.hasManufacturer, 7, AmpKB.Amplifier],
#  [AmpKB.hasManufacturer, 8, str],
#  [AmpKB.hasNumericalValue, 6, owl.DatatypeProperty],
#  [AmpKB.hasNumericalValue, 10, owl.topDataProperty],
#  [AmpKB.hasNumericalValue, 7, AmpKB.CMRR],
#  [AmpKB.hasNumericalValue, 7, AmpKB.DualSupplyVoltage],
#  [AmpKB.hasNumericalValue, 7, AmpKB.Gain],
#  [AmpKB.hasNumericalValue, 7, AmpKB.GainBandwidthProduct],
#  [AmpKB.hasNumericalValue, 7, AmpKB.InputBiasCurrent],
#  [AmpKB.hasNumericalValue, 7, AmpKB.NoiseFigure],
#  [AmpKB.hasNumericalValue, 7, AmpKB.OperatingFrequency],
#  [AmpKB.hasNumericalValue, 7, AmpKB.OperatingSupplyVoltage],
#  [AmpKB.hasNumericalValue, 7, AmpKB.OperatingTemperature],
#  [AmpKB.hasNumericalValue, 7, AmpKB.OutputCurrent],
#  [AmpKB.hasNumericalValue, 7, AmpKB.PSRR],
#  [AmpKB.hasNumericalValue, 7, AmpKB.PowerDissipation],
#  [AmpKB.hasNumericalValue, 7, AmpKB.SingleSupplyVoltage],
#  [AmpKB.hasNumericalValue, 7, AmpKB.SupplyCurrent],
#  [AmpKB.hasNumericalValue, 7, AmpKB.SupplyVoltage],
#  [AmpKB.hasNumericalValue, 8, str],
#  [AmpKB.hasOutputSignalType, 6, owl.DatatypeProperty],
#  [AmpKB.hasOutputSignalType, 10, owl.topDataProperty],
#  [AmpKB.hasOutputSignalType, 7, AmpKB.Amplifier],
#  [AmpKB.hasOutputSignalType, 8, str],
#  [AmpKB.hasOutputType, 6, owl.DatatypeProperty],
#  [AmpKB.hasOutputType, 10, owl.topDataProperty],
#  [AmpKB.hasOutputType, 7, AmpKB.Amplifier],
#  [AmpKB.hasOutputType, 8, str],
#  [AmpKB.hasPinCount, 6, owl.DatatypeProperty],
#  [AmpKB.hasPinCount, 10, owl.topDataProperty],
#  [AmpKB.hasPinCount, 7, AmpKB.Amplifier],
#  [AmpKB.hasPinCount, 8, str],
#  [AmpKB.hasPowerSupplyType, 6, owl.DatatypeProperty],
#  [AmpKB.hasPowerSupplyType, 10, owl.topDataProperty],
#  [AmpKB.hasPowerSupplyType, 7, AmpKB.Amplifier],
#  [AmpKB.hasPowerSupplyType, 8, str],
#  [AmpKB.hasProcessTechnology, 6, owl.DatatypeProperty],
#  [AmpKB.hasProcessTechnology, 10, owl.topDataProperty],
#  [AmpKB.hasProcessTechnology, 7, AmpKB.Amplifier],
#  [AmpKB.hasProcessTechnology, 8, str],
#  [AmpKB.hasUnit, 6, owl.DatatypeProperty],
#  [AmpKB.hasUnit, 10, owl.topDataProperty],
#  [AmpKB.hasUnit, 7, AmpKB.CMRR],
#  [AmpKB.hasUnit, 7, AmpKB.DualSupplyVoltage],
#  [AmpKB.hasUnit, 7, AmpKB.Gain],
#  [AmpKB.hasUnit, 7, AmpKB.GainBandwidthProduct],
#  [AmpKB.hasUnit, 7, AmpKB.InputBiasCurrent],
#  [AmpKB.hasUnit, 7, AmpKB.NoiseFigure],
#  [AmpKB.hasUnit, 7, AmpKB.OperatingFrequency],
#  [AmpKB.hasUnit, 7, AmpKB.OperatingSupplyVoltage],
#  [AmpKB.hasUnit, 7, AmpKB.OperatingTemperature],
#  [AmpKB.hasUnit, 7, AmpKB.OutputCurrent],
#  [AmpKB.hasUnit, 7, AmpKB.PSRR],
#  [AmpKB.hasUnit, 7, AmpKB.PowerDissipation],
#  [AmpKB.hasUnit, 7, AmpKB.SingleSupplyVoltage],
#  [AmpKB.hasUnit, 7, AmpKB.SupplyCurrent],
#  [AmpKB.hasUnit, 7, AmpKB.SupplyVoltage],
#  [AmpKB.hasUnit, 8, str],
#  [AmpKB.hasUpperBoundNumericalValue, 6, owl.DatatypeProperty],
#  [AmpKB.hasUpperBoundNumericalValue, 10, owl.topDataProperty],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.CMRR],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.DualSupplyVoltage],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.Gain],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.GainBandwidthProduct],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.InputBiasCurrent],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.NoiseFigure],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.OperatingFrequency],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.OperatingSupplyVoltage],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.OperatingTemperature],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.OutputCurrent],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.PSRR],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.PowerDissipation],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.SingleSupplyVoltage],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.SupplyCurrent],
#  [AmpKB.hasUpperBoundNumericalValue, 7, AmpKB.SupplyVoltage],
#  [AmpKB.hasUpperBoundNumericalValue, 8, str],
#  [AmpKB.Amplifier, 6, 11],
#  [AmpKB.hasProperty.some(AmpKB.PSRR), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.PSRR), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.PSRR), 24, AmpKB.PSRR],
#  [AmpKB.Amplifier, 9, AmpKB.hasProperty.some(AmpKB.PSRR)],
#  [AmpKB.hasProperty.some(AmpKB.PowerDissipation), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.PowerDissipation), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.PowerDissipation), 24, AmpKB.PowerDissipation],
#  [AmpKB.Amplifier, 9, AmpKB.hasProperty.some(AmpKB.PowerDissipation)],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage),
#   24,
#   AmpKB.SingleSupplyVoltage],
#  [AmpKB.Amplifier, 9, AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage)],
#  [AmpKB.hasProperty.some(AmpKB.SupplyCurrent), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.SupplyCurrent), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.SupplyCurrent), 24, AmpKB.SupplyCurrent],
#  [AmpKB.Amplifier, 9, AmpKB.hasProperty.some(AmpKB.SupplyCurrent)],
#  [AmpKB.hasProperty.some(AmpKB.SupplyVoltage), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.SupplyVoltage), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.SupplyVoltage), 24, AmpKB.SupplyVoltage],
#  [AmpKB.Amplifier, 9, AmpKB.hasProperty.some(AmpKB.SupplyVoltage)],
#  [AmpKB.AudioAmplifier, 6, 11],
#  [AmpKB.AudioAmplifier, 9, AmpKB.Amplifier],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature),
#   24,
#   AmpKB.OperatingTemperature],
#  [AmpKB.AudioAmplifier, 9, AmpKB.hasProperty.some(AmpKB.OperatingTemperature)],
#  [AmpKB.hasProperty.some(AmpKB.PowerDissipation), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.PowerDissipation), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.PowerDissipation), 24, AmpKB.PowerDissipation],
#  [AmpKB.AudioAmplifier, 9, AmpKB.hasProperty.some(AmpKB.PowerDissipation)],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage),
#   24,
#   AmpKB.SingleSupplyVoltage],
#  [AmpKB.AudioAmplifier, 9, AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage)],
#  [AmpKB.hasInputSignalType.some(<class 'str'>), 6, 17],
#  [AmpKB.hasInputSignalType.some(<class 'str'>), 18, AmpKB.hasInputSignalType],
#  [AmpKB.hasInputSignalType.some(<class 'str'>), 24, str],
#  [AmpKB.AudioAmplifier, 9, AmpKB.hasInputSignalType.some(<class 'str'>)],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 6, 17],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 18, AmpKB.hasManufacturer],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 24, str],
#  [AmpKB.AudioAmplifier, 9, AmpKB.hasManufacturer.some(<class 'str'>)],
#  [AmpKB.hasOutputSignalType.some(<class 'str'>), 6, 17],
#  [AmpKB.hasOutputSignalType.some(<class 'str'>),
#   18,
#   AmpKB.hasOutputSignalType],
#  [AmpKB.hasOutputSignalType.some(<class 'str'>), 24, str],
#  [AmpKB.AudioAmplifier, 9, AmpKB.hasOutputSignalType.some(<class 'str'>)],
#  [AmpKB.hasOutputType.some(<class 'str'>), 6, 17],
#  [AmpKB.hasOutputType.some(<class 'str'>), 18, AmpKB.hasOutputType],
#  [AmpKB.hasOutputType.some(<class 'str'>), 24, str],
#  [AmpKB.AudioAmplifier, 9, AmpKB.hasOutputType.some(<class 'str'>)],
#  [AmpKB.hasPinCount.some(<class 'str'>), 6, 17],
#  [AmpKB.hasPinCount.some(<class 'str'>), 18, AmpKB.hasPinCount],
#  [AmpKB.hasPinCount.some(<class 'str'>), 24, str],
#  [AmpKB.AudioAmplifier, 9, AmpKB.hasPinCount.some(<class 'str'>)],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 6, 17],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 18, AmpKB.hasPowerSupplyType],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 24, str],
#  [AmpKB.AudioAmplifier, 9, AmpKB.hasPowerSupplyType.some(<class 'str'>)],
#  [AmpKB.AutoZeroOperationalAmplifier, 6, 11],
#  [AmpKB.AutoZeroOperationalAmplifier, 9, AmpKB.OperationalAmplifier],
#  [AmpKB.CMRR, 6, 11],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasLowerBoundNumericalValue],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.CMRR, 9, AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.CMRR, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.ChopperOperationalAmplifier, 6, 11],
#  [AmpKB.ChopperOperationalAmplifier, 9, AmpKB.OperationalAmplifier],
#  [AmpKB.ClassAB, 6, 11],
#  [AmpKB.ClassAB, 9, AmpKB.AudioAmplifier],
#  [AmpKB.ClassD, 6, 11],
#  [AmpKB.ClassD, 9, AmpKB.AudioAmplifier],
#  [AmpKB.ClassG, 6, 11],
#  [AmpKB.ClassG, 9, AmpKB.AudioAmplifier],
#  [AmpKB.DualInstrumentalAmplifier, 6, 11],
#  [AmpKB.DualInstrumentalAmplifier, 9, AmpKB.InstrumentalAmplifier],
#  [AmpKB.DualInstrumentalAmplifier, 88, AmpKB.SingleInstrumentalAmplifier],
#  [AmpKB.DualSupplyVoltage, 6, 11],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 18, AmpKB.hasNumericalValue],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.DualSupplyVoltage, 9, AmpKB.hasNumericalValue.some(<class 'str'>)],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.DualSupplyVoltage, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.DualVideoAmplifier, 6, 11],
#  [AmpKB.DualVideoAmplifier, 9, AmpKB.VideoAmplifier],
#  [AmpKB.GPSAmplifier, 6, 11],
#  [AmpKB.GPSAmplifier, 9, AmpKB.Amplifier],
#  [AmpKB.hasProperty.some(AmpKB.Gain), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.Gain), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.Gain), 24, AmpKB.Gain],
#  [AmpKB.GPSAmplifier, 9, AmpKB.hasProperty.some(AmpKB.Gain)],
#  [AmpKB.hasProperty.some(AmpKB.OperatingFrequency), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.OperatingFrequency), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.OperatingFrequency),
#   24,
#   AmpKB.OperatingFrequency],
#  [AmpKB.GPSAmplifier, 9, AmpKB.hasProperty.some(AmpKB.OperatingFrequency)],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature),
#   24,
#   AmpKB.OperatingTemperature],
#  [AmpKB.GPSAmplifier, 9, AmpKB.hasProperty.some(AmpKB.OperatingTemperature)],
#  [AmpKB.hasProperty.some(AmpKB.PowerDissipation), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.PowerDissipation), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.PowerDissipation), 24, AmpKB.PowerDissipation],
#  [AmpKB.GPSAmplifier, 9, AmpKB.hasProperty.some(AmpKB.PowerDissipation)],
#  [AmpKB.hasProperty.some(AmpKB.SupplyCurrent), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.SupplyCurrent), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.SupplyCurrent), 24, AmpKB.SupplyCurrent],
#  [AmpKB.GPSAmplifier, 9, AmpKB.hasProperty.some(AmpKB.SupplyCurrent)],
#  [AmpKB.hasProperty.some(AmpKB.SupplyVoltage), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.SupplyVoltage), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.SupplyVoltage), 24, AmpKB.SupplyVoltage],
#  [AmpKB.GPSAmplifier, 9, AmpKB.hasProperty.some(AmpKB.SupplyVoltage)],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 6, 17],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 18, AmpKB.hasManufacturer],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 24, str],
#  [AmpKB.GPSAmplifier, 9, AmpKB.hasManufacturer.some(<class 'str'>)],
#  [AmpKB.hasPinCount.some(<class 'str'>), 6, 17],
#  [AmpKB.hasPinCount.some(<class 'str'>), 18, AmpKB.hasPinCount],
#  [AmpKB.hasPinCount.some(<class 'str'>), 24, str],
#  [AmpKB.GPSAmplifier, 9, AmpKB.hasPinCount.some(<class 'str'>)],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 6, 17],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 18, AmpKB.hasPowerSupplyType],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 24, str],
#  [AmpKB.GPSAmplifier, 9, AmpKB.hasPowerSupplyType.some(<class 'str'>)],
#  [AmpKB.hasProcessTechnology.some(<class 'str'>), 6, 17],
#  [AmpKB.hasProcessTechnology.some(<class 'str'>),
#   18,
#   AmpKB.hasProcessTechnology],
#  [AmpKB.hasProcessTechnology.some(<class 'str'>), 24, str],
#  [AmpKB.GPSAmplifier, 9, AmpKB.hasProcessTechnology.some(<class 'str'>)],
#  [AmpKB.Gain, 6, 11],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.Gain, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasUpperBoundNumericalValue],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.Gain, 9, AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.GainBandwidthProduct, 6, 11],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 18, AmpKB.hasNumericalValue],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.GainBandwidthProduct, 9, AmpKB.hasNumericalValue.some(<class 'str'>)],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.GainBandwidthProduct, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.GeneralPurposeOperationalAmplifier, 6, 11],
#  [AmpKB.GeneralPurposeOperationalAmplifier, 9, AmpKB.OperationalAmplifier],
#  [AmpKB.HexVideoAmplifier, 6, 11],
#  [AmpKB.HexVideoAmplifier, 9, AmpKB.VideoAmplifier],
#  [AmpKB.HighSpeedOperationalAmplifier, 6, 11],
#  [AmpKB.HighSpeedOperationalAmplifier, 9, AmpKB.OperationalAmplifier],
#  [AmpKB.InputBiasCurrent, 6, 11],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.InputBiasCurrent, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasUpperBoundNumericalValue],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.InputBiasCurrent,
#   9,
#   AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.InstrumentalAmplifier, 6, 11],
#  [AmpKB.InstrumentalAmplifier, 9, AmpKB.Amplifier],
#  [AmpKB.hasProperty.some(AmpKB.CMRR), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.CMRR), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.CMRR), 24, AmpKB.CMRR],
#  [AmpKB.InstrumentalAmplifier, 9, AmpKB.hasProperty.some(AmpKB.CMRR)],
#  [AmpKB.hasProperty.some(AmpKB.DualSupplyVoltage), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.DualSupplyVoltage), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.DualSupplyVoltage),
#   24,
#   AmpKB.DualSupplyVoltage],
#  [AmpKB.InstrumentalAmplifier,
#   9,
#   AmpKB.hasProperty.some(AmpKB.DualSupplyVoltage)],
#  [AmpKB.hasProperty.some(AmpKB.InputBiasCurrent), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.InputBiasCurrent), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.InputBiasCurrent), 24, AmpKB.InputBiasCurrent],
#  [AmpKB.InstrumentalAmplifier,
#   9,
#   AmpKB.hasProperty.some(AmpKB.InputBiasCurrent)],
#  [AmpKB.hasProperty.some(AmpKB.OperatingSupplyVoltage), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.OperatingSupplyVoltage), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.OperatingSupplyVoltage),
#   24,
#   AmpKB.OperatingSupplyVoltage],
#  [AmpKB.InstrumentalAmplifier,
#   9,
#   AmpKB.hasProperty.some(AmpKB.OperatingSupplyVoltage)],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature),
#   24,
#   AmpKB.OperatingTemperature],
#  [AmpKB.InstrumentalAmplifier,
#   9,
#   AmpKB.hasProperty.some(AmpKB.OperatingTemperature)],
#  [AmpKB.hasProperty.some(AmpKB.PSRR), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.PSRR), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.PSRR), 24, AmpKB.PSRR],
#  [AmpKB.InstrumentalAmplifier, 9, AmpKB.hasProperty.some(AmpKB.PSRR)],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage),
#   24,
#   AmpKB.SingleSupplyVoltage],
#  [AmpKB.InstrumentalAmplifier,
#   9,
#   AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage)],
#  [AmpKB.hasProperty.some(AmpKB.SupplyVoltage), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.SupplyVoltage), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.SupplyVoltage), 24, AmpKB.SupplyVoltage],
#  [AmpKB.InstrumentalAmplifier, 9, AmpKB.hasProperty.some(AmpKB.SupplyVoltage)],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 6, 17],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 18, AmpKB.hasManufacturer],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 24, str],
#  [AmpKB.InstrumentalAmplifier, 9, AmpKB.hasManufacturer.some(<class 'str'>)],
#  [AmpKB.hasPinCount.some(<class 'str'>), 6, 17],
#  [AmpKB.hasPinCount.some(<class 'str'>), 18, AmpKB.hasPinCount],
#  [AmpKB.hasPinCount.some(<class 'str'>), 24, str],
#  [AmpKB.InstrumentalAmplifier, 9, AmpKB.hasPinCount.some(<class 'str'>)],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 6, 17],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 18, AmpKB.hasPowerSupplyType],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 24, str],
#  [AmpKB.InstrumentalAmplifier,
#   9,
#   AmpKB.hasPowerSupplyType.some(<class 'str'>)],
#  [AmpKB.LowNoiseGPSAmplifier, 6, 11],
#  [AmpKB.LowNoiseGPSAmplifier, 9, AmpKB.GPSAmplifier],
#  [AmpKB.LowNoiseOperationalAmplifier, 6, 11],
#  [AmpKB.LowNoiseOperationalAmplifier, 9, AmpKB.OperationalAmplifier],
#  [AmpKB.LowOffsetVoltageOperationalAmplifier, 6, 11],
#  [AmpKB.LowOffsetVoltageOperationalAmplifier, 9, AmpKB.OperationalAmplifier],
#  [AmpKB.MicropowerOperationalAmplifier, 6, 11],
#  [AmpKB.MicropowerOperationalAmplifier, 9, AmpKB.OperationalAmplifier],
#  [AmpKB.NoiseFigure, 6, 11],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 18, AmpKB.hasNumericalValue],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.NoiseFigure, 9, AmpKB.hasNumericalValue.some(<class 'str'>)],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.NoiseFigure, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.OperatingFrequency, 6, 11],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasLowerBoundNumericalValue],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.OperatingFrequency,
#   9,
#   AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.OperatingFrequency, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasUpperBoundNumericalValue],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.OperatingFrequency,
#   9,
#   AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.OperatingSupplyVoltage, 6, 11],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.OperatingSupplyVoltage, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasUpperBoundNumericalValue],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.OperatingSupplyVoltage,
#   9,
#   AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.OperatingTemperature, 6, 11],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasLowerBoundNumericalValue],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.OperatingTemperature,
#   9,
#   AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.OperatingTemperature, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasUpperBoundNumericalValue],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.OperatingTemperature,
#   9,
#   AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.OperationalAmplifier, 6, 11],
#  [AmpKB.OperationalAmplifier, 9, AmpKB.Amplifier],
#  [AmpKB.hasProperty.some(AmpKB.CMRR), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.CMRR), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.CMRR), 24, AmpKB.CMRR],
#  [AmpKB.OperationalAmplifier, 9, AmpKB.hasProperty.some(AmpKB.CMRR)],
#  [AmpKB.hasProperty.some(AmpKB.GainBandwidthProduct), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.GainBandwidthProduct), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.GainBandwidthProduct),
#   24,
#   AmpKB.GainBandwidthProduct],
#  [AmpKB.OperationalAmplifier,
#   9,
#   AmpKB.hasProperty.some(AmpKB.GainBandwidthProduct)],
#  [AmpKB.hasProperty.some(AmpKB.InputBiasCurrent), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.InputBiasCurrent), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.InputBiasCurrent), 24, AmpKB.InputBiasCurrent],
#  [AmpKB.OperationalAmplifier,
#   9,
#   AmpKB.hasProperty.some(AmpKB.InputBiasCurrent)],
#  [AmpKB.hasProperty.some(AmpKB.OperatingSupplyVoltage), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.OperatingSupplyVoltage), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.OperatingSupplyVoltage),
#   24,
#   AmpKB.OperatingSupplyVoltage],
#  [AmpKB.OperationalAmplifier,
#   9,
#   AmpKB.hasProperty.some(AmpKB.OperatingSupplyVoltage)],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature),
#   24,
#   AmpKB.OperatingTemperature],
#  [AmpKB.OperationalAmplifier,
#   9,
#   AmpKB.hasProperty.some(AmpKB.OperatingTemperature)],
#  [AmpKB.hasProperty.some(AmpKB.OutputCurrent), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.OutputCurrent), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.OutputCurrent), 24, AmpKB.OutputCurrent],
#  [AmpKB.OperationalAmplifier, 9, AmpKB.hasProperty.some(AmpKB.OutputCurrent)],
#  [AmpKB.hasProperty.some(AmpKB.PSRR), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.PSRR), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.PSRR), 24, AmpKB.PSRR],
#  [AmpKB.OperationalAmplifier, 9, AmpKB.hasProperty.some(AmpKB.PSRR)],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage),
#   24,
#   AmpKB.SingleSupplyVoltage],
#  [AmpKB.OperationalAmplifier,
#   9,
#   AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage)],
#  [AmpKB.hasProperty.some(AmpKB.SupplyVoltage), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.SupplyVoltage), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.SupplyVoltage), 24, AmpKB.SupplyVoltage],
#  [AmpKB.OperationalAmplifier, 9, AmpKB.hasProperty.some(AmpKB.SupplyVoltage)],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 6, 17],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 18, AmpKB.hasManufacturer],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 24, str],
#  [AmpKB.OperationalAmplifier, 9, AmpKB.hasManufacturer.some(<class 'str'>)],
#  [AmpKB.hasPinCount.some(<class 'str'>), 6, 17],
#  [AmpKB.hasPinCount.some(<class 'str'>), 18, AmpKB.hasPinCount],
#  [AmpKB.hasPinCount.some(<class 'str'>), 24, str],
#  [AmpKB.OperationalAmplifier, 9, AmpKB.hasPinCount.some(<class 'str'>)],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 6, 17],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 18, AmpKB.hasPowerSupplyType],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 24, str],
#  [AmpKB.OperationalAmplifier, 9, AmpKB.hasPowerSupplyType.some(<class 'str'>)],
#  [AmpKB.hasProcessTechnology.some(<class 'str'>), 6, 17],
#  [AmpKB.hasProcessTechnology.some(<class 'str'>),
#   18,
#   AmpKB.hasProcessTechnology],
#  [AmpKB.hasProcessTechnology.some(<class 'str'>), 24, str],
#  [AmpKB.OperationalAmplifier,
#   9,
#   AmpKB.hasProcessTechnology.some(<class 'str'>)],
#  [AmpKB.OutputCurrent, 6, 11],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 18, AmpKB.hasNumericalValue],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.OutputCurrent, 9, AmpKB.hasNumericalValue.some(<class 'str'>)],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.OutputCurrent, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.PSRR, 6, 11],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasLowerBoundNumericalValue],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.PSRR, 9, AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.PSRR, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.PowerDissipation, 6, 11],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.PowerDissipation, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasUpperBoundNumericalValue],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.PowerDissipation,
#   9,
#   AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.PrecisionOperationalAmplifier, 6, 11],
#  [AmpKB.PrecisionOperationalAmplifier, 9, AmpKB.OperationalAmplifier],
#  [AmpKB.QuadVideoAmplifier, 6, 11],
#  [AmpKB.QuadVideoAmplifier, 9, AmpKB.VideoAmplifier],
#  [AmpKB.SingleInstrumentalAmplifier, 6, 11],
#  [AmpKB.SingleInstrumentalAmplifier, 9, AmpKB.InstrumentalAmplifier],
#  [AmpKB.SingleSupplyVoltage, 6, 11],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasLowerBoundNumericalValue],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.SingleSupplyVoltage,
#   9,
#   AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 18, AmpKB.hasNumericalValue],
#  [AmpKB.hasNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.SingleSupplyVoltage, 9, AmpKB.hasNumericalValue.some(<class 'str'>)],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.SingleSupplyVoltage, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasUpperBoundNumericalValue],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.SingleSupplyVoltage,
#   9,
#   AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.SingleVideoAmplifier, 6, 11],
#  [AmpKB.SingleVideoAmplifier, 9, AmpKB.VideoAmplifier],
#  [AmpKB.SupplyCurrent, 6, 11],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.SupplyCurrent, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasUpperBoundNumericalValue],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.SupplyCurrent,
#   9,
#   AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.SupplyVoltage, 6, 11],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasLowerBoundNumericalValue],
#  [AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.SupplyVoltage,
#   9,
#   AmpKB.hasLowerBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.hasUnit.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUnit.some(<class 'str'>), 18, AmpKB.hasUnit],
#  [AmpKB.hasUnit.some(<class 'str'>), 24, str],
#  [AmpKB.SupplyVoltage, 9, AmpKB.hasUnit.some(<class 'str'>)],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 6, 17],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>),
#   18,
#   AmpKB.hasUpperBoundNumericalValue],
#  [AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>), 24, str],
#  [AmpKB.SupplyVoltage,
#   9,
#   AmpKB.hasUpperBoundNumericalValue.some(<class 'str'>)],
#  [AmpKB.TripleVideoAmplifier, 6, 11],
#  [AmpKB.TripleVideoAmplifier, 9, AmpKB.VideoAmplifier],
#  [AmpKB.VideoAmplifier, 6, 11],
#  [AmpKB.VideoAmplifier, 9, AmpKB.Amplifier],
#  [AmpKB.hasProperty.some(AmpKB.DualSupplyVoltage), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.DualSupplyVoltage), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.DualSupplyVoltage),
#   24,
#   AmpKB.DualSupplyVoltage],
#  [AmpKB.VideoAmplifier, 9, AmpKB.hasProperty.some(AmpKB.DualSupplyVoltage)],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.OperatingTemperature),
#   24,
#   AmpKB.OperatingTemperature],
#  [AmpKB.VideoAmplifier, 9, AmpKB.hasProperty.some(AmpKB.OperatingTemperature)],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage), 6, 17],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage), 18, AmpKB.hasProperty],
#  [AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage),
#   24,
#   AmpKB.SingleSupplyVoltage],
#  [AmpKB.VideoAmplifier, 9, AmpKB.hasProperty.some(AmpKB.SingleSupplyVoltage)],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 6, 17],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 18, AmpKB.hasManufacturer],
#  [AmpKB.hasManufacturer.some(<class 'str'>), 24, str],
#  [AmpKB.VideoAmplifier, 9, AmpKB.hasManufacturer.some(<class 'str'>)],
#  [AmpKB.hasPinCount.some(<class 'str'>), 6, 17],
#  [AmpKB.hasPinCount.some(<class 'str'>), 18, AmpKB.hasPinCount],
#  [AmpKB.hasPinCount.some(<class 'str'>), 24, str],
#  [AmpKB.VideoAmplifier, 9, AmpKB.hasPinCount.some(<class 'str'>)],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 6, 17],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 18, AmpKB.hasPowerSupplyType],
#  [AmpKB.hasPowerSupplyType.some(<class 'str'>), 24, str],
#  [AmpKB.VideoAmplifier, 9, AmpKB.hasPowerSupplyType.some(<class 'str'>)],
#  [AmpKB.WidebandOperationalAmplifier, 6, 11],
#  [AmpKB.WidebandOperationalAmplifier, 9, AmpKB.OperationalAmplifier],
#  [AmpKB.AD812ARZ, 6, owl.NamedIndividual],
#  [AmpKB.AD812ARZ, 6, AmpKB.DualVideoAmplifier],
#  [AmpKB.AD812ARZ, AmpKB.hasProperty, AmpKB.VIDEODSV5],
#  [AmpKB.AD812ARZ, AmpKB.hasProperty, AmpKB.VIDEOOT5],
#  [AmpKB.AD812ARZ, AmpKB.hasProperty, AmpKB.VIDEOSSV5],
#  [AmpKB.AUDIOOT1, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOOT1, 6, AmpKB.OperatingTemperature],
#  [AmpKB.AUDIOOT10, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOOT10, 6, AmpKB.OperatingTemperature],
#  [AmpKB.AUDIOOT2, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOOT2, 6, AmpKB.OperatingTemperature],
#  [AmpKB.AUDIOOT3, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOOT3, 6, AmpKB.OperatingTemperature],
#  [AmpKB.AUDIOOT4, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOOT4, 6, AmpKB.OperatingTemperature],
#  [AmpKB.AUDIOOT5, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOOT5, 6, AmpKB.OperatingTemperature],
#  [AmpKB.AUDIOOT6, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOOT6, 6, AmpKB.OperatingTemperature],
#  [AmpKB.AUDIOOT7, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOOT7, 6, AmpKB.OperatingTemperature],
#  [AmpKB.AUDIOOT8, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOOT8, 6, AmpKB.OperatingTemperature],
#  [AmpKB.AUDIOOT9, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOOT9, 6, AmpKB.OperatingTemperature],
#  [AmpKB.AUDIOPD1, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOPD1, 6, AmpKB.PowerDissipation],
#  [AmpKB.AUDIOPD10, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOPD10, 6, AmpKB.PowerDissipation],
#  [AmpKB.AUDIOPD2, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOPD2, 6, AmpKB.PowerDissipation],
#  [AmpKB.AUDIOPD3, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOPD3, 6, AmpKB.PowerDissipation],
#  [AmpKB.AUDIOPD4, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOPD4, 6, AmpKB.PowerDissipation],
#  [AmpKB.AUDIOPD5, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOPD5, 6, AmpKB.PowerDissipation],
#  [AmpKB.AUDIOPD6, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOPD6, 6, AmpKB.PowerDissipation],
#  [AmpKB.AUDIOPD7, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOPD7, 6, AmpKB.PowerDissipation],
#  [AmpKB.AUDIOPD8, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOPD8, 6, AmpKB.PowerDissipation],
#  [AmpKB.AUDIOPD9, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOPD9, 6, AmpKB.PowerDissipation],
#  [AmpKB.AUDIOSV1, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOSV1, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.AUDIOSV10, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOSV10, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.AUDIOSV2, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOSV2, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.AUDIOSV3, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOSV3, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.AUDIOSV4, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOSV4, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.AUDIOSV5, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOSV5, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.AUDIOSV6, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOSV6, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.AUDIOSV7, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOSV7, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.AUDIOSV8, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOSV8, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.AUDIOSV9, 6, owl.NamedIndividual],
#  [AmpKB.AUDIOSV9, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.BD28623MUV-E2, 6, owl.NamedIndividual],
#  [AmpKB.BD28623MUV-E2, 6, AmpKB.ClassD],
#  [AmpKB.BD28623MUV-E2, AmpKB.hasProperty, AmpKB.AUDIOOT3],
#  [AmpKB.BD28623MUV-E2, AmpKB.hasProperty, AmpKB.AUDIOPD3],
#  [AmpKB.BD28623MUV-E2, AmpKB.hasProperty, AmpKB.AUDIOSV3],
#  [AmpKB.BGA123L4E6327XTSA1, 6, owl.NamedIndividual],
#  [AmpKB.BGA123L4E6327XTSA1, 6, AmpKB.LowNoiseGPSAmplifier],
#  [AmpKB.BGA123L4E6327XTSA1, AmpKB.hasProperty, AmpKB.GPSGain2],
#  [AmpKB.BGA123L4E6327XTSA1, AmpKB.hasProperty, AmpKB.GPSNF2],
#  [AmpKB.BGA123L4E6327XTSA1, AmpKB.hasProperty, AmpKB.GPSOF2],
#  [AmpKB.BGA123L4E6327XTSA1, AmpKB.hasProperty, AmpKB.GPSOT2],
#  [AmpKB.BGA123L4E6327XTSA1, AmpKB.hasProperty, AmpKB.GPSPD2],
#  [AmpKB.BGA123L4E6327XTSA1, AmpKB.hasProperty, AmpKB.GPSSC2],
#  [AmpKB.BGA123L4E6327XTSA1, AmpKB.hasProperty, AmpKB.GPSSV2],
#  [AmpKB.BGA524N6E6327XTSA1, 6, owl.NamedIndividual],
#  [AmpKB.BGA524N6E6327XTSA1, 6, AmpKB.LowNoiseGPSAmplifier],
#  [AmpKB.BGA524N6E6327XTSA1, AmpKB.hasProperty, AmpKB.GPSGain9],
#  [AmpKB.BGA524N6E6327XTSA1, AmpKB.hasProperty, AmpKB.GPSNF9],
#  [AmpKB.BGA524N6E6327XTSA1, AmpKB.hasProperty, AmpKB.GPSOF9],
#  [AmpKB.BGA524N6E6327XTSA1, AmpKB.hasProperty, AmpKB.GPSOT9],
#  [AmpKB.BGA524N6E6327XTSA1, AmpKB.hasProperty, AmpKB.GPSPD9],
#  [AmpKB.BGA524N6E6327XTSA1, AmpKB.hasProperty, AmpKB.GPSSC9],
#  [AmpKB.BGA524N6E6327XTSA1, AmpKB.hasProperty, AmpKB.GPSSV9],
#  [AmpKB.BGA715N7E6327XTSA2, 6, owl.NamedIndividual],
#  [AmpKB.BGA715N7E6327XTSA2, 6, AmpKB.LowNoiseGPSAmplifier],
#  [AmpKB.BGA715N7E6327XTSA2, AmpKB.hasProperty, AmpKB.GPSGain3],
#  [AmpKB.BGA715N7E6327XTSA2, AmpKB.hasProperty, AmpKB.GPSNF3],
#  [AmpKB.BGA715N7E6327XTSA2, AmpKB.hasProperty, AmpKB.GPSOF3],
#  [AmpKB.BGA715N7E6327XTSA2, AmpKB.hasProperty, AmpKB.GPSOT3],
#  [AmpKB.BGA715N7E6327XTSA2, AmpKB.hasProperty, AmpKB.GPSPD3],
#  [AmpKB.BGA715N7E6327XTSA2, AmpKB.hasProperty, AmpKB.GPSSC3],
#  [AmpKB.BGA715N7E6327XTSA2, AmpKB.hasProperty, AmpKB.GPSSV3],
#  [AmpKB.BGA725L6E6327FTSA1, 6, owl.NamedIndividual],
#  [AmpKB.BGA725L6E6327FTSA1, 6, AmpKB.LowNoiseGPSAmplifier],
#  [AmpKB.BGA725L6E6327FTSA1, AmpKB.hasProperty, AmpKB.GPSGain1],
#  [AmpKB.BGA725L6E6327FTSA1, AmpKB.hasProperty, AmpKB.GPSNF1],
#  [AmpKB.BGA725L6E6327FTSA1, AmpKB.hasProperty, AmpKB.GPSOF1],
#  [AmpKB.BGA725L6E6327FTSA1, AmpKB.hasProperty, AmpKB.GPSOT1],
#  [AmpKB.BGA725L6E6327FTSA1, AmpKB.hasProperty, AmpKB.GPSPD1],
#  [AmpKB.BGA725L6E6327FTSA1, AmpKB.hasProperty, AmpKB.GPSSC1],
#  [AmpKB.BGA725L6E6327FTSA1, AmpKB.hasProperty, AmpKB.GPSSV1],
#  [AmpKB.BGU7004-115, 6, owl.NamedIndividual],
#  [AmpKB.BGU7004-115, 6, AmpKB.LowNoiseGPSAmplifier],
#  [AmpKB.BGU7004-115, AmpKB.hasProperty, AmpKB.GPSGain8],
#  [AmpKB.BGU7004-115, AmpKB.hasProperty, AmpKB.GPSNF8],
#  [AmpKB.BGU7004-115, AmpKB.hasProperty, AmpKB.GPSOF8],
#  [AmpKB.BGU7004-115, AmpKB.hasProperty, AmpKB.GPSOT8],
#  [AmpKB.BGU7004-115, AmpKB.hasProperty, AmpKB.GPSPD8],
#  [AmpKB.BGU7004-115, AmpKB.hasProperty, AmpKB.GPSSC8],
#  [AmpKB.BGU7004-115, AmpKB.hasProperty, AmpKB.GPSSV8],
#  [AmpKB.BGU7005-115, 6, owl.NamedIndividual],
#  [AmpKB.BGU7005-115, 6, AmpKB.LowNoiseGPSAmplifier],
#  [AmpKB.BGU7005-115, AmpKB.hasProperty, AmpKB.GPSGain10],
#  [AmpKB.BGU7005-115, AmpKB.hasProperty, AmpKB.GPSNF10],
#  [AmpKB.BGU7005-115, AmpKB.hasProperty, AmpKB.GPSOF10],
#  [AmpKB.BGU7005-115, AmpKB.hasProperty, AmpKB.GPSOT10],
#  [AmpKB.BGU7005-115, AmpKB.hasProperty, AmpKB.GPSPD10],
#  [AmpKB.BGU7005-115, AmpKB.hasProperty, AmpKB.GPSSC10],
#  [AmpKB.BGU7005-115, AmpKB.hasProperty, AmpKB.GPSSV10],
#  [AmpKB.BGU7007-115, 6, owl.NamedIndividual],
#  [AmpKB.BGU7007-115, 6, AmpKB.LowNoiseGPSAmplifier],
#  [AmpKB.BGU7007-115, AmpKB.hasProperty, AmpKB.GPSGain6],
#  [AmpKB.BGU7007-115, AmpKB.hasProperty, AmpKB.GPSNF6],
#  [AmpKB.BGU7007-115, AmpKB.hasProperty, AmpKB.GPSOF6],
#  [AmpKB.BGU7007-115, AmpKB.hasProperty, AmpKB.GPSOT6],
#  [AmpKB.BGU7007-115, AmpKB.hasProperty, AmpKB.GPSPD6],
#  [AmpKB.BGU7007-115, AmpKB.hasProperty, AmpKB.GPSSC6],
#  [AmpKB.BGU7007-115, AmpKB.hasProperty, AmpKB.GPSSV6],
#  [AmpKB.BGU7008-115, 6, owl.NamedIndividual],
#  [AmpKB.BGU7008-115, 6, AmpKB.LowNoiseGPSAmplifier],
#  [AmpKB.BGU7008-115, AmpKB.hasProperty, AmpKB.GPSGain7],
#  [AmpKB.BGU7008-115, AmpKB.hasProperty, AmpKB.GPSNF7],
#  [AmpKB.BGU7008-115, AmpKB.hasProperty, AmpKB.GPSOF7],
#  [AmpKB.BGU7008-115, AmpKB.hasProperty, AmpKB.GPSOT7],
#  [AmpKB.BGU7008-115, AmpKB.hasProperty, AmpKB.GPSPD7],
#  [AmpKB.BGU7008-115, AmpKB.hasProperty, AmpKB.GPSSC7],
#  [AmpKB.BGU7008-115, AmpKB.hasProperty, AmpKB.GPSSV7],
#  [AmpKB.BGU8019X, 6, owl.NamedIndividual],
#  [AmpKB.BGU8019X, 6, AmpKB.LowNoiseGPSAmplifier],
#  [AmpKB.BGU8019X, AmpKB.hasProperty, AmpKB.GPSGain5],
#  [AmpKB.BGU8019X, AmpKB.hasProperty, AmpKB.GPSNF5],
#  [AmpKB.BGU8019X, AmpKB.hasProperty, AmpKB.GPSOF5],
#  [AmpKB.BGU8019X, AmpKB.hasProperty, AmpKB.GPSOT5],
#  [AmpKB.BGU8019X, AmpKB.hasProperty, AmpKB.GPSPD5],
#  [AmpKB.BGU8019X, AmpKB.hasProperty, AmpKB.GPSSC5],
#  [AmpKB.BGU8019X, AmpKB.hasProperty, AmpKB.GPSSV5],
#  [AmpKB.BGU8103X, 6, owl.NamedIndividual],
#  [AmpKB.BGU8103X, 6, AmpKB.LowNoiseGPSAmplifier],
#  [AmpKB.BGU8103X, AmpKB.hasProperty, AmpKB.GPSGain4],
#  [AmpKB.BGU8103X, AmpKB.hasProperty, AmpKB.GPSNF4],
#  [AmpKB.BGU8103X, AmpKB.hasProperty, AmpKB.GPSOF4],
#  [AmpKB.BGU8103X, AmpKB.hasProperty, AmpKB.GPSOT4],
#  [AmpKB.BGU8103X, AmpKB.hasProperty, AmpKB.GPSPD4],
#  [AmpKB.BGU8103X, AmpKB.hasProperty, AmpKB.GPSSC4],
#  [AmpKB.BGU8103X, AmpKB.hasProperty, AmpKB.GPSSV4],
#  [AmpKB.BM28723AMUV-E2, 6, owl.NamedIndividual],
#  [AmpKB.BM28723AMUV-E2, 6, AmpKB.ClassD],
#  [AmpKB.BM28723AMUV-E2, AmpKB.hasProperty, AmpKB.AUDIOOT8],
#  [AmpKB.BM28723AMUV-E2, AmpKB.hasProperty, AmpKB.AUDIOPD8],
#  [AmpKB.BM28723AMUV-E2, AmpKB.hasProperty, AmpKB.AUDIOSV8],
#  [AmpKB.GPSGain1, 6, owl.NamedIndividual],
#  [AmpKB.GPSGain1, 6, AmpKB.Gain],
#  [AmpKB.GPSGain10, 6, owl.NamedIndividual],
#  [AmpKB.GPSGain10, 6, AmpKB.Gain],
#  [AmpKB.GPSGain2, 6, owl.NamedIndividual],
#  [AmpKB.GPSGain2, 6, AmpKB.Gain],
#  [AmpKB.GPSGain3, 6, owl.NamedIndividual],
#  [AmpKB.GPSGain3, 6, AmpKB.Gain],
#  [AmpKB.GPSGain4, 6, owl.NamedIndividual],
#  [AmpKB.GPSGain4, 6, AmpKB.Gain],
#  [AmpKB.GPSGain5, 6, owl.NamedIndividual],
#  [AmpKB.GPSGain5, 6, AmpKB.Gain],
#  [AmpKB.GPSGain6, 6, owl.NamedIndividual],
#  [AmpKB.GPSGain6, 6, AmpKB.Gain],
#  [AmpKB.GPSGain7, 6, owl.NamedIndividual],
#  [AmpKB.GPSGain7, 6, AmpKB.Gain],
#  [AmpKB.GPSGain8, 6, owl.NamedIndividual],
#  [AmpKB.GPSGain8, 6, AmpKB.Gain],
#  [AmpKB.GPSGain9, 6, owl.NamedIndividual],
#  [AmpKB.GPSGain9, 6, AmpKB.Gain],
#  [AmpKB.GPSNF1, 6, owl.NamedIndividual],
#  [AmpKB.GPSNF1, 6, AmpKB.NoiseFigure],
#  [AmpKB.GPSNF10, 6, owl.NamedIndividual],
#  [AmpKB.GPSNF10, 6, AmpKB.NoiseFigure],
#  [AmpKB.GPSNF2, 6, owl.NamedIndividual],
#  [AmpKB.GPSNF2, 6, AmpKB.NoiseFigure],
#  [AmpKB.GPSNF3, 6, owl.NamedIndividual],
#  [AmpKB.GPSNF3, 6, AmpKB.NoiseFigure],
#  [AmpKB.GPSNF4, 6, owl.NamedIndividual],
#  [AmpKB.GPSNF4, 6, AmpKB.NoiseFigure],
#  [AmpKB.GPSNF5, 6, owl.NamedIndividual],
#  [AmpKB.GPSNF5, 6, AmpKB.NoiseFigure],
#  [AmpKB.GPSNF6, 6, owl.NamedIndividual],
#  [AmpKB.GPSNF6, 6, AmpKB.NoiseFigure],
#  [AmpKB.GPSNF7, 6, owl.NamedIndividual],
#  [AmpKB.GPSNF7, 6, AmpKB.NoiseFigure],
#  [AmpKB.GPSNF8, 6, owl.NamedIndividual],
#  [AmpKB.GPSNF8, 6, AmpKB.NoiseFigure],
#  [AmpKB.GPSNF9, 6, owl.NamedIndividual],
#  [AmpKB.GPSNF9, 6, AmpKB.NoiseFigure],
#  [AmpKB.GPSOF1, 6, owl.NamedIndividual],
#  [AmpKB.GPSOF1, 6, AmpKB.OperatingFrequency],
#  [AmpKB.GPSOF10, 6, owl.NamedIndividual],
#  [AmpKB.GPSOF10, 6, AmpKB.OperatingFrequency],
#  [AmpKB.GPSOF2, 6, owl.NamedIndividual],
#  [AmpKB.GPSOF2, 6, AmpKB.OperatingFrequency],
#  [AmpKB.GPSOF3, 6, owl.NamedIndividual],
#  [AmpKB.GPSOF3, 6, AmpKB.OperatingFrequency],
#  [AmpKB.GPSOF4, 6, owl.NamedIndividual],
#  [AmpKB.GPSOF4, 6, AmpKB.OperatingFrequency],
#  [AmpKB.GPSOF5, 6, owl.NamedIndividual],
#  [AmpKB.GPSOF5, 6, AmpKB.OperatingFrequency],
#  [AmpKB.GPSOF6, 6, owl.NamedIndividual],
#  [AmpKB.GPSOF6, 6, AmpKB.OperatingFrequency],
#  [AmpKB.GPSOF7, 6, owl.NamedIndividual],
#  [AmpKB.GPSOF7, 6, AmpKB.OperatingFrequency],
#  [AmpKB.GPSOF8, 6, owl.NamedIndividual],
#  [AmpKB.GPSOF8, 6, AmpKB.OperatingFrequency],
#  [AmpKB.GPSOF9, 6, owl.NamedIndividual],
#  [AmpKB.GPSOF9, 6, AmpKB.OperatingFrequency],
#  [AmpKB.GPSOT1, 6, owl.NamedIndividual],
#  [AmpKB.GPSOT1, 6, AmpKB.OperatingTemperature],
#  [AmpKB.GPSOT10, 6, owl.NamedIndividual],
#  [AmpKB.GPSOT10, 6, AmpKB.OperatingTemperature],
#  [AmpKB.GPSOT2, 6, owl.NamedIndividual],
#  [AmpKB.GPSOT2, 6, AmpKB.OperatingTemperature],
#  [AmpKB.GPSOT3, 6, owl.NamedIndividual],
#  [AmpKB.GPSOT3, 6, AmpKB.OperatingTemperature],
#  [AmpKB.GPSOT4, 6, owl.NamedIndividual],
#  [AmpKB.GPSOT4, 6, AmpKB.OperatingTemperature],
#  [AmpKB.GPSOT5, 6, owl.NamedIndividual],
#  [AmpKB.GPSOT5, 6, AmpKB.OperatingTemperature],
#  [AmpKB.GPSOT6, 6, owl.NamedIndividual],
#  [AmpKB.GPSOT6, 6, AmpKB.OperatingTemperature],
#  [AmpKB.GPSOT7, 6, owl.NamedIndividual],
#  [AmpKB.GPSOT7, 6, AmpKB.OperatingTemperature],
#  [AmpKB.GPSOT8, 6, owl.NamedIndividual],
#  [AmpKB.GPSOT8, 6, AmpKB.OperatingTemperature],
#  [AmpKB.GPSOT9, 6, owl.NamedIndividual],
#  [AmpKB.GPSOT9, 6, AmpKB.OperatingTemperature],
#  [AmpKB.GPSPD1, 6, owl.NamedIndividual],
#  [AmpKB.GPSPD1, 6, AmpKB.PowerDissipation],
#  [AmpKB.GPSPD10, 6, owl.NamedIndividual],
#  [AmpKB.GPSPD10, 6, AmpKB.PowerDissipation],
#  [AmpKB.GPSPD2, 6, owl.NamedIndividual],
#  [AmpKB.GPSPD2, 6, AmpKB.PowerDissipation],
#  [AmpKB.GPSPD3, 6, owl.NamedIndividual],
#  [AmpKB.GPSPD3, 6, AmpKB.PowerDissipation],
#  [AmpKB.GPSPD4, 6, owl.NamedIndividual],
#  [AmpKB.GPSPD4, 6, AmpKB.PowerDissipation],
#  [AmpKB.GPSPD5, 6, owl.NamedIndividual],
#  [AmpKB.GPSPD5, 6, AmpKB.PowerDissipation],
#  [AmpKB.GPSPD6, 6, owl.NamedIndividual],
#  [AmpKB.GPSPD6, 6, AmpKB.PowerDissipation],
#  [AmpKB.GPSPD7, 6, owl.NamedIndividual],
#  [AmpKB.GPSPD7, 6, AmpKB.PowerDissipation],
#  [AmpKB.GPSPD8, 6, owl.NamedIndividual],
#  [AmpKB.GPSPD8, 6, AmpKB.PowerDissipation],
#  [AmpKB.GPSPD9, 6, owl.NamedIndividual],
#  [AmpKB.GPSPD9, 6, AmpKB.PowerDissipation],
#  [AmpKB.GPSSC1, 6, owl.NamedIndividual],
#  [AmpKB.GPSSC1, 6, AmpKB.SupplyCurrent],
#  [AmpKB.GPSSC10, 6, owl.NamedIndividual],
#  [AmpKB.GPSSC10, 6, AmpKB.SupplyCurrent],
#  [AmpKB.GPSSC2, 6, owl.NamedIndividual],
#  [AmpKB.GPSSC2, 6, AmpKB.SupplyCurrent],
#  [AmpKB.GPSSC3, 6, owl.NamedIndividual],
#  [AmpKB.GPSSC3, 6, AmpKB.SupplyCurrent],
#  [AmpKB.GPSSC4, 6, owl.NamedIndividual],
#  [AmpKB.GPSSC4, 6, AmpKB.SupplyCurrent],
#  [AmpKB.GPSSC5, 6, owl.NamedIndividual],
#  [AmpKB.GPSSC5, 6, AmpKB.SupplyCurrent],
#  [AmpKB.GPSSC6, 6, owl.NamedIndividual],
#  [AmpKB.GPSSC6, 6, AmpKB.SupplyCurrent],
#  [AmpKB.GPSSC7, 6, owl.NamedIndividual],
#  [AmpKB.GPSSC7, 6, AmpKB.SupplyCurrent],
#  [AmpKB.GPSSC8, 6, owl.NamedIndividual],
#  [AmpKB.GPSSC8, 6, AmpKB.SupplyCurrent],
#  [AmpKB.GPSSC9, 6, owl.NamedIndividual],
#  [AmpKB.GPSSC9, 6, AmpKB.SupplyCurrent],
#  [AmpKB.GPSSV1, 6, owl.NamedIndividual],
#  [AmpKB.GPSSV1, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.GPSSV10, 6, owl.NamedIndividual],
#  [AmpKB.GPSSV10, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.GPSSV2, 6, owl.NamedIndividual],
#  [AmpKB.GPSSV2, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.GPSSV3, 6, owl.NamedIndividual],
#  [AmpKB.GPSSV3, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.GPSSV4, 6, owl.NamedIndividual],
#  [AmpKB.GPSSV4, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.GPSSV5, 6, owl.NamedIndividual],
#  [AmpKB.GPSSV5, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.GPSSV6, 6, owl.NamedIndividual],
#  [AmpKB.GPSSV6, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.GPSSV7, 6, owl.NamedIndividual],
#  [AmpKB.GPSSV7, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.GPSSV8, 6, owl.NamedIndividual],
#  [AmpKB.GPSSV8, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.GPSSV9, 6, owl.NamedIndividual],
#  [AmpKB.GPSSV9, 6, AmpKB.SingleSupplyVoltage],
#  [AmpKB.INA101HP, 6, owl.NamedIndividual],
#  [AmpKB.INA101HP, 6, AmpKB.SingleInstrumentalAmplifier],
#  [AmpKB.INA101HP, AmpKB.hasProperty, AmpKB.INSTRUCMRR1],
#  [AmpKB.INA101HP, AmpKB.hasProperty, AmpKB.INSTRUDSV1],
#  [AmpKB.INA101HP, AmpKB.hasProperty, AmpKB.INSTRUIBC1],
#  [AmpKB.INA101HP, AmpKB.hasProperty, AmpKB.INSTRUOSV1],
#  [AmpKB.INA101HP, AmpKB.hasProperty, AmpKB.INSTRUOT1],
#  [AmpKB.INA101HP, AmpKB.hasProperty, AmpKB.INSTRUPSRR1],
#  [AmpKB.INA101HP, AmpKB.hasProperty, AmpKB.INSTRUSSV1],
#  [AmpKB.INA101HP, AmpKB.hasProperty, AmpKB.INSTRUSV1],
#  [AmpKB.INA115BU, 6, owl.NamedIndividual],
#  [AmpKB.INA115BU, 6, AmpKB.SingleInstrumentalAmplifier],
#  [AmpKB.INA115BU, AmpKB.hasProperty, AmpKB.INSTRUCMRR5],
#  [AmpKB.INA115BU, AmpKB.hasProperty, AmpKB.INSTRUDSV5],
#  [AmpKB.INA115BU, AmpKB.hasProperty, AmpKB.INSTRUIBC5],
#  [AmpKB.INA115BU, AmpKB.hasProperty, AmpKB.INSTRUOSV5],
#  [AmpKB.INA115BU, AmpKB.hasProperty, AmpKB.INSTRUOT5],
#  [AmpKB.INA115BU, AmpKB.hasProperty, AmpKB.INSTRUPSRR5],
#  [AmpKB.INA115BU, AmpKB.hasProperty, AmpKB.INSTRUSSV5],
#  [AmpKB.INA115BU, AmpKB.hasProperty, AmpKB.INSTRUSV5],
#  [AmpKB.INA122PA, 6, owl.NamedIndividual],
#  [AmpKB.INA122PA, 6, AmpKB.SingleInstrumentalAmplifier],
#  [AmpKB.INA122PA, AmpKB.hasProperty, AmpKB.INSTRUCMRR2],
#  [AmpKB.INA122PA, AmpKB.hasProperty, AmpKB.INSTRUDSV2],
#  [AmpKB.INA122PA, AmpKB.hasProperty, AmpKB.INSTRUIBC2],
#  [AmpKB.INA122PA, AmpKB.hasProperty, AmpKB.INSTRUOSV2],
#  [AmpKB.INA122PA, AmpKB.hasProperty, AmpKB.INSTRUOT2],
#  [AmpKB.INA122PA, AmpKB.hasProperty, AmpKB.INSTRUPSRR2],
#  [AmpKB.INA122PA, AmpKB.hasProperty, AmpKB.INSTRUSSV2],
#  [AmpKB.INA122PA, AmpKB.hasProperty, AmpKB.INSTRUSV2],
#  [AmpKB.INA125UA, 6, owl.NamedIndividual],
#  [AmpKB.INA125UA, 6, AmpKB.SingleInstrumentalAmplifier],
#  [AmpKB.INA125UA, AmpKB.hasProperty, AmpKB.INSTRUCMRR4],
#  [AmpKB.INA125UA, AmpKB.hasProperty, AmpKB.INSTRUDSV4],
#  [AmpKB.INA125UA, AmpKB.hasProperty, AmpKB.INSTRUIBC4],
#  [AmpKB.INA125UA, AmpKB.hasProperty, AmpKB.INSTRUOSV4],
#  [AmpKB.INA125UA, AmpKB.hasProperty, AmpKB.INSTRUOT4],
#  [AmpKB.INA125UA, AmpKB.hasProperty, AmpKB.INSTRUPSRR4],
#  [AmpKB.INA125UA, AmpKB.hasProperty, AmpKB.INSTRUSSV4],
#  [AmpKB.INA125UA, AmpKB.hasProperty, AmpKB.INSTRUSV4],
#  [AmpKB.INA2128U, 6, owl.NamedIndividual],
#  [AmpKB.INA2128U, 6, AmpKB.DualInstrumentalAmplifier],
#  [AmpKB.INA2128U, AmpKB.hasProperty, AmpKB.INSTRUCMRR9],
#  [AmpKB.INA2128U, AmpKB.hasProperty, AmpKB.INSTRUDSV9],
#  [AmpKB.INA2128U, AmpKB.hasProperty, AmpKB.INSTRUIBC9],
#  [AmpKB.INA2128U, AmpKB.hasProperty, AmpKB.INSTRUOSV9],
#  [AmpKB.INA2128U, AmpKB.hasProperty, AmpKB.INSTRUOT9],
#  [AmpKB.INA2128U, AmpKB.hasProperty, AmpKB.INSTRUPSRR9],
#  [AmpKB.INA2128U, AmpKB.hasProperty, AmpKB.INSTRUSSV9],
#  [AmpKB.INA2128U, AmpKB.hasProperty, AmpKB.INSTRUSV9],
#  [AmpKB.INA217AIDWT, 6, owl.NamedIndividual],
#  [AmpKB.INA217AIDWT, 6, AmpKB.SingleInstrumentalAmplifier],
#  [AmpKB.INA217AIDWT, AmpKB.hasProperty, AmpKB.INSTRUCMRR6],
#  [AmpKB.INA217AIDWT, AmpKB.hasProperty, AmpKB.INSTRUDSV6],
#  [AmpKB.INA217AIDWT, AmpKB.hasProperty, AmpKB.INSTRUIBC6],
#  [AmpKB.INA217AIDWT, AmpKB.hasProperty, AmpKB.INSTRUOSV6],
#  [AmpKB.INA217AIDWT, AmpKB.hasProperty, AmpKB.INSTRUOT6],
#  [AmpKB.INA217AIDWT, AmpKB.hasProperty, AmpKB.INSTRUPSRR6],
#  [AmpKB.INA217AIDWT, AmpKB.hasProperty, AmpKB.INSTRUSSV6],
#  [AmpKB.INA217AIDWT, AmpKB.hasProperty, AmpKB.INSTRUSV6],
#  [AmpKB.INSTRUCMRR1, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUCMRR1, 6, AmpKB.CMRR],
#  [AmpKB.INSTRUCMRR10, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUCMRR10, 6, AmpKB.CMRR],
#  [AmpKB.INSTRUCMRR2, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUCMRR2, 6, AmpKB.CMRR],
#  [AmpKB.INSTRUCMRR3, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUCMRR3, 6, AmpKB.CMRR],
#  [AmpKB.INSTRUCMRR4, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUCMRR4, 6, AmpKB.CMRR],
#  [AmpKB.INSTRUCMRR5, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUCMRR5, 6, AmpKB.CMRR],
#  [AmpKB.INSTRUCMRR6, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUCMRR6, 6, AmpKB.CMRR],
#  [AmpKB.INSTRUCMRR7, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUCMRR7, 6, AmpKB.CMRR],
#  [AmpKB.INSTRUCMRR8, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUCMRR8, 6, AmpKB.CMRR],
#  [AmpKB.INSTRUCMRR9, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUCMRR9, 6, AmpKB.CMRR],
#  [AmpKB.INSTRUDSV1, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUDSV1, 6, AmpKB.DualSupplyVoltage],
#  [AmpKB.INSTRUDSV10, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUDSV10, 6, AmpKB.DualSupplyVoltage],
#  [AmpKB.INSTRUDSV2, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUDSV2, 6, AmpKB.DualSupplyVoltage],
#  [AmpKB.INSTRUDSV3, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUDSV3, 6, AmpKB.DualSupplyVoltage],
#  [AmpKB.INSTRUDSV4, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUDSV4, 6, AmpKB.DualSupplyVoltage],
#  [AmpKB.INSTRUDSV5, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUDSV5, 6, AmpKB.DualSupplyVoltage],
#  [AmpKB.INSTRUDSV6, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUDSV6, 6, AmpKB.DualSupplyVoltage],
#  [AmpKB.INSTRUDSV7, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUDSV7, 6, AmpKB.DualSupplyVoltage],
#  [AmpKB.INSTRUDSV8, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUDSV8, 6, AmpKB.DualSupplyVoltage],
#  [AmpKB.INSTRUDSV9, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUDSV9, 6, AmpKB.DualSupplyVoltage],
#  [AmpKB.INSTRUIBC1, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUIBC1, 6, AmpKB.InputBiasCurrent],
#  [AmpKB.INSTRUIBC10, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUIBC10, 6, AmpKB.InputBiasCurrent],
#  [AmpKB.INSTRUIBC2, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUIBC2, 6, AmpKB.InputBiasCurrent],
#  [AmpKB.INSTRUIBC3, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUIBC3, 6, AmpKB.InputBiasCurrent],
#  [AmpKB.INSTRUIBC4, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUIBC4, 6, AmpKB.InputBiasCurrent],
#  [AmpKB.INSTRUIBC5, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUIBC5, 6, AmpKB.InputBiasCurrent],
#  [AmpKB.INSTRUIBC6, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUIBC6, 6, AmpKB.InputBiasCurrent],
#  [AmpKB.INSTRUIBC7, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUIBC7, 6, AmpKB.InputBiasCurrent],
#  [AmpKB.INSTRUIBC8, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUIBC8, 6, AmpKB.InputBiasCurrent],
#  [AmpKB.INSTRUIBC9, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUIBC9, 6, AmpKB.InputBiasCurrent],
#  [AmpKB.INSTRUOSV1, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOSV1, 6, AmpKB.OperatingSupplyVoltage],
#  [AmpKB.INSTRUOSV10, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOSV10, 6, AmpKB.OperatingSupplyVoltage],
#  [AmpKB.INSTRUOSV2, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOSV2, 6, AmpKB.OperatingSupplyVoltage],
#  [AmpKB.INSTRUOSV3, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOSV3, 6, AmpKB.OperatingSupplyVoltage],
#  [AmpKB.INSTRUOSV4, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOSV4, 6, AmpKB.OperatingSupplyVoltage],
#  [AmpKB.INSTRUOSV5, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOSV5, 6, AmpKB.OperatingSupplyVoltage],
#  [AmpKB.INSTRUOSV6, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOSV6, 6, AmpKB.OperatingSupplyVoltage],
#  [AmpKB.INSTRUOSV7, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOSV7, 6, AmpKB.OperatingSupplyVoltage],
#  [AmpKB.INSTRUOSV8, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOSV8, 6, AmpKB.OperatingSupplyVoltage],
#  [AmpKB.INSTRUOSV9, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOSV9, 6, AmpKB.OperatingSupplyVoltage],
#  [AmpKB.INSTRUOT1, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOT1, 6, AmpKB.OperatingTemperature],
#  [AmpKB.INSTRUOT10, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOT10, 6, AmpKB.OperatingTemperature],
#  [AmpKB.INSTRUOT2, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOT2, 6, AmpKB.OperatingTemperature],
#  [AmpKB.INSTRUOT3, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOT3, 6, AmpKB.OperatingTemperature],
#  [AmpKB.INSTRUOT4, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOT4, 6, AmpKB.OperatingTemperature],
#  [AmpKB.INSTRUOT5, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOT5, 6, AmpKB.OperatingTemperature],
#  [AmpKB.INSTRUOT6, 6, owl.NamedIndividual],
#  [AmpKB.INSTRUOT6, 6, AmpKB.OperatingTemperature],
#  ...]

# %%
list(default_world.sparql("""
        SELECT DISTINCT ?individual ?property
        WHERE {
        # ?individual rdf:type/rdfs:subClassOf* <http://w3id.org/amplifiers#AudioAmplifier> .
        # ?individual <http://w3id.org/amplifiers#hasProperty> ?property .
        }
    """))
# Out:
# [[AmpKB.LM386MMX-1-NOPB, AmpKB.AUDIOOT7],
#  [AmpKB.LM386MMX-1-NOPB, AmpKB.AUDIOPD7],
#  [AmpKB.LM386MMX-1-NOPB, AmpKB.AUDIOSV7],
#  [AmpKB.LM4861M-NOPB, AmpKB.AUDIOOT1],
#  [AmpKB.LM4861M-NOPB, AmpKB.AUDIOPD1],
#  [AmpKB.LM4861M-NOPB, AmpKB.AUDIOSV1],
#  [AmpKB.LM4862M-NOPB, AmpKB.AUDIOOT6],
#  [AmpKB.LM4862M-NOPB, AmpKB.AUDIOPD6],
#  [AmpKB.LM4862M-NOPB, AmpKB.AUDIOSV6],
#  [AmpKB.LM4889MA-NOPB, AmpKB.AUDIOOT10],
#  [AmpKB.LM4889MA-NOPB, AmpKB.AUDIOPD10],
#  [AmpKB.LM4889MA-NOPB, AmpKB.AUDIOSV10],
#  [AmpKB.OPA1611AID, AmpKB.AUDIOOT4],
#  [AmpKB.OPA1611AID, AmpKB.AUDIOPD4],
#  [AmpKB.OPA1611AID, AmpKB.AUDIOSV4],
#  [AmpKB.BD28623MUV-E2, AmpKB.AUDIOOT3],
#  [AmpKB.BD28623MUV-E2, AmpKB.AUDIOPD3],
#  [AmpKB.BD28623MUV-E2, AmpKB.AUDIOSV3],
#  [AmpKB.BM28723AMUV-E2, AmpKB.AUDIOOT8],
#  [AmpKB.BM28723AMUV-E2, AmpKB.AUDIOPD8],
#  [AmpKB.BM28723AMUV-E2, AmpKB.AUDIOSV8],
#  [AmpKB.PAM8610TR, AmpKB.AUDIOOT9],
#  [AmpKB.PAM8610TR, AmpKB.AUDIOPD9],
#  [AmpKB.PAM8610TR, AmpKB.AUDIOSV9],
#  [AmpKB.TPA3125D2N, AmpKB.AUDIOOT2],
#  [AmpKB.TPA3125D2N, AmpKB.AUDIOPD2],
#  [AmpKB.TPA3125D2N, AmpKB.AUDIOSV2],
#  [AmpKB.PAM8945PJR, AmpKB.AUDIOOT5],
#  [AmpKB.PAM8945PJR, AmpKB.AUDIOPD5],
#  [AmpKB.PAM8945PJR, AmpKB.AUDIOSV5]]

# %%
list(default_world.sparql("""
        SELECT DISTINCT ?individual ?singlesupplyvoltage ?value
        WHERE {
        # ?individual rdf:type/rdfs:subClassOf* <http://w3id.org/amplifiers#AudioAmplifier> .
        # ?individual <http://w3id.org/amplifiers#hasProperty> ?singlesupplyvoltage .
        # ?singlesupplyvoltage rdf:type <http://w3id.org/amplifiers#SingleSupplyVoltage> .
        # ?singlesupplyvoltage <http://w3id.org/amplifiers#hasNumericalValue> ?value .
        FILTER (?value > "5")
        }
    """))
# Out:
# [[AmpKB.BD28623MUV-E2, AmpKB.AUDIOSV3, '9|12|15|18'],
#  [AmpKB.OPA1611AID, AmpKB.AUDIOSV4, '5|9|12|15|18|24|28'],
#  [AmpKB.LM386MMX-1-NOPB, AmpKB.AUDIOSV7, '5|9']]
