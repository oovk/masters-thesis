# %% [markdown]
# # Data Extraction and Cleaning

# %%
import pandas as pd

df1 = pd.read_excel('./../AmplifiersData/AudioAmplifiers.xlsx')
df2 = pd.read_excel('./../AmplifiersData/GPSAmplifiers.xlsx')
df4 = pd.read_excel('./../AmplifiersData/OperationalAmplifiers.xlsx')
df5 = pd.read_excel('./../AmplifiersData/VideoAmplifiers.xlsx')
df6 = pd.read_excel('./../AmplifiersData/InstrumentationAmplifiers.xlsx')

# %%
AudioAmpData = df1.drop(columns=['Description','Product line'])
AudioAmpData = AudioAmpData.to_csv(index=False)
AudioAmpData
# Out:
# 'Part,Type,Manufacturer,PowerSupplyType,InputSignalType,OutputSignalType,OutputType,PinCount,TypicalSingleSupplyVoltage,TypicalSingleSupplyVoltageUnit,MinimumSingleSupplyVoltage,MinimumSingleSupplyVoltageUnit,MaximumSingleSupplyVoltage,MaximumSingleSupplyVoltageUnit,MinimumOperatingTemperature,MinimumOperatingTemperatureUnit,MaximumOperatingTemperature,MaximumOperatingTemperatureUnit,MaximumPowerDissipation,MaximumPowerDissipationUnit\nLM4861M-NOPB ,Class-AB ,Texas Instruments ,Single ,Single ,Differential ,1-Channel Mono ,8,3|5,V,2,V,5.5,V,-40,°C,85,°C,-,mW\nLM4889MA-NOPB ,Class-AB ,Texas Instruments ,Single ,Differential|Single ,Differential ,1-Channel Mono ,8,3|5,V,2.2,V,5.5,V,-40,°C,85,°C,-,mW\nTPA3125D2N ,Class-D ,Texas Instruments ,Single ,Single ,Differential|Single ,1-Channel Mono|2-Channel Stereo ,20,12|15|18|24,V,10,V,26,V,-40,°C,85,°C,1870,mW\nBD28623MUV-E2 ,Class-D ,ROHM Semiconductor ,Single ,Single ,Differential ,2-Channel Stereo ,24,9|12|15|18,V,8.5,V,24,V,-25,°C,85,°C,3560,mW\nOPA1611AID ,Class-AB ,Texas Instruments ,Single|Dual ,Differential ,Single ,1-Channel Mono ,8,5|9|12|15|18|24|28,V,4.5,V,36,V,-40,°C,85,°C,-,mW\nPAM8945PJR ,Class-G ,Diodes Incorporated ,Single ,Differential ,Differential ,1-Channel Mono ,12,3|5,V,2.8,V,5.2,V,-40,°C,85,°C,-,mW\nLM4862M-NOPB ,Class-AB ,Texas Instruments ,Single ,Single ,Differential ,1-Channel Mono ,8,3|5,V,2.7,V,5.5,V,-40,°C,85,°C,-,mW\nLM386MMX-1-NOPB ,Class-AB ,Texas Instruments ,Single ,Differential ,Single ,1-Channel Mono ,8,5|9,V,4,V,12,V,-,°C,70,°C,595,mW\nBM28723AMUV-E2 ,Class-D ,ROHM Semiconductor ,Triple ,Single ,Differential ,2-Channel Stereo ,32,-,V,-,V,-,V,-25,°C,85,°C,-,mW\nPAM8610TR ,Class-D ,Diodes Incorporated ,Single ,Differential ,Differential ,2-Channel Stereo ,40,12,V,7,V,15,V,-20,°C,85,°C,-,mW\n'

# %%
GPSAmpData = df2.drop(columns=['Description','ProductLine'])
GPSAmpData = GPSAmpData.to_csv(index=False)
GPSAmpData
# Out:
# 'Part,Type,Manufacturer,ProcessTechnology,PowerSupplyType,PinCount,MaximumGain,MaximumGainUnit,TypicalSingleSupplyVoltage,TypicalSingleSupplyVoltageUnit,MinimumSingleSupplyVoltage,MinimumSingleSupplyVoltageUnit,MaximumSingleSupplyVoltage,MaximumSingleSupplyVoltageUnit,MinimumOperatingFrequency,MinimumOperatingFrequencyUnit,MaximumOperatingFrequency,MaximumOperatingFrequencyUnit,TypicalNoiseFigure,TypicalNoiseFigureUnit,MinimumOperatingTemperature,MinimumOperatingTemperatureUnit,MaximumOperatingTemperature,MaximumOperatingTemperatureUnit,MaximumSupplyCurrent,MaximumSupplyCurrentUnit,MaximumPowerDissipation,MaximumPowerDissipationUnit\nBGA725L6E6327FTSA1,Low Noise Amplifier,Infineon Technologies AG,SiGe,Single,6,-,dB,3,V,1.5,V,3.6,V,1550,MHz,1615,MHz,0.65,dB,-40,°C,85,°C,3.6,mA,72,mW\nBGU7005-115,Low Noise Amplifier,NXP Semiconductors,SiGe,Single,6,20,dB,1.8,V,1.5,V,3.1,V,-,MHz,1850,MHz,1.3,dB,-40,°C,85,°C,14.4,mA,55,mW\nBGA123L4E6327XTSA1,Low Noise Amplifier,Infineon Technologies AG,-,Single,4,19.9,dB,1.8,V,1.1,V,3.6,V,1550,MHz,1615,MHz,0.75,dB,-40,°C,85,°C,1.7,mA,40,mW\nBGA715N7E6327XTSA2,Low Noise Amplifier,Infineon Technologies AG,SiGe,Single,6,20,dB,1.8,V,1.5,V,3.6,V,1550,MHz,1615,MHz,0.7,dB,-40,°C,85,°C,3.3,mA,36,mW\nBGU8103X,Low Noise Amplifier,NXP Semiconductors,SiGe,Single,6,18.5,dB,3,V,1.5,V,3.1,V,1559,MHz,1610,MHz,1.4,dB,-40,°C,85,°C,2.5,mA,55,mW\nBGU8019X,Low Noise Amplifier,NXP Semiconductors,SiGe,Single,6,20.5,dB,3,V,1.5,V,3.1,V,1559,MHz,1610,MHz,1.3,dB,-40,°C,85,°C,10.0,mA,55,mW\nBGU7007-115,Low Noise Amplifier,NXP Semiconductors,SiGe,Single,6,21.5,dB,-,-,1.5,V,3.1,V,1559,MHz,1610,MHz,1.3,dB,-40,°C,85,°C,15.9,mA,55,mW\nBGU7008-115,Low Noise Amplifier,NXP Semiconductors,SiGe,Single,6,21.5,dB,-,-,1.5,V,2.85,V,1559,MHz,1610,MHz,1.3,dB,-40,°C,125,°C,15.9,mA,55,mW\nBGU7004-115,Low Noise Amplifier,NXP Semiconductors,SiGe,Single,6,21,dB,-,-,1.5,V,2.85,V,1559,MHz,1610,MHz,1.3,dB,-40,°C,125,°C,14.4,mA,55,mW\nBGA524N6E6327XTSA1,Low Noise Amplifier,Infineon Technologies AG,SiGe,Single,6,-,dB,3,V,1.5,V,3.3,V,1550,MHz,1615,MHz,0.55,dB,-40,°C,85,°C,3.6,mA,60,mW\n'

# %%
InstruAmpData = df6.drop(columns=['Description','ProductLine'])
InstruAmpData = InstruAmpData.to_csv(index=False)
InstruAmpData
# Out:
# 'Part,Type,Manufacturer,PowerSupplyType,PinCount,MinimumPSRR,MinimumPSRRUnit,MaximumOperatingSupplyVoltage,MaximumOperatingSupplyVoltageUnit,MinimumSupplyVoltage,MinimumSupplyVoltageUnit,MaximumSupplyVoltage,MaximumSupplyVoltageUnit,TypicalDualSupplyVoltage,TypicalDualSupplyVoltageUnit,TypicalSingleSupplyVoltage,TypicalSingleSupplyVoltageUnit,MinimumCMRR,MinimumCMRRUnit,MaximumInputBiasCurrent,MaximumInputBiasCurrentUnit,MinimumOperatingTemperature,MinimumOperatingTemperatureUnit,MaximumOperatingTemperature,MaximumOperatingTemperatureUnit\nINA101HP ,Single,Texas Instruments ,Dual ,14,-,dB,±20,V,30,V,50,V,±15,V,-,V,-,dB,0.02,uA,-,°C,70,°C\nMCP6N11T-100E-MNY ,Single,Microchip Technology ,Single ,8,86,dB,5.5,V,5,V,7,V,-,V,3.3|5,V,86,dB,-,uA,-40,°C,125,°C\nINA122PA ,Single,Texas Instruments ,Single|Dual ,8,100,dB,±18|36,V,30,V,50,V,±3|±5|±9|±12|±15,V,5,V,76,dB,0.05,uA,-40,°C,85,°C\nPGA204AP ,Single,Texas Instruments ,Dual ,16,-,dB,±18,V,30,V,50,V,±15,V,-,V,75,dB,0.005,uA,-40,°C,85,°C\nINA125UA ,Single,Texas Instruments ,Single|Dual ,16,-,dB,±18|36,V,30,V,50,V,±15,V,5,V,72,dB,0.05,uA,-55,°C,125,°C\nINA115BU ,Single,Texas Instruments ,Dual ,16,-,dB,±18,V,30,V,50,V,±15,V,-,V,80,dB,-,uA,-40,°C,85,°C\nINA217AIDWT ,Single,Texas Instruments ,Dual ,16,-,dB,±18,V,30,V,50,V,±15,V,-,V,70,dB,12,uA,-40,°C,125,°C\nLMP8358MA-NOPB ,Single,Texas Instruments ,Single ,14,112,dB,5.5,V,5,V,7,V,-,V,3|5,V,116,dB,-,uA,-40,°C,125,°C\nMCP6N16-010E-MS ,Single,Microchip Technology ,Single ,8,104,dB,5.5,V,5,V,7,V,-,V,3.3|5,V,94,dB,-,uA,-40,°C,125,°C\nINA2128U ,Dual,Texas Instruments ,Dual ,16,-,dB,±18,V,30,V,50,V,±15,V,-,V,80,dB,0.005,uA,-40,°C,85,°C\n'

# %%
OpAmpData = df4.drop(columns=['Description','ProductLine'])
OpAmpData = OpAmpData.to_csv(index=False)
OpAmpData
# Out:
# 'Part,Type,Manufacturer,ProcessTechnology,PowerSupplyType,PinCount,MinimumPSRR,MinimumPSRRUnit,MaximumOperatingSupplyVoltage,MaximumOperatingSupplyVoltageUnit,MinimumSupplyVoltage,MinimumSupplyVoltageUnit,MaximumSupplyVoltage,MaximumSupplyVoltageUnit,TypicalSingleSupplyVoltage,TypicalSingleSupplyVoltageunit,MinimumSingleSupplyVoltage,MinimumSingleSupplyVoltageUnit,MaximumSingleSupplyVoltage,MaximumSingleSupplyVoltageUnit,MinimumCMRR,MinimumCMRRUnit,MaximumInputBiasCurrent,MaximumInputBiasCurrentUnit,MinimumOperatingTemperature,MinimumOperatingTemperatureUnit,MaximumOperatingTemperature,MaximumOperatingTemperatureUnit,TypicalOutputCurrent,TypicalOutputCurrentUnit,TypicalGainBandwidthProduct,TypicalGainBandwidthProductUnit\nMCP607-I-P ,Micropower Amplifier ,Microchip Technology ,CMOS ,Single ,8,80,dB,6,V,6.0,V,9,V,3|5,V,2.5,V,6.0,V,75,dB,-,uA,-40,°C,85,°C,30,mA,0.155,MHz\nMCP6034-E-SL ,Precision Amplifier ,Microchip Technology ,CMOS ,Single ,14,70,dB,5.5,V,5.5,V,6,V,3|5,V,1.8,V,5.5,V,70,dB,0.0001,uA,-40,°C,125,°C,30,mA,0.01,MHz\nMCP6V27-E-SN ,Auto Zero Amplifier ,Microchip Technology ,CMOS ,Single ,8,125,dB,5.5,V,5.5,V,6,V,3|5,V,2.3,V,5.5,V,120,dB,0.005,uA,-40,°C,125,°C,30,mA,2.0,MHz\nLM6132BIN-NOPB ,Low Power Amplifier ,Texas Instruments ,-,Single ,8,78,dB,24,V,17.0,V,30,V,3|5|9|12|15|18,V,1.8,V,24.0,V,60,dB,0.18,uA,-40,°C,85,°C,30,mA,10.0,MHz\nMCP6292-E-P ,General Purpose Amplifier ,Microchip Technology ,CMOS ,Single ,8,70,dB,5.5,V,5.5,V,6,V,3|5,V,2.4,V,6.0,V,70,dB,1e-06,uA,-40,°C,125,°C,30,mA,10.0,MHz\nMCP6V32-E-MS ,Chopper Amplifier ,Microchip Technology ,CMOS ,Single ,8,120,dB,5.5,V,5.5,V,6,V,3|5,V,1.8,V,5.5,V,120,dB,-,uA,-40,°C,125,°C,30,mA,0.3,MHz\nOPA625IDBVT ,High Speed Amplifier ,Texas Instruments ,Bipolar ,Single|Dual ,8,100,dB,±2.75|5.5,V,5.5,V,6,V,5|9,V,3.0,V,12.0,V,72,dB,2.6,uA,-40,°C,85,°C,110,mA,86.0,MHz\nLMH6639MA-NOPB ,Low Offset Voltage Amplifier ,Texas Instruments ,VIP10 ,Single|Dual ,8,72,dB,±6|12,V,12.0,V,12.5,V,5|9|12|15|18|24|28,V,4.0,V,40.0,V,85,dB,0.07,uA,-40,°C,85,°C,20,mA,1.2,MHz\nTLC27M2CP ,Wideband Amplifier ,Texas Instruments ,LinCMOS ,Single ,8,-,dB,16,V,16.0,V,17,V,3,V,2.7,V,5.0,V,54,dB,1e-05,uA,-40,°C,85,°C,-,mA,5.5,MHz\nOPA343UA ,Low Noise Amplifier ,Texas Instruments ,CMOS ,Single|Dual ,8,87.96,dB,5,V,5.5,V,-,V,5|9|12|15,V,4.4,V,16.0,V,70,dB,0.0001,uA,-,°C,70,°C,50,mA,0.71,MHz\n'

# %%
VideoAmpData = df5.drop(columns=['Description','ProductLine'])
VideoAmpData = VideoAmpData.to_csv(index=False)
VideoAmpData
# Out:
# 'Part,Type,Manufacturer,PowerSupplyType,PinCount,TypicalDualSupplyVoltage,TypicalDualSupplyVoltageUnit,MinimumDualSupplyVoltage,MinimumDualSupplyVoltageUnit,MaximumDualSupplyVoltage,MaximumDualSupplyVoltageUnit,TypicalSingleSupplyVoltage,TypicalSingleSupplyVoltageUnit,MinimumSingleSupplyVoltage,MinimumSingleSupplyVoltageUnit,MaximumSingleSupplyVoltage,MaximumSingleSupplyVoltageUnit,MinimumOperatingTemperature,MinimumOperatingTemperatureUnit,MaximumOperatingTemperature,MaximumOperatingTemperatureUnit\nLMH6714MF-NOPB ,Single,Texas Instruments ,Single|Dual ,5,±5,V,±4,V,±6.25,V,9|12,V,8,V,12.6,V,-40,°C,85,°C\nLM6172IN-NOPB ,Dual,Texas Instruments ,Dual ,8,±5|±15,V,±2.75,V,±18,V,-,V,-,V,-,V,-40,°C,85,°C\nLMH6720MF-NOPB ,Single,Texas Instruments ,Single|Dual ,6,±5,V,±4,V,±6.25,V,9|12,V,8,V,12.5,V,-40,°C,85,°C\nLMH6739MQ-NOPB ,Triple,Texas Instruments ,Single ,16,-,V,-,V,-,V,9,V,8,V,12,V,-40,°C,85,°C\nLMH6738MQ-NOPB ,Triple,Texas Instruments ,Single ,16,-,V,-,V,-,V,9,V,8,V,12,V,-40,°C,85,°C\nAD812ARZ ,Dual,Analog Devices ,Single|Dual ,8,±3|±5|±12|±15,V,±1.2,V,±18,V,3|5|9|12|15|18|24|28,V,2.4,V,36,V,-40,°C,85,°C\nLMH6722MA-NOPB ,Quad,Texas Instruments ,Single|Dual ,14,±5,V,±4,V,±6.25,V,9|12,V,8,V,12.5,V,-40,°C,85,°C\nTHS7360IPW ,Hex,Texas Instruments ,Single ,20,-,V,-,V,-,V,3,V,2.7,V,5,V,-40,°C,85,°C\nTHS7374IPW ,Quad,Texas Instruments ,Single ,14,-,V,-,V,-,V,-,V,3,V,5,V,-40,°C,85,°C\nTHS7360IPWR ,Hex,Texas Instruments ,Single ,20,-,V,-,V,-,V,3,V,2.7,V,5,V,-40,°C,85,°C\n'

# %% [markdown]
# # Prompt Engineering

# %%
# Reading prompts from files
def read_file(file_path):
    try:
        with open(file_path, 'r') as file:
            file_content = file.read()
            return file_content
    except FileNotFoundError:
        print(f"The file at path '{file_path}' was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# Setting Prompts:
file1_path = "./../prompts/AudioInput.txt"
file2_path = "./../prompts/AudioOutput.txt"
file3_path = "./../prompts/GPSInput.txt"
file4_path = "./../prompts/GPSOutput.txt"
file5_path = "./../prompts/InstrumentationInput.txt"
file6_path = "./../prompts/InstrumentationOutput.txt"
file7_path = "./../prompts/OpInput.txt"
file8_path = "./../prompts/OpOutput.txt"
file9_path = "./../prompts/RFInput.txt"
file10_path = "./../prompts/RFOutput.txt"
file11_path = "./../prompts/VideoInput.txt"
file12_path = "./../prompts/VideoOutput.txt"
file13_path = "./../prompts/system2.txt"

audio_input_prompt = read_file(file1_path)
audio_ouput_prompt = read_file(file2_path)
gps_input_prompt = read_file(file3_path)
gps_ouput_prompt = read_file(file4_path)
instru_input_prompt = read_file(file5_path)
instru_ouput_prompt = read_file(file6_path)
op_input_prompt = read_file(file7_path)
op_ouput_prompt = read_file(file8_path)
rf_input_prompt = read_file(file9_path)
rf_ouput_prompt = read_file(file10_path)
video_input_prompt = read_file(file11_path)
video_ouput_prompt = read_file(file12_path)
system_prompt = read_file(file13_path)

# %% [markdown]
# # LLM for Triplets Extraction

# %%
import vertexai
from vertexai import language_models

project_id = "modular-glider-408308"
location = "us-central1"

def extract_triplets(project_id: str, location: str, data: str, input_prompt:str, output_prompt:str) -> str:
    """Extract Triplets with a Large Language Model."""

    vertexai.init(project=project_id, location=location)

    chat_model = language_models.ChatModel.from_pretrained("chat-bison")

    parameters = {
        "temperature": 0.8,
        "max_output_tokens": 2048,
        "top_p": 0.95,
        "top_k": 40,
    }

    chat = chat_model.start_chat(
        context=system_prompt,   #add our system_prompt
        examples=[
            language_models.InputOutputTextPair(
                input_text=input_prompt,   #add input data example
                output_text=output_prompt, #add output we expect
            ),
        ],
    )

    responses = chat.send_message_streaming(
        message=data,   #provide our own data
        **parameters,
    )

    results = []
    for response in responses:
        results.append(str(response.candidates[0].text))
    results = "".join(results)
    return results

# %%
import csv
import json
from io import StringIO

def process_csv_to_triplets(csv_data, project_id, location, input_prompt, output_prompt):
    
    # Use StringIO to simulate reading from a file
    csv_file = StringIO(csv_data.strip())

    # Use csv.reader to read the CSV data
    reader = csv.reader(csv_file)

    # Read the header row
    header = next(reader)

    for row in reader:
    
        # Combine the header and row into a single list
        combined_row = header + row
        row_data = ','.join(combined_row)
        json_data = extract_triplets(project_id, location, row_data, input_prompt, output_prompt)
        
        print(json_data)

# %% [markdown]
# ## Extracted triplets using Google's Gemini

# %%
process_csv_to_triplets(AudioAmpData, project_id, location, audio_input_prompt, audio_ouput_prompt)
# Out:
#  [
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasType",
#     "tail": "Class-AB"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasInputSignalType",
#     "tail": "Single"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasOutputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasOutputType",
#     "tail": "1-Channel Mono"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "\u00b0C"
#   },
#   {
#     "head": "LM4861M-NOPB",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  ```json
# [
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasType",
#     "tail": "Class-AB"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasInputSignalType",
#     "tail": "Differential|Single"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasOutputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasOutputType",
#     "tail": "1-Channel Mono"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.2"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "\u00b0C"
#   },
#   {
#     "head": "LM4889MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
# ```
#  [
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasType",
#     "tail": "Class-D"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasInputSignalType",
#     "tail": "Single"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasOutputSignalType",
#     "tail": "Differential|Single"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasOutputType",
#     "tail": "1-Channel Mono|2-Channel Stereo"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasPinCount",
#     "tail": "20"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "12|15|18|24"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "10"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "26"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "TPA3125D2N",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1870"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  """
# [
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasType",
#     "tail": "Class-D"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasManufacturer",
#     "tail": "ROHM Semiconductor"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasInputSignalType",
#     "tail": "Single"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasOutputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasOutputType",
#     "tail": "2-Channel Stereo"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasPinCount",
#     "tail": "24"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "9|12|15|18"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "8.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "24"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-25"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BD28623MUV-E2",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3560"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
# """
#  {
#     "head": "OPA1611AID",
#     "relation": "hasType",
#     "tail": "Class-AB"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasInputSignalType",
#     "tail": "Differential"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasOutputSignalType",
#     "tail": "Single"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasOutputType",
#     "tail": "1-Channel Mono"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasPinCount",
#     "tail": "8"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
# },
# {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "5|9|12|15|18|24|28"
# },
# {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "4.5"
# },
# {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "36"
# },
# {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
# },
# {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
# },
# {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
# },
# {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
# },
# {
#     "head": "OPA1611AID",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
# },
# {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
# },
# {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
# }
#  ```json
# [
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasType",
#     "tail": "Class-G"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasManufacturer",
#     "tail": "Diodes Incorporated"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasInputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasOutputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasOutputType",
#     "tail": "1-Channel Mono"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasPinCount",
#     "tail": "12"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.2"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "PAM8945PJR",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
# ```
#  [
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasType",
#         "tail":"Class-AB"
#     },
#     {
#         "head": "LM4862M-NOPB",
#         "relation":"hasManufacturer",
#         "tail":"Texas Instruments"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasPowerSupplyType",
#         "tail":"Single"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasInputSignalType",
#         "tail":"Single"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasOutputSignalType",
#         "tail":"Differential"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasOutputType",
#         "tail":"1-Channel Mono"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasPinCount",
#         "tail":"8"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasProperty",
#         "tail":"SingleSupplyVoltage"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasNumericalValue",
#         "tail":"3|5"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"2.7"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"5.50"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasProperty",
#         "tail":"OperatingTemperature"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"-40"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"85"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUnit",
#         "tail":"°C"
#     },
#     {
#         "head":"LM4862M-NOPB",
#         "relation":"hasProperty",
#         "tail":"PowerDissipation"
#     },
#     {
#         "head":"PowerDissipation",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"-"
#     },
#     {
#         "head":"PowerDissipation",
#         "relation":"hasUnit",
#         "tail":"mW"
#     }
# ]
#  [
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasType",
#     "tail": "Class-AB"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasInputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasOutputSignalType",
#     "tail": "Single"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasOutputType",
#     "tail": "1-Channel Mono"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasProperty",
#     "tail": "TypicalSingleSupplyVoltage"
#   },
#   {
#     "head": "TypicalSingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "5|9"
#   },
#   {
#     "head": "TypicalSingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasProperty",
#     "tail": "MinimumSingleSupplyVoltage"
#   },
#   {
#     "head": "MinimumSingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "4"
#   },
#   {
#     "head": "MinimumSingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasProperty",
#     "tail": "MaximumSingleSupplyVoltage"
#   },
#   {
#     "head": "MaximumSingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "12"
#   },
#   {
#     "head": "MaximumSingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasProperty",
#     "tail": "MinimumOperatingTemperature"
#   },
#   {
#     "head": "MinimumOperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasProperty",
#     "tail": "MaximumOperatingTemperature"
#   },
#   {
#     "head": "MaximumOperatingTemperature",
#     "relation": "hasNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "MaximumOperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "LM386MMX-1-NOPB",
#     "relation": "hasProperty",
#     "tail": "MaximumPowerDissipation"
#   },
#   {
#     "head": "MaximumPowerDissipation",
#     "relation": "hasNumericalValue",
#     "tail": "595"
#   },
#   {
#     "head": "MaximumPowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasType",
#     "tail": "Class-D"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasManufacturer",
#     "tail": "ROHM Semiconductor"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasPowerSupplyType",
#     "tail": "Triple"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasInputSignalType",
#     "tail": "Single"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasOutputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasOutputType",
#     "tail": "2-Channel Stereo"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasPinCount",
#     "tail": "32"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   },
#   {
#     "head": "BM28723AMUV-E2",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-25"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "PAM8610TR",
#     "relation": "hasType",
#     "tail": "Class-D"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasManufacturer",
#     "tail": "Diodes Incorporated"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasInputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasOutputSignalType",
#     "tail": "Differential"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasOutputType",
#     "tail": "2-Channel Stereo"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasPinCount",
#     "tail": "40"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "12"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "7"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "15"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-20"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "PAM8610TR",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]

# %%
process_csv_to_triplets(GPSAmpData, project_id, location, gps_input_prompt, gps_ouput_prompt)
# Out:
#  ```json
# [
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasManufacturer",
#     "tail": "Infineon Technologies AG"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.6"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1550"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1615"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "0.65"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.6"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGA725L6E6327FTSA1",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "72"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
# ```
#  [
#   {
#     "head": "BGU7005-115",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasManufacturer",
#     "tail": "NXP Semiconductors"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "20"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "1.8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.1"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1850"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "1.3"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "14.4"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGU7005-115",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "55"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasManufacturer",
#     "tail": "Infineon Technologies AG"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasPinCount",
#     "tail": "4"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "19.9"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "1.8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.1"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.6"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1550"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1615"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "0.75"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1.7"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGA123L4E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "40"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasManufacturer",
#     "tail": "Infineon Technologies AG"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "20"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "1.8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.6"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1550"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1615"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "0.7"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.3"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGA715N7E6327XTSA2",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "36"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#   {
#     "head": "BGU8103X",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasManufacturer",
#     "tail": "NXP Semiconductors"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "18.5"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.1"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1559"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1610"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "1.4"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "2.5"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGU8103X",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "55"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#   {
#     "head": "BGU8019X",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasManufacturer",
#     "tail": "NXP Semiconductors"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "20.5"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.1"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1559"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1610"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "1.3"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "\u00b0C"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "10.0"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGU8019X",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "55"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#   {
#     "head": "BGU7007-115",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasManufacturer",
#     "tail": "NXP Semiconductors"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "21.5"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.1"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1559"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1610"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "1.3"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "15.9"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGU7007-115",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "55"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#     {
#         "head":"BGU7008-115",
#         "relation":"hasType",
#         "tail":"Low Noise Amplifier"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasManufacturer",
#         "tail":"NXP Semiconductors"
#     },
#     {
#         "head": "BGU7008-115",
#         "relation":"hasProcessTechnology",
#         "tail":"SiGe"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasPowerSupplyType",
#         "tail":"Single"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasPinCount",
#         "tail":"6"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasProperty",
#         "tail":"Gain"
#     },
#     {
#         "head":"Gain",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"21.5"
#     },
#     {
#         "head":"Gain",
#         "relation":"hasUnit",
#         "tail":"dB"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasProperty",
#         "tail":"SingleSupplyVoltage"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"1.5"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"2.85"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasProperty",
#         "tail":"OperatingFrequency"
#     },
#     {
#         "head":"OperatingFrequency",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"1559"
#     },
#     {
#         "head":"OperatingFrequency",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"1610"
#     },
#     {
#         "head":"OperatingFrequency",
#         "relation":"hasUnit",
#         "tail":"MHz"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasProperty",
#         "tail":"NoiseFigure"
#     },
#     {
#         "head":"NoiseFigure",
#         "relation":"hasNumericalValue",
#         "tail":"1.3"
#     },
#     {
#         "head":"NoiseFigure",
#         "relation":"hasUnit",
#         "tail":"dB"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasProperty",
#         "tail":"OperatingTemperature"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"-40"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"125"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUnit",
#         "tail":"°C"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasProperty",
#         "tail":"SupplyCurrent"
#     },
#     {
#         "head":"SupplyCurrent",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"15.9"
#     },
#     {
#         "head":"SupplyCurrent",
#         "relation":"hasUnit",
#         "tail":"mA"
#     },
#     {
#         "head":"BGU7008-115",
#         "relation":"hasProperty",
#         "tail":"PowerDissipation"
#     },
#     {
#         "head":"PowerDissipation",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"55"
#     },
#     {
#         "head":"PowerDissipation",
#         "relation":"hasUnit",
#         "tail":"mW"
#     }
# ]
#  [
#   {
#     "head": "BGU7004-115",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasManufacturer",
#     "tail": "NXP Semiconductors"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "21"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "2.85"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1559"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1610"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "1.3"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "14.4"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGU7004-115",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "55"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]
#  [
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasManufacturer",
#     "tail": "Infineon Technologies AG"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProcessTechnology",
#     "tail": "SiGe"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "Gain"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "Gain",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "OperatingFrequency"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1550"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1615"
#   },
#   {
#     "head": "OperatingFrequency",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "NoiseFigure"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasNumericalValue",
#     "tail": "0.55"
#   },
#   {
#     "head": "NoiseFigure",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "SupplyCurrent"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "3.6"
#   },
#   {
#     "head": "SupplyCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "BGA524N6E6327XTSA1",
#     "relation": "hasProperty",
#     "tail": "PowerDissipation"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "60"
#   },
#   {
#     "head": "PowerDissipation",
#     "relation": "hasUnit",
#     "tail": "mW"
#   }
# ]

# %%
process_csv_to_triplets(InstruAmpData, project_id, location, instru_input_prompt, instru_ouput_prompt)
# Out:
#  [
#   {
#     "head": "INA101HP",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasPowerSupplyType",
#     "tail": "Dual"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasPinCount",
#     "tail": "14"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±20"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.02"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "INA101HP",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasManufacturer",
#     "tail": "Microchip Technology"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "86"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "7"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3.3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "86"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "MCP6N11T-100E-MNY",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "INA122PA",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "100"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18|36"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±3|±5|±9|±12|±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "76"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.05"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "INA122PA",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  ```json
# [
#   {
#     "head": "PGA204AP",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasPowerSupplyType",
#     "tail": "Dual"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasPinCount",
#     "tail": "16"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "75"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.005"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "PGA204AP",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
# ```
#  [
#   {
#     "head": "INA125UA",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasPinCount",
#     "tail": "16"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "72"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.05"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "INA125UA",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-55"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  ```JSON
# [
#   {
#     "head": "INA115BU",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasPowerSupplyType",
#     "tail": "Dual"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasPinCount",
#     "tail": "16"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "80"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "INA115BU",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
# ```
#  [
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasPowerSupplyType",
#     "tail": "Dual"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasPinCount",
#     "tail": "16"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "INA217AIDWT",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasType",
#         "tail":"Single"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasManufacturer",
#         "tail":"Texas Instruments"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasPowerSupplyType",
#         "tail":"Single"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasPinCount",
#         "tail":"14"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"PSRR"
#     },
#     {
#         "head":"PSRR",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"112"
#     },
#     {
#         "head":"PSRR",
#         "relation":"hasUnit",
#         "tail":"dB"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"OperatingSupplyVoltage"
#     },
#     {
#         "head":"OperatingSupplyVoltage",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"5.5"
#     },
#     {
#         "head":"OperatingSupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"SupplyVoltage"
#     },
#     {
#         "head":"SupplyVoltage",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"5"
#     },
#     {
#         "head":"SupplyVoltage",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"7"
#     },
#     {
#         "head":"SupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"DualSupplyVoltage"
#     },
#     {
#         "head":"DualSupplyVoltage",
#         "relation":"hasNumericalValue",
#         "tail":"-"
#     },
#     {
#         "head":"DualSupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"SingleSupplyVoltage"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasNumericalValue",
#         "tail":"3|5"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"CMRR"
#     },
#     {
#         "head":"CMRR",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"116"
#     },
#     {
#         "head":"CMRR",
#         "relation":"hasUnit",
#         "tail":"dB"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"InputBiasCurrent"
#     },
#     {
#         "head":"InputBiasCurrent",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"-"
#     },
#     {
#         "head":"InputBiasCurrent",
#         "relation":"hasUnit",
#         "tail":"uA"
#     },
#     {
#         "head":"LMP8358MA-NOPB",
#         "relation":"hasProperty",
#         "tail":"OperatingTemperature"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"-40"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"125"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUnit",
#         "tail":"°C"
#     }
# ]
#  ```json
# [
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasManufacturer",
#     "tail": "Microchip Technology"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "104"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "7"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3.3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "94"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "MCP6N16-010E-MS",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
# ```
#  ```json
# [
#   {
#     "head": "INA2128U",
#     "relation": "hasType",
#     "tail": "Dual"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasPowerSupplyType",
#     "tail": "Dual"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasPinCount",
#     "tail": "16"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "80"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.005"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "INA2128U",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
# ```

# %%
process_csv_to_triplets(OpAmpData, project_id, location, op_input_prompt, op_ouput_prompt)
# Out:
#  ```json
# [
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasType",
#     "tail": "Micropower Amplifier"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasManufacturer",
#     "tail": "Microchip Technology"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProcessTechnology",
#     "tail": "CMOS"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "80"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "9"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "75"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "OutputCurrent"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "MCP607-I-P",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "0.155"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]
# ```
#  ```json
# [
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasType",
#     "tail": "Precision Amplifier"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasManufacturer",
#     "tail": "Microchip Technology"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProcessTechnology",
#     "tail": "CMOS"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasPinCount",
#     "tail": "14"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "1.8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.0001"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "\u00b0C"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "OutputCurrent"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "MCP6034-E-SL",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "0.01"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]
# ```
#  ```json
# [
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasType",
#     "tail": "Auto Zero Amplifier"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasManufacturer",
#     "tail": "Microchip Technology"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProcessTechnology",
#     "tail": "CMOS"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "120"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.005"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "OutputCurrent"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "MCP6V27-E-SN",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "2.0"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]
# ```
#  [
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasType",
#     "tail": "General Purpose Amplifier"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasManufacturer",
#     "tail": "Microchip Technology"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProcessTechnology",
#     "tail": "CMOS"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.4"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1e-06"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "125"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "OutputCurrent"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasNumericalValue",
#     "tail": "30"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "MCP6292-E-P",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "10.0"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]
#  [
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasType",
#         "tail":"Chopper Amplifier"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasManufacturer",
#         "tail":"Microchip Technology"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProcessTechnology",
#         "tail":"CMOS"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasPowerSupplyType",
#         "tail":"Single"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasPinCount",
#         "tail":"8"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"PSRR"
#     },
#     {
#         "head":"PSRR",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"120"
#     },
#     {
#         "head":"PSRR",
#         "relation":"hasUnit",
#         "tail":"dB"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"OperatingSupplyVoltage"
#     },
#     {
#         "head":"OperatingSupplyVoltage",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"5.5"
#     },
#     {
#         "head":"OperatingSupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"SupplyVoltage"
#     },
#     {
#         "head":"SupplyVoltage",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"5.5"
#     },
#     {
#         "head":"SupplyVoltage",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"6"
#     },
#     {
#         "head":"SupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"SingleSupplyVoltage"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasNumericalValue",
#         "tail":"3|5"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"1.8"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"5.5"
#     },
#     {
#         "head":"SingleSupplyVoltage",
#         "relation":"hasUnit",
#         "tail":"V"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"CMRR"
#     },
#     {
#         "head":"CMRR",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"120"
#     },
#     {
#         "head":"CMRR",
#         "relation":"hasUnit",
#         "tail":"dB"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"InputBiasCurrent"
#     },
#     {
#         "head":"InputBiasCurrent",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"-"
#     },
#     {
#         "head":"InputBiasCurrent",
#         "relation":"hasUnit",
#         "tail":"uA"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"OperatingTemperature"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasLowerBoundNumericalValue",
#         "tail":"-40"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUpperBoundNumericalValue",
#         "tail":"125"
#     },
#     {
#         "head":"OperatingTemperature",
#         "relation":"hasUnit",
#         "tail":"°C"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"OutputCurrent"
#     },
#     {
#         "head":"OutputCurrent",
#         "relation":"hasNumericalValue",
#         "tail":"30"
#     },
#     {
#         "head":"OutputCurrent",
#         "relation":"hasUnit",
#         "tail":"mA"
#     },
#     {
#         "head":"MCP6V32-E-MS",
#         "relation":"hasProperty",
#         "tail":"GainBandwidthProduct"
#     },
#     {
#         "head":"GainBandwidthProduct",
#         "relation":"hasNumericalValue",
#         "tail":"0.3"
#     },
#     {
#         "head":"GainBandwidthProduct",
#         "relation":"hasUnit",
#         "tail":"MHz"
#     }
# ]
#  ```json
# [
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasType",
#     "tail": "High Speed Amplifier"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProcessTechnology",
#     "tail": "Bipolar"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "100"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "5|9"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "3.0"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12.0"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "72"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "2.6"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "OutputCurrent"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasNumericalValue",
#     "tail": "110"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "OPA625IDBVT",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "86.0"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]
# ```
#  ```json
# [
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasType",
#     "tail": "Low Offset Voltage Amplifier"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProcessTechnology",
#     "tail": "VIP10"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "72"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "6"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "12"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12.5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "5|9|12|15|18|24|28"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.07"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "OutputCurrent"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasNumericalValue",
#     "tail": "20"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "LMH6639MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "1.2"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]
# ```
#  ```json
# [
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasType",
#     "tail": "Wideband Amplifier"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProcessTechnology",
#     "tail": "LinCMOS"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "54"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "16"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "16"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "17"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.7"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "54"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "1e-05"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "TLC27M2CP",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]
# ```
#  [
#   {
#     "head": "OPA343UA",
#     "relation": "hasType",
#     "tail": "Low Noise Amplifier"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProcessTechnology",
#     "tail": "CMOS"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "PSRR"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasNumericalValue",
#     "tail": "87.96"
#   },
#   {
#     "head": "PSRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "OperatingSupplyVoltage"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "OperatingSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "SupplyVoltage"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "5.5"
#   },
#   {
#     "head": "SupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "5|9|12|15"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "CMRR"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "CMRR",
#     "relation": "hasUnit",
#     "tail": "dB"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "InputBiasCurrent"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "0.0001"
#   },
#   {
#     "head": "InputBiasCurrent",
#     "relation": "hasUnit",
#     "tail": "uA"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "70"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "OutputCurrent"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasNumericalValue",
#     "tail": "50"
#   },
#   {
#     "head": "OutputCurrent",
#     "relation": "hasUnit",
#     "tail": "mA"
#   },
#   {
#     "head": "OPA343UA",
#     "relation": "hasProperty",
#     "tail": "GainBandwidthProduct"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasNumericalValue",
#     "tail": "0.71"
#   },
#   {
#     "head": "GainBandwidthProduct",
#     "relation": "hasUnit",
#     "tail": "MHz"
#   }
# ]

# %%
process_csv_to_triplets(VideoAmpData, project_id, location, video_input_prompt, video_ouput_prompt)
# Out:
#  [
#   {
#     "head": "LMH6714MF-NOPB",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "LMH6714MF-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LMH6714MF-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "LMH6714MF-NOPB",
#     "relation": "hasPinCount",
#     "tail": "5"
#   },
#   {
#     "head": "LMH6714MF-NOPB",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±5"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "±4"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±6.25"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6714MF-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "9|12"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12.6"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6714MF-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "LM6172IN-NOPB",
#     "relation": "hasType",
#     "tail": "Dual"
#   },
#   {
#     "head": "LM6172IN-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LM6172IN-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Dual"
#   },
#   {
#     "head": "LM6172IN-NOPB",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "LM6172IN-NOPB",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±5|±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "±2.75"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LM6172IN-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "-"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LM6172IN-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "LMH6720MF-NOPB",
#     "relation": "hasType",
#     "tail": "Single"
#   },
#   {
#     "head": "LMH6720MF-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LMH6720MF-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "LMH6720MF-NOPB",
#     "relation": "hasPinCount",
#     "tail": "6"
#   },
#   {
#     "head": "LMH6720MF-NOPB",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±5"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "±4"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±6.25"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6720MF-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "9|12"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6720MF-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "LMH6739MQ-NOPB",
#     "relation": "hasType",
#     "tail": "Triple"
#   },
#   {
#     "head": "LMH6739MQ-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LMH6739MQ-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "LMH6739MQ-NOPB",
#     "relation": "hasPinCount",
#     "tail": "16"
#   },
#   {
#     "head": "LMH6739MQ-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "9"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6739MQ-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "LMH6738MQ-NOPB",
#     "relation": "hasType",
#     "tail": "Triple"
#   },
#   {
#     "head": "LMH6738MQ-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LMH6738MQ-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "LMH6738MQ-NOPB",
#     "relation": "hasPinCount",
#     "tail": "16"
#   },
#   {
#     "head": "LMH6738MQ-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "9"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6738MQ-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "AD812ARZ",
#     "relation": "hasType",
#     "tail": "Dual"
#   },
#   {
#     "head": "AD812ARZ",
#     "relation": "hasManufacturer",
#     "tail": "Analog Devices"
#   },
#   {
#     "head": "AD812ARZ",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "AD812ARZ",
#     "relation": "hasPinCount",
#     "tail": "8"
#   },
#   {
#     "head": "AD812ARZ",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±3|±5|±12|±15"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "±1.2"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±18"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "AD812ARZ",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3|5|9|12|15|18|24|28"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.4"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "36"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "AD812ARZ",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "LMH6722MA-NOPB",
#     "relation": "hasType",
#     "tail": "Quad"
#   },
#   {
#     "head": "LMH6722MA-NOPB",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "LMH6722MA-NOPB",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single|Dual"
#   },
#   {
#     "head": "LMH6722MA-NOPB",
#     "relation": "hasPinCount",
#     "tail": "14"
#   },
#   {
#     "head": "LMH6722MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "DualSupplyVoltage"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "±5"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "±4"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "±6.25"
#   },
#   {
#     "head": "DualSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6722MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "9|12"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "8"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "12.5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "LMH6722MA-NOPB",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "THS7360IPW",
#     "relation": "hasType",
#     "tail": "Hex"
#   },
#   {
#     "head": "THS7360IPW",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "THS7360IPW",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "THS7360IPW",
#     "relation": "hasPinCount",
#     "tail": "20"
#   },
#   {
#     "head": "THS7360IPW",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.7"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "THS7360IPW",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "THS7374IPW",
#     "relation": "hasType",
#     "tail": "Quad"
#   },
#   {
#     "head": "THS7374IPW",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "THS7374IPW",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "THS7374IPW",
#     "relation": "hasPinCount",
#     "tail": "14"
#   },
#   {
#     "head": "THS7374IPW",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "THS7374IPW",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]
#  [
#   {
#     "head": "THS7360IPWR",
#     "relation": "hasType",
#     "tail": "Hex"
#   },
#   {
#     "head": "THS7360IPWR",
#     "relation": "hasManufacturer",
#     "tail": "Texas Instruments"
#   },
#   {
#     "head": "THS7360IPWR",
#     "relation": "hasPowerSupplyType",
#     "tail": "Single"
#   },
#   {
#     "head": "THS7360IPWR",
#     "relation": "hasPinCount",
#     "tail": "20"
#   },
#   {
#     "head": "THS7360IPWR",
#     "relation": "hasProperty",
#     "tail": "SingleSupplyVoltage"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasNumericalValue",
#     "tail": "3"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "2.7"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "5"
#   },
#   {
#     "head": "SingleSupplyVoltage",
#     "relation": "hasUnit",
#     "tail": "V"
#   },
#   {
#     "head": "THS7360IPWR",
#     "relation": "hasProperty",
#     "tail": "OperatingTemperature"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasLowerBoundNumericalValue",
#     "tail": "-40"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUpperBoundNumericalValue",
#     "tail": "85"
#   },
#   {
#     "head": "OperatingTemperature",
#     "relation": "hasUnit",
#     "tail": "°C"
#   }
# ]

# %% [markdown]
# # Populating OWL File With Extracted Triplets

# %% [markdown]
# ### Importing OWL File Using owlready2

# %%
from owlready2 import *
filepath = "./../OntoFiles/AmpKB.rdf"
onto = get_ontology(filepath)
onto.load()
# Out:
# get_ontology("http://w3id.org/amplifiers#")

# %% [markdown]
# ### Creating Amplifier's Individuals In OWL File Using JSON Triplets

# %% [markdown]
# #### Instrumental Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/InstruAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Access the data as a Python dictionary
for array in data:
    if array[0]["tail"] == "Single":
            SingleInstrumentalAmplifier = onto.SingleInstrumentalAmplifier
            array[0]["head"] = SingleInstrumentalAmplifier(array[0]["head"])        
    else:
        DualInstrumentalAmplifier = onto.DualInstrumentalAmplifier
        array[0]["head"] = DualInstrumentalAmplifier(array[0]["head"])

# %% [markdown]
# #### Audio Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/AudioAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Access the data as a Python dictionary
for array in data:
    if array[0]["tail"] == "Class-AB":
        ClassAB = onto.ClassAB
        array[0]["head"] = ClassAB(array[0]["head"])        
    elif array[0]["tail"] == "Class-D":
        ClassD = onto.ClassD
        array[0]["head"] = ClassD(array[0]["head"])
    else:
        ClassG = onto.ClassG
        array[0]["head"] = ClassG(array[0]["head"])

# %% [markdown]
# #### GPS Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/GPSAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Access the data as a Python dictionary
for array in data:
    if array[0]["tail"] == "Low Noise Amplifier":
            LowNoiseGPSAmplifier = onto.LowNoiseGPSAmplifier
            array[0]["head"] = LowNoiseGPSAmplifier(array[0]["head"])

# %% [markdown]
# #### Operational Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/OpAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

for array in data:
    if array[0]["tail"] == "Micropower Amplifier":
        MicropowerOperationalAmplifier = onto.MicropowerOperationalAmplifier
        array[0]["head"] = MicropowerOperationalAmplifier(array[0]["head"])        
    elif array[0]["tail"] == "Precision Amplifier":
        PrecisionOperationalAmplifier = onto.PrecisionOperationalAmplifier
        array[0]["head"] = PrecisionOperationalAmplifier(array[0]["head"])
    elif array[0]["tail"] == "Auto Zero Amplifier":
        AutoZeroOperationalAmplifier = onto.AutoZeroOperationalAmplifier
        array[0]["head"] = AutoZeroOperationalAmplifier(array[0]["head"])
    elif array[0]["tail"] == "Low Power Amplifier":
        LowPowerOperationalAmplifier = onto.LowPowerOperationalAmplifier
        array[0]["head"] = LowPowerOperationalAmplifier(array[0]["head"])
    elif array[0]["tail"] == "General Purpose Amplifier":
        GeneralPurposeOperationalAmplifier = onto.GeneralPurposeOperationalAmplifier
        array[0]["head"] = GeneralPurposeOperationalAmplifier(array[0]["head"])
    elif array[0]["tail"] == "Chopper Amplifier":
        ChopperOperationalAmplifier = onto.ChopperOperationalAmplifier
        array[0]["head"] = ChopperOperationalAmplifier(array[0]["head"])
    elif array[0]["tail"] == "High Speed Amplifier":
        HighSpeedOperationalAmplifier = onto.HighSpeedOperationalAmplifier
        array[0]["head"] = HighSpeedOperationalAmplifier(array[0]["head"])
    elif array[0]["tail"] == "Low Offset Voltage Amplifier":
        LowOffsetVoltageOperationalAmplifier = onto.LowOffsetVoltageOperationalAmplifier
        array[0]["head"] = LowOffsetVoltageOperationalAmplifier(array[0]["head"])
    elif array[0]["tail"] == "Wideband Amplifier":
        WidebandOperationalAmplifier = onto.WidebandOperationalAmplifier
        array[0]["head"] = WidebandOperationalAmplifier(array[0]["head"])
    else:
        LowNoiseOperationalAmplifier = onto.LowNoiseOperationalAmplifier 
        array[0]["head"] = LowNoiseOperationalAmplifier(array[0]["head"])

# %% [markdown]
# #### Video Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/VideoAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

for array in data:
    if array[0]["tail"] == "Single":
        SingleVideoAmplifier = onto.SingleVideoAmplifier
        array[0]["head"] = SingleVideoAmplifier(array[0]["head"])        
    elif array[0]["tail"] == "Dual":
        DualVideoAmplifier = onto.DualVideoAmplifier
        array[0]["head"] = DualVideoAmplifier(array[0]["head"])
    elif array[0]["tail"] == "Hex":
        HexVideoAmplifier = onto.HexVideoAmplifier
        array[0]["head"] = HexVideoAmplifier(array[0]["head"])
    elif array[0]["tail"] == "Triple":
        TripleVideoAmplifier = onto.TripleVideoAmplifier
        array[0]["head"] = TripleVideoAmplifier(array[0]["head"])
    else:
        QuadVideoAmplifier = onto.QuadVideoAmplifier
        array[0]["head"] = QuadVideoAmplifier(array[0]["head"])

# %% [markdown]
# ### Creating Individuals For Electrical Charaterstics In OWL File Using JSON Triplets

# %% [markdown]
# #### GPS Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/GPSAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for i in range(1,11):
            if obj["relation"] == "hasProperty" and obj["tail"] == "Gain":
                Gain = onto.Gain
                gain_instance = "GPSGain"+str(i)
                gain_instance = Gain(gain_instance)
                gain_instance.
            if obj["relation"] == "hasProperty" and obj["tail"] == "SingleSupplyVoltage":
                SingleSupplyVoltage = onto.SingleSupplyVoltage
                SingleSupplyVoltage_instance = "GPSSV"+str(i)
                SingleSupplyVoltage_instance = SingleSupplyVoltage(SingleSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingFrequency":
                OperatingFrequency = onto.OperatingFrequency
                OperatingFrequency_instance = "GPSOF"+str(i)
                OperatingFrequency_instance = OperatingFrequency(OperatingFrequency_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "NoiseFigure":
                NoiseFigure = onto.NoiseFigure
                NoiseFigure_instance = "GPSNF"+str(i)
                NoiseFigure_instance = NoiseFigure(NoiseFigure_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingTemperature":
                OperatingTemperature = onto.OperatingTemperature
                OperatingTemperature_instance = "GPSOT"+str(i)
                OperatingTemperature_instance = OperatingTemperature(OperatingTemperature_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "SupplyCurrent":
                SupplyCurrent = onto.SupplyCurrent
                SupplyCurrent_instance = "GPSSC"+str(i)
                SupplyCurrent_instance = SupplyCurrent(SupplyCurrent_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "PowerDissipation":
                PowerDissipation = onto.PowerDissipation
                PowerDissipation_instance = "GPSPD"+str(i)
                PowerDissipation_instance = PowerDissipation(PowerDissipation_instance)

# %% [markdown]
# #### Audio Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/AudioAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

count = 0
# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for i in range(1,11):
            if obj["relation"] == "hasProperty" and obj["tail"] == "SingleSupplyVoltage":
                SingleSupplyVoltage = onto.SingleSupplyVoltage
                SingleSupplyVoltage_instance = "AUDIOSV"+str(i)
                SingleSupplyVoltage_instance = SingleSupplyVoltage(SingleSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingTemperature":
                OperatingTemperature = onto.OperatingTemperature
                OperatingTemperature_instance = "AUDIOOT"+str(i)
                OperatingTemperature_instance = OperatingTemperature(OperatingTemperature_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "PowerDissipation":
                PowerDissipation = onto.PowerDissipation
                PowerDissipation_instance = "AUDIOPD"+str(i)
                PowerDissipation_instance = PowerDissipation(PowerDissipation_instance)

# %% [markdown]
# #### Instrumental Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/InstruAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for i in range(1,11):
            if obj["relation"] == "hasProperty" and obj["tail"] == "PSRR":
                PSRR = onto.PSRR
                PSRR_instance = "INSTRUPSRR"+str(i)
                PSRR_instance = PSRR(PSRR_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingSupplyVoltage":
                OperatingSupplyVoltage = onto.OperatingSupplyVoltage
                OperatingSupplyVoltage_instance = "INSTRUOSV"+str(i)
                OperatingSupplyVoltage_instance = OperatingSupplyVoltage(OperatingSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "SupplyVoltage":
                SupplyVoltage = onto.SupplyVoltage
                SupplyVoltage_instance = "INSTRUSV"+str(i)
                SupplyVoltage_instance = SupplyVoltage(SupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "DualSupplyVoltage":
                DualSupplyVoltage = onto.DualSupplyVoltage
                DualSupplyVoltage_instance = "INSTRUDSV"+str(i)
                DualSupplyVoltage_instance = DualSupplyVoltage(DualSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "SingleSupplyVoltage":
                SingleSupplyVoltage = onto.SingleSupplyVoltage
                SingleSupplyVoltage_instance = "INSTRUSSV"+str(i)
                SingleSupplyVoltage_instance = SingleSupplyVoltage(SingleSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "CMRR":
                CMRR = onto.CMRR
                CMRR_instance = "INSTRUCMRR"+str(i)
                CMRR_instance = CMRR(CMRR_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "InputBiasCurrent":
                InputBiasCurrent = onto.InputBiasCurrent
                InputBiasCurrent_instance = "INSTRUIBC"+str(i)
                InputBiasCurrent_instance = InputBiasCurrent(InputBiasCurrent_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingTemperature":
                OperatingTemperature = onto.OperatingTemperature
                OperatingTemperature_instance = "INSTRUOT"+str(i)
                OperatingTemperature_instance = OperatingTemperature(OperatingTemperature_instance)

# %% [markdown]
# #### Operational Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/OpAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for i in range(1,11):
            if obj["relation"] == "hasProperty" and obj["tail"] == "PSRR":
                PSRR = onto.PSRR
                PSRR_instance = "OPPSRR"+str(i)
                PSRR_instance = PSRR(PSRR_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingSupplyVoltage":
                OperatingSupplyVoltage = onto.OperatingSupplyVoltage
                OperatingSupplyVoltage_instance = "OPOSV"+str(i)
                OperatingSupplyVoltage_instance = OperatingSupplyVoltage(OperatingSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "SupplyVoltage":
                SupplyVoltage = onto.SupplyVoltage
                SupplyVoltage_instance = "OPSV"+str(i)
                SupplyVoltage_instance = SupplyVoltage(SupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "SingleSupplyVoltage":
                SingleSupplyVoltage = onto.SingleSupplyVoltage
                SingleSupplyVoltage_instance = "OPSSV"+str(i)
                SingleSupplyVoltage_instance = SingleSupplyVoltage(SingleSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "CMRR":
                CMRR = onto.CMRR
                CMRR_instance = "OPCMRR"+str(i)
                CMRR_instance = CMRR(CMRR_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "InputBiasCurrent":
                InputBiasCurrent = onto.InputBiasCurrent
                InputBiasCurrent_instance = "OPIBC"+str(i)
                InputBiasCurrent_instance = InputBiasCurrent(InputBiasCurrent_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingTemperature":
                OperatingTemperature = onto.OperatingTemperature
                OperatingTemperature_instance = "OPOT"+str(i)
                OperatingTemperature_instance = OperatingTemperature(OperatingTemperature_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OutputCurrent":
                OutputCurrent = onto.OutputCurrent
                OutputCurrent_instance = "OPOC"+str(i)
                OutputCurrent_instance = OutputCurrent(OutputCurrent_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "GainBandwidthProduct":
                GainBandwidthProduct = onto.GainBandwidthProduct
                GainBandwidthProduct_instance = "OPGBP"+str(i)
                GainBandwidthProduct_instance = GainBandwidthProduct(GainBandwidthProduct_instance)

# %% [markdown]
# #### Video Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/VideoAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

count = 0
# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for i in range(1,11):
            if obj["relation"] == "hasProperty" and obj["tail"] == "DualSupplyVoltage":
                DualSupplyVoltage = onto.DualSupplyVoltage
                DualSupplyVoltage_instance = "VIDEODSV"+str(i)
                DualSupplyVoltage_instance = DualSupplyVoltage(DualSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "SingleSupplyVoltage":
                SingleSupplyVoltage = onto.SingleSupplyVoltage
                SingleSupplyVoltage_instance = "VIDEOSSV"+str(i)
                SingleSupplyVoltage_instance = SingleSupplyVoltage(SingleSupplyVoltage_instance)
            if obj["relation"] == "hasProperty" and obj["tail"] == "OperatingTemperature":
                OperatingTemperature = onto.OperatingTemperature
                OperatingTemperature_instance = "VIDEOOT"+str(i)
                OperatingTemperature_instance = OperatingTemperature(OperatingTemperature_instance)

# %% [markdown]
# ### Assigning Data Properties To Individuals

# %% [markdown]
# #### Video Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/VideoAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)
    
instances = list(onto.VideoAmplifier.instances())

count = 0
# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for instance in instances:
            if instance.name == obj["head"]:
                if obj["relation"] == "hasManufacturer":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasManufacturer.append(obj["tail"])
                if obj["relation"] == "hasPowerSupplyType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPowerSupplyType.append(obj["tail"])
                if obj["relation"] == "hasPinCount":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPinCount.append(obj["tail"])
# Out:
# LMH6714MF-NOPB hasManufacturer Texas Instruments
# LMH6714MF-NOPB hasPowerSupplyType Single|Dual
# LMH6714MF-NOPB hasPinCount 5
# LM6172IN-NOPB hasManufacturer Texas Instruments
# LM6172IN-NOPB hasPowerSupplyType Dual
# LM6172IN-NOPB hasPinCount 8
# LMH6720MF-NOPB hasManufacturer Texas Instruments
# LMH6720MF-NOPB hasPowerSupplyType Single|Dual
# LMH6720MF-NOPB hasPinCount 6
# LMH6739MQ-NOPB hasManufacturer Texas Instruments
# LMH6739MQ-NOPB hasPowerSupplyType Single
# LMH6739MQ-NOPB hasPinCount 16
# LMH6738MQ-NOPB hasManufacturer Texas Instruments
# LMH6738MQ-NOPB hasPowerSupplyType Single
# LMH6738MQ-NOPB hasPinCount 16
# AD812ARZ hasManufacturer Analog Devices
# AD812ARZ hasPowerSupplyType Single|Dual
# AD812ARZ hasPinCount 8
# LMH6722MA-NOPB hasManufacturer Texas Instruments
# LMH6722MA-NOPB hasPowerSupplyType Single|Dual
# LMH6722MA-NOPB hasPinCount 14
# THS7360IPW hasManufacturer Texas Instruments
# THS7360IPW hasPowerSupplyType Single
# THS7360IPW hasPinCount 20
# THS7374IPW hasManufacturer Texas Instruments
# THS7374IPW hasPowerSupplyType Single
# THS7374IPW hasPinCount 14
# THS7360IPWR hasManufacturer Texas Instruments
# THS7360IPWR hasPowerSupplyType Single
# THS7360IPWR hasPinCount 20

# %% [markdown]
# #### Audio Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/AudioAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)
    
instances = list(onto.AudioAmplifier.instances())

count = 0
# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for instance in instances:
            if instance.name == obj["head"]:
                if obj["relation"] == "hasManufacturer":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasManufacturer.append(obj["tail"])
                if obj["relation"] == "hasPowerSupplyType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPowerSupplyType.append(obj["tail"])
                if obj["relation"] == "hasInputSignalType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasInputSignalType.append(obj["tail"])
                if obj["relation"] == "hasOutputSignalType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasOutputSignalType.append(obj["tail"])
                if obj["relation"] == "hasOutputType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasOutputType.append(obj["tail"])
                if obj["relation"] == "hasPinCount":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPinCount.append(obj["tail"])
# Out:
# LM4861M-NOPB hasManufacturer Texas Instruments
# LM4861M-NOPB hasPowerSupplyType Single
# LM4861M-NOPB hasInputSignalType Single
# LM4861M-NOPB hasOutputSignalType Differential
# LM4861M-NOPB hasOutputType 1-Channel Mono
# LM4861M-NOPB hasPinCount 8
# LM4889MA-NOPB hasManufacturer Texas Instruments
# LM4889MA-NOPB hasPowerSupplyType Single
# LM4889MA-NOPB hasInputSignalType Differential|Single
# LM4889MA-NOPB hasOutputSignalType Differential
# LM4889MA-NOPB hasOutputType 1-Channel Mono
# LM4889MA-NOPB hasPinCount 8
# TPA3125D2N hasManufacturer Texas Instruments
# TPA3125D2N hasPowerSupplyType Single
# TPA3125D2N hasInputSignalType Single
# TPA3125D2N hasOutputSignalType Differential|Single
# TPA3125D2N hasOutputType 1-Channel Mono|2-Channel Stereo
# TPA3125D2N hasPinCount 20
# BD28623MUV-E2 hasManufacturer Rohm Semiconductor
# BD28623MUV-E2 hasPowerSupplyType Single
# BD28623MUV-E2 hasInputSignalType Single
# BD28623MUV-E2 hasOutputSignalType Differential
# BD28623MUV-E2 hasOutputType 2-Channel Stereo
# BD28623MUV-E2 hasPinCount 24
# OPA1611AID hasManufacturer Texas Instruments
# OPA1611AID hasPowerSupplyType Single|Dual
# OPA1611AID hasInputSignalType Differential
# OPA1611AID hasOutputSignalType Single
# OPA1611AID hasOutputType 1-Channel Mono
# OPA1611AID hasPinCount 8
# PAM8945PJR hasManufacturer Texas Instruments
# PAM8945PJR hasPowerSupplyType Single
# PAM8945PJR hasInputSignalType Differential
# PAM8945PJR hasOutputSignalType Differential
# PAM8945PJR hasOutputType 1-Channel Mono
# PAM8945PJR hasPinCount 12
# LM4862M-NOPB hasManufacturer Texas Instruments
# LM4862M-NOPB hasPowerSupplyType Single
# LM4862M-NOPB hasInputSignalType Single
# LM4862M-NOPB hasOutputSignalType Differential
# LM4862M-NOPB hasOutputType 1-Channel Mono
# LM4862M-NOPB hasPinCount 8
# LM386MMX-1-NOPB hasManufacturer Texas Instruments
# LM386MMX-1-NOPB hasPowerSupplyType Single
# LM386MMX-1-NOPB hasInputSignalType Differential
# LM386MMX-1-NOPB hasOutputSignalType Single
# LM386MMX-1-NOPB hasOutputType 1-Channel Mono
# LM386MMX-1-NOPB hasPinCount 8
# BM28723AMUV-E2 hasManufacturer Texas Instruments
# BM28723AMUV-E2 hasPowerSupplyType Triple
# BM28723AMUV-E2 hasInputSignalType Single
# BM28723AMUV-E2 hasOutputSignalType Differential
# BM28723AMUV-E2 hasOutputType 2-Channel Stereo
# BM28723AMUV-E2 hasPinCount 32
# PAM8610TR hasManufacturer Texas Instruments
# PAM8610TR hasPowerSupplyType Single
# PAM8610TR hasInputSignalType Differential
# PAM8610TR hasOutputSignalType Differential
# PAM8610TR hasOutputType 2-Channel Stereo
# PAM8610TR hasPinCount 40

# %% [markdown]
# #### GPS Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/GPSAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)
    
instances = list(onto.GPSAmplifier.instances())

count = 0
# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for instance in instances:
            if instance.name == obj["head"]:
                if obj["relation"] == "hasManufacturer":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasManufacturer.append(obj["tail"])
                if obj["relation"] == "hasProcessTechnology":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasProcessTechnology.append(obj["tail"])
                if obj["relation"] == "hasPowerSupplyType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPowerSupplyType.append(obj["tail"])
                if obj["relation"] == "hasPinCount":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPinCount.append(obj["tail"])
# Out:
# BGA725L6E6327FTSA1 hasManufacturer Infineon Technologies AG
# BGA725L6E6327FTSA1 hasProcessTechnology SiGe
# BGA725L6E6327FTSA1 hasPowerSupplyType Single
# BGA725L6E6327FTSA1 hasPinCount 6
# BGU7005-115 hasManufacturer NXP Semiconductors
# BGU7005-115 hasProcessTechnology SiGe
# BGU7005-115 hasPowerSupplyType Single
# BGU7005-115 hasPinCount 6
# BGA123L4E6327XTSA1 hasManufacturer Infineon Technologies AG
# BGA123L4E6327XTSA1 hasProcessTechnology -
# BGA123L4E6327XTSA1 hasPowerSupplyType Single
# BGA123L4E6327XTSA1 hasPinCount 4
# BGA715N7E6327XTSA2 hasManufacturer Infineon Technologies AG
# BGA715N7E6327XTSA2 hasProcessTechnology SiGe
# BGA715N7E6327XTSA2 hasPowerSupplyType Single
# BGA715N7E6327XTSA2 hasPinCount 6
# BGU8103X hasManufacturer NXP Semiconductors
# BGU8103X hasProcessTechnology SiGe
# BGU8103X hasPowerSupplyType Single
# BGU8103X hasPinCount 6
# BGU8019X hasManufacturer NXP Semiconductors
# BGU8019X hasProcessTechnology SiGe
# BGU8019X hasPowerSupplyType Single
# BGU8019X hasPinCount 6
# BGU7007-115 hasManufacturer NXP Semiconductors
# BGU7007-115 hasProcessTechnology SiGe
# BGU7007-115 hasPowerSupplyType Single
# BGU7007-115 hasPinCount 6
# BGU7008-115 hasManufacturer NXP Semiconductors
# BGU7008-115 hasProcessTechnology SiGe
# BGU7008-115 hasPowerSupplyType Single
# BGU7008-115 hasPinCount 6
# BGU7004-115 hasManufacturer NXP Semiconductors
# BGU7004-115 hasProcessTechnology SiGe
# BGU7004-115 hasPowerSupplyType Single
# BGU7004-115 hasPinCount 6
# BGA524N6E6327XTSA1 hasManufacturer Infineon Technologies AG
# BGA524N6E6327XTSA1 hasProcessTechnology SiGe
# BGA524N6E6327XTSA1 hasPowerSupplyType Single
# BGA524N6E6327XTSA1 hasPinCount 6

# %% [markdown]
# #### Instrumental Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/InstruAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)
    
instances = list(onto.InstrumentalAmplifier.instances())

count = 0
# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for instance in instances:
            if instance.name == obj["head"]:
                if obj["relation"] == "hasManufacturer":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasManufacturer.append(obj["tail"])
                if obj["relation"] == "hasPowerSupplyType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPowerSupplyType.append(obj["tail"])
                if obj["relation"] == "hasPinCount":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPinCount.append(obj["tail"])
# Out:
# INA101HP hasManufacturer Texas Instruments
# INA101HP hasPowerSupplyType Dual
# INA101HP hasPinCount 14
# MCP6N11T-100E-MNY hasManufacturer Microchip Technology
# MCP6N11T-100E-MNY hasPowerSupplyType Single
# MCP6N11T-100E-MNY hasPinCount 8
# INA122PA hasManufacturer Texas Instruments
# INA122PA hasPowerSupplyType Single|Dual
# INA122PA hasPinCount 8
# PGA204AP hasManufacturer Texas Instruments
# PGA204AP hasPowerSupplyType Dual
# PGA204AP hasPinCount 16
# INA125UA hasManufacturer Texas Instruments
# INA125UA hasPowerSupplyType Single|Dual
# INA125UA hasPinCount 16
# INA115BU hasManufacturer Texas Instruments
# INA115BU hasPowerSupplyType Dual
# INA115BU hasPinCount 16
# INA217AIDWT hasManufacturer Texas Instruments
# INA217AIDWT hasPowerSupplyType Dual
# INA217AIDWT hasPinCount 16
# LMP8358MA-NOPB hasManufacturer Texas Instruments
# LMP8358MA-NOPB hasPowerSupplyType Single
# LMP8358MA-NOPB hasPinCount 14
# MCP6N16-010E-MS hasManufacturer Microchip Technology
# MCP6N16-010E-MS hasPowerSupplyType Single
# MCP6N16-010E-MS hasPinCount 8
# INA2128U hasManufacturer Texas Instruments
# INA2128U hasPowerSupplyType Dual
# INA2128U hasPinCount 16

# %% [markdown]
# #### Operational Amplifiers

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/OpAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)
    
instances = list(onto.OperationalAmplifier.instances())

count = 0
# Access the data as a Python dictionary
for array in data:
    for obj in array:
        for instance in instances:
            if instance.name == obj["head"]:
                if obj["relation"] == "hasManufacturer":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasManufacturer.append(obj["tail"])
                if obj["relation"] == "hasProcessTechnology":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasProcessTechnology.append(obj["tail"])
                if obj["relation"] == "hasPowerSupplyType":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPowerSupplyType.append(obj["tail"])
                if obj["relation"] == "hasPinCount":
                    print("Assigning: "+obj["head"]+" "+obj["relation"]+" "+obj["tail"])
                    instance.hasPinCount.append(obj["tail"])
# Out:
# MCP607-I-P hasManufacturer Microchip Technology
# MCP607-I-P hasProcessTechnology CMOS
# MCP607-I-P hasPowerSupplyType Single
# MCP607-I-P hasPinCount 8
# MCP6034-E-SL hasManufacturer Microchip Technology
# MCP6034-E-SL hasProcessTechnology CMOS
# MCP6034-E-SL hasPowerSupplyType Single
# MCP6034-E-SL hasPinCount 14
# MCP6V27-E-SN hasManufacturer Microchip Technology
# MCP6V27-E-SN hasProcessTechnology CMOS
# MCP6V27-E-SN hasPowerSupplyType Single
# MCP6V27-E-SN hasPinCount 8
# MCP6292-E-P hasManufacturer Microchip Technology
# MCP6292-E-P hasProcessTechnology CMOS
# MCP6292-E-P hasPowerSupplyType Single
# MCP6292-E-P hasPinCount 8
# MCP6V32-E-MS hasManufacturer Microchip Technology
# MCP6V32-E-MS hasProcessTechnology CMOS
# MCP6V32-E-MS hasPowerSupplyType Single
# MCP6V32-E-MS hasPinCount 8
# OPA625IDBVT hasManufacturer Texas Instruments
# OPA625IDBVT hasProcessTechnology Bipolar
# OPA625IDBVT hasPowerSupplyType Single|Dual
# OPA625IDBVT hasPinCount 8
# LMH6639MA-NOPB hasManufacturer Texas Instruments
# LMH6639MA-NOPB hasProcessTechnology VIP10
# LMH6639MA-NOPB hasPowerSupplyType Single|Dual
# LMH6639MA-NOPB hasPinCount 8
# TLC27M2CP hasManufacturer Texas Instruments
# TLC27M2CP hasProcessTechnology LinCMOS
# TLC27M2CP hasPowerSupplyType Single
# TLC27M2CP hasPinCount 8
# OPA343UA hasManufacturer Texas Instruments
# OPA343UA hasProcessTechnology CMOS
# OPA343UA hasPowerSupplyType Single|Dual
# OPA343UA hasPinCount 8

# %%
onto.save(filepath)

# %%
import json

# Specify the path to your JSON file
json_file_path = './../ExtractedTriplets/OpAmpTriplets.json'

# Read and parse the JSON file
with open(json_file_path, 'r') as file:
    data = json.load(file)

# Access the data as a Python dictionary
for array in data:
    for obj in array:
        print(obj["head"]+" "+obj["relation"]+" "+obj["tail"])
# Out:
# MCP607-I-P hasType Micropower Amplifier
# MCP607-I-P hasManufacturer Microchip Technology
# MCP607-I-P hasProcessTechnology CMOS
# MCP607-I-P hasPowerSupplyType Single
# MCP607-I-P hasPinCount 8
# MCP607-I-P hasProperty PSRR
# PSRR hasLowerBoundNumericalValue 80
# PSRR hasUnit dB
# MCP607-I-P hasProperty OperatingSupplyVoltage
# OperatingSupplyVoltage hasUpperBoundNumericalValue 6
# OperatingSupplyVoltage hasUnit V
# MCP607-I-P hasProperty SupplyVoltage
# SupplyVoltage hasLowerBoundNumericalValue 6
# SupplyVoltage hasUpperBoundNumericalValue 9
# SupplyVoltage hasUnit V
# MCP607-I-P hasProperty SingleSupplyVoltage
# SingleSupplyVoltage hasNumericalValue 3|5
# SingleSupplyVoltage hasLowerBoundNumericalValue 2.5
# SingleSupplyVoltage hasUpperBoundNumericalValue 6
# SingleSupplyVoltage hasUnit V
# MCP607-I-P hasProperty CMRR
# CMRR hasLowerBoundNumericalValue 75
# CMRR hasUnit dB
# MCP607-I-P hasProperty InputBiasCurrent
# InputBiasCurrent hasUpperBoundNumericalValue -
# InputBiasCurrent hasUnit uA
# MCP607-I-P hasProperty OperatingTemperature
# OperatingTemperature hasLowerBoundNumericalValue -40
# OperatingTemperature hasUpperBoundNumericalValue 85
# OperatingTemperature hasUnit °C
# MCP607-I-P hasProperty OutputCurrent
# OutputCurrent hasNumericalValue 30
# OutputCurrent hasUnit mA
# MCP607-I-P hasProperty GainBandwidthProduct
# GainBandwidthProduct hasNumericalValue 0.155
# GainBandwidthProduct hasUnit MHz
# MCP6034-E-SL hasType Precision Amplifier
# MCP6034-E-SL hasManufacturer Microchip Technology
# MCP6034-E-SL hasProcessTechnology CMOS
# MCP6034-E-SL hasPowerSupplyType Single
# MCP6034-E-SL hasPinCount 14
# MCP6034-E-SL hasProperty PSRR
# PSRR hasLowerBoundNumericalValue 70
# PSRR hasUnit dB
# MCP6034-E-SL hasProperty OperatingSupplyVoltage
# OperatingSupplyVoltage hasUpperBoundNumericalValue 5.5
# OperatingSupplyVoltage hasUnit V
# MCP6034-E-SL hasProperty SupplyVoltage
# SupplyVoltage hasLowerBoundNumericalValue 5.5
# SupplyVoltage hasUpperBoundNumericalValue 6
# SupplyVoltage hasUnit V
# MCP6034-E-SL hasProperty SingleSupplyVoltage
# SingleSupplyVoltage hasNumericalValue 3|5
# SingleSupplyVoltage hasLowerBoundNumericalValue 1.8
# SingleSupplyVoltage hasUpperBoundNumericalValue 5.5
# SingleSupplyVoltage hasUnit V
# MCP6034-E-SL hasProperty CMRR
# CMRR hasLowerBoundNumericalValue 70
# CMRR hasUnit dB
# MCP6034-E-SL hasProperty InputBiasCurrent
# InputBiasCurrent hasUpperBoundNumericalValue 0.0001
# InputBiasCurrent hasUnit uA
# MCP6034-E-SL hasProperty OperatingTemperature
# OperatingTemperature hasLowerBoundNumericalValue -40
# OperatingTemperature hasUpperBoundNumericalValue 125
# OperatingTemperature hasUnit °C
# MCP6034-E-SL hasProperty OutputCurrent
# OutputCurrent hasNumericalValue 30
# OutputCurrent hasUnit mA
# MCP6034-E-SL hasProperty GainBandwidthProduct
# GainBandwidthProduct hasNumericalValue 0.01
# GainBandwidthProduct hasUnit MHz
# MCP6V27-E-SN hasType Auto Zero Amplifier
# MCP6V27-E-SN hasManufacturer Microchip Technology
# MCP6V27-E-SN hasProcessTechnology CMOS
# MCP6V27-E-SN hasPowerSupplyType Single
# MCP6V27-E-SN hasPinCount 8
# MCP6V27-E-SN hasProperty PSRR
# PSRR hasLowerBoundNumericalValue 125
# PSRR hasUnit dB
# MCP6V27-E-SN hasProperty OperatingSupplyVoltage
# OperatingSupplyVoltage hasUpperBoundNumericalValue 5.5
# OperatingSupplyVoltage hasUnit V
# MCP6V27-E-SN hasProperty SupplyVoltage
# SupplyVoltage hasLowerBoundNumericalValue 5.5
# SupplyVoltage hasUpperBoundNumericalValue 6
# SupplyVoltage hasUnit V
# MCP6V27-E-SN hasProperty SingleSupplyVoltage
# SingleSupplyVoltage hasNumericalValue 3|5
# SingleSupplyVoltage hasLowerBoundNumericalValue 2.3
# SingleSupplyVoltage hasUpperBoundNumericalValue 5.5
# SingleSupplyVoltage hasUnit V
# MCP6V27-E-SN hasProperty CMRR
# CMRR hasLowerBoundNumericalValue 120
# CMRR hasUnit dB
# MCP6V27-E-SN hasProperty InputBiasCurrent
# InputBiasCurrent hasUpperBoundNumericalValue 0.005
# InputBiasCurrent hasUnit uA
# MCP6V27-E-SN hasProperty OperatingTemperature
# OperatingTemperature hasLowerBoundNumericalValue -40
# OperatingTemperature hasUpperBoundNumericalValue 125
# OperatingTemperature hasUnit °C
# MCP6V27-E-SN hasProperty OutputCurrent
# OutputCurrent hasNumericalValue 30
# OutputCurrent hasUnit mA
# MCP6V27-E-SN hasProperty GainBandwidthProduct
# GainBandwidthProduct hasNumericalValue 2.0
# GainBandwidthProduct hasUnit MHz
# MCP6292-E-P hasType General Purpose Amplifier
# MCP6292-E-P hasManufacturer Microchip Technology
# MCP6292-E-P hasProcessTechnology CMOS
# MCP6292-E-P hasPowerSupplyType Single
# MCP6292-E-P hasPinCount 8
# MCP6292-E-P hasProperty PSRR
# PSRR hasLowerBoundNumericalValue 70
# PSRR hasUnit dB
# MCP6292-E-P hasProperty OperatingSupplyVoltage
# OperatingSupplyVoltage hasUpperBoundNumericalValue 5.5
# OperatingSupplyVoltage hasUnit V
# MCP6292-E-P hasProperty SupplyVoltage
# SupplyVoltage hasLowerBoundNumericalValue 5.5
# SupplyVoltage hasUpperBoundNumericalValue 6
# SupplyVoltage hasUnit V
# MCP6292-E-P hasProperty SingleSupplyVoltage
# SingleSupplyVoltage hasNumericalValue 3|5
# SingleSupplyVoltage hasLowerBoundNumericalValue 2.4
# SingleSupplyVoltage hasUpperBoundNumericalValue 6
# SingleSupplyVoltage hasUnit V
# MCP6292-E-P hasProperty CMRR
# CMRR hasLowerBoundNumericalValue 70
# CMRR hasUnit dB
# MCP6292-E-P hasProperty InputBiasCurrent
# InputBiasCurrent hasUpperBoundNumericalValue 1e-06
# InputBiasCurrent hasUnit uA
# MCP6292-E-P hasProperty OperatingTemperature
# OperatingTemperature hasLowerBoundNumericalValue -40
# OperatingTemperature hasUpperBoundNumericalValue 125
# OperatingTemperature hasUnit °C
# MCP6292-E-P hasProperty OutputCurrent
# OutputCurrent hasNumericalValue 30
# OutputCurrent hasUnit mA
# MCP6292-E-P hasProperty GainBandwidthProduct
# GainBandwidthProduct hasNumericalValue 10.0
# GainBandwidthProduct hasUnit MHz
# MCP6V32-E-MS hasType Chopper Amplifier
# MCP6V32-E-MS hasManufacturer Microchip Technology
# MCP6V32-E-MS hasProcessTechnology CMOS
# MCP6V32-E-MS hasPowerSupplyType Single
# MCP6V32-E-MS hasPinCount 8
# MCP6V32-E-MS hasProperty PSRR
# PSRR hasLowerBoundNumericalValue 120
# PSRR hasUnit dB
# MCP6V32-E-MS hasProperty OperatingSupplyVoltage
# OperatingSupplyVoltage hasUpperBoundNumericalValue 5.5
# OperatingSupplyVoltage hasUnit V
# MCP6V32-E-MS hasProperty SupplyVoltage
# SupplyVoltage hasLowerBoundNumericalValue 5.5
# SupplyVoltage hasUpperBoundNumericalValue 6
# SupplyVoltage hasUnit V
# MCP6V32-E-MS hasProperty SingleSupplyVoltage
# SingleSupplyVoltage hasNumericalValue 3|5
# SingleSupplyVoltage hasLowerBoundNumericalValue 1.8
# SingleSupplyVoltage hasUpperBoundNumericalValue 5.5
# SingleSupplyVoltage hasUnit V
# MCP6V32-E-MS hasProperty CMRR
# CMRR hasLowerBoundNumericalValue 120
# CMRR hasUnit dB
# MCP6V32-E-MS hasProperty InputBiasCurrent
# InputBiasCurrent hasUpperBoundNumericalValue -
# InputBiasCurrent hasUnit uA
# MCP6V32-E-MS hasProperty OperatingTemperature
# OperatingTemperature hasLowerBoundNumericalValue -40
# OperatingTemperature hasUpperBoundNumericalValue 125
# OperatingTemperature hasUnit °C
# MCP6V32-E-MS hasProperty OutputCurrent
# OutputCurrent hasNumericalValue 30
# OutputCurrent hasUnit mA
# MCP6V32-E-MS hasProperty GainBandwidthProduct
# GainBandwidthProduct hasNumericalValue 0.3
# GainBandwidthProduct hasUnit MHz
# OPA625IDBVT hasType High Speed Amplifier
# OPA625IDBVT hasManufacturer Texas Instruments
# OPA625IDBVT hasProcessTechnology Bipolar
# OPA625IDBVT hasPowerSupplyType Single|Dual
# OPA625IDBVT hasPinCount 8
# OPA625IDBVT hasProperty PSRR
# PSRR hasLowerBoundNumericalValue 100
# PSRR hasUnit dB
# OPA625IDBVT hasProperty OperatingSupplyVoltage
# OperatingSupplyVoltage hasUpperBoundNumericalValue 5.5
# OperatingSupplyVoltage hasUnit V
# OPA625IDBVT hasProperty SupplyVoltage
# SupplyVoltage hasLowerBoundNumericalValue 5.5
# SupplyVoltage hasUpperBoundNumericalValue 6
# SupplyVoltage hasUnit V
# OPA625IDBVT hasProperty SingleSupplyVoltage
# SingleSupplyVoltage hasNumericalValue 5|9
# SingleSupplyVoltage hasLowerBoundNumericalValue 3.0
# SingleSupplyVoltage hasUpperBoundNumericalValue 12.0
# SingleSupplyVoltage hasUnit V
# OPA625IDBVT hasProperty CMRR
# CMRR hasLowerBoundNumericalValue 72
# CMRR hasUnit dB
# OPA625IDBVT hasProperty InputBiasCurrent
# InputBiasCurrent hasUpperBoundNumericalValue 2.6
# InputBiasCurrent hasUnit uA
# OPA625IDBVT hasProperty OperatingTemperature
# OperatingTemperature hasLowerBoundNumericalValue -40
# OperatingTemperature hasUpperBoundNumericalValue 85
# OperatingTemperature hasUnit °C
# OPA625IDBVT hasProperty OutputCurrent
# OutputCurrent hasNumericalValue 110
# OutputCurrent hasUnit mA
# OPA625IDBVT hasProperty GainBandwidthProduct
# GainBandwidthProduct hasNumericalValue 86.0
# GainBandwidthProduct hasUnit MHz
# LMH6639MA-NOPB hasType Low Offset Voltage Amplifier
# LMH6639MA-NOPB hasManufacturer Texas Instruments
# LMH6639MA-NOPB hasProcessTechnology VIP10
# LMH6639MA-NOPB hasPowerSupplyType Single|Dual
# LMH6639MA-NOPB hasPinCount 8
# LMH6639MA-NOPB hasProperty PSRR
# PSRR hasLowerBoundNumericalValue 72
# PSRR hasUnit dB
# LMH6639MA-NOPB hasProperty OperatingSupplyVoltage
# OperatingSupplyVoltage hasUpperBoundNumericalValue 6
# OperatingSupplyVoltage hasUnit V
# LMH6639MA-NOPB hasProperty SupplyVoltage
# SupplyVoltage hasLowerBoundNumericalValue 12
# SupplyVoltage hasUpperBoundNumericalValue 12.5
# SupplyVoltage hasUnit V
# LMH6639MA-NOPB hasProperty SingleSupplyVoltage
# SingleSupplyVoltage hasNumericalValue 5|9|12|15|18|24|28
# SingleSupplyVoltage hasUnit V
# LMH6639MA-NOPB hasProperty CMRR
# CMRR hasLowerBoundNumericalValue 85
# CMRR hasUnit dB
# LMH6639MA-NOPB hasProperty InputBiasCurrent
# InputBiasCurrent hasUpperBoundNumericalValue 0.07
# InputBiasCurrent hasUnit uA
# LMH6639MA-NOPB hasProperty OperatingTemperature
# OperatingTemperature hasLowerBoundNumericalValue -40
# OperatingTemperature hasUpperBoundNumericalValue 85
# OperatingTemperature hasUnit °C
# LMH6639MA-NOPB hasProperty OutputCurrent
# OutputCurrent hasNumericalValue 20
# OutputCurrent hasUnit mA
# LMH6639MA-NOPB hasProperty GainBandwidthProduct
# GainBandwidthProduct hasNumericalValue 1.2
# GainBandwidthProduct hasUnit MHz
# TLC27M2CP hasType Wideband Amplifier
# TLC27M2CP hasManufacturer Texas Instruments
# TLC27M2CP hasProcessTechnology LinCMOS
# TLC27M2CP hasPowerSupplyType Single
# TLC27M2CP hasPinCount 8
# TLC27M2CP hasProperty PSRR
# PSRR hasLowerBoundNumericalValue 54
# PSRR hasUnit dB
# TLC27M2CP hasProperty OperatingSupplyVoltage
# OperatingSupplyVoltage hasUpperBoundNumericalValue 16
# OperatingSupplyVoltage hasUnit V
# TLC27M2CP hasProperty SupplyVoltage
# SupplyVoltage hasLowerBoundNumericalValue 16
# SupplyVoltage hasUpperBoundNumericalValue 17
# SupplyVoltage hasUnit V
# TLC27M2CP hasProperty SingleSupplyVoltage
# SingleSupplyVoltage hasNumericalValue 3
# SingleSupplyVoltage hasLowerBoundNumericalValue 2.7
# SingleSupplyVoltage hasUpperBoundNumericalValue 5
# SingleSupplyVoltage hasUnit V
# TLC27M2CP hasProperty CMRR
# CMRR hasLowerBoundNumericalValue 54
# CMRR hasUnit dB
# TLC27M2CP hasProperty InputBiasCurrent
# InputBiasCurrent hasUpperBoundNumericalValue 1e-05
# InputBiasCurrent hasUnit uA
# TLC27M2CP hasProperty OperatingTemperature
# OperatingTemperature hasLowerBoundNumericalValue -40
# OperatingTemperature hasUpperBoundNumericalValue 85
# OperatingTemperature hasUnit °C
# TLC27M2CP hasProperty OutputCurrent
# OutputCurrent hasNumericalValue -
# OutputCurrent hasUnit mA
# TLC27M2CP hasProperty GainBandwidthProduct
# GainBandwidthProduct hasNumericalValue 5.5
# GainBandwidthProduct hasUnit MHz
# OPA343UA hasType Low Noise Amplifier
# OPA343UA hasManufacturer Texas Instruments
# OPA343UA hasProcessTechnology CMOS
# OPA343UA hasPowerSupplyType Single|Dual
# OPA343UA hasPinCount 8
# OPA343UA hasProperty PSRR
# PSRR hasNumericalValue 87.96
# PSRR hasUnit dB
# OPA343UA hasProperty OperatingSupplyVoltage
# OperatingSupplyVoltage hasUpperBoundNumericalValue 5
# OperatingSupplyVoltage hasUnit V
# OPA343UA hasProperty SupplyVoltage
# SupplyVoltage hasLowerBoundNumericalValue 5.5
# SupplyVoltage hasUnit V
# OPA343UA hasProperty SingleSupplyVoltage
# SingleSupplyVoltage hasNumericalValue 5|9|12|15
# SingleSupplyVoltage hasUnit V
# OPA343UA hasProperty CMRR
# CMRR hasLowerBoundNumericalValue 70
# CMRR hasUnit dB
# OPA343UA hasProperty InputBiasCurrent
# InputBiasCurrent hasUpperBoundNumericalValue 0.0001
# InputBiasCurrent hasUnit uA
# OPA343UA hasProperty OperatingTemperature
# OperatingTemperature hasUpperBoundNumericalValue 70
# OperatingTemperature hasUnit °C
# OPA343UA hasProperty OutputCurrent
# OutputCurrent hasNumericalValue 50
# OutputCurrent hasUnit mA
# OPA343UA hasProperty GainBandwidthProduct
# GainBandwidthProduct hasNumericalValue 0.71
# GainBandwidthProduct hasUnit MHz
